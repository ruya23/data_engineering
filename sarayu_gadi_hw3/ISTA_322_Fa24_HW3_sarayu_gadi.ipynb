# %% [markdown]
# #HW3 - SQL
#
# This homework has you working with a new database of information on ticket sales for various types of events.  Your job will be to do some initial exploring and then demonstrate your ability to do all the different types of SQL queries we learned over the last two week.  You'll also need to make one function that'll make looking at the tables easier.
#
# These questions are written in the way someone would ask them to you.  In other words, I'm using 'plain english' questions vs. ones where I'm very explicit in terms of what columns and tables to use.  Your exploring of the database and functions to ease that process will come in handy here!
#
# The database has been created using a set of data from Amazon. You can read more about what each table contains here: https://docs.aws.amazon.com/redshift/latest/dg/c_sampledb.html.

# %% [markdown]
# ## Libraries and import functions

# %% [markdown]
# First bring the libraries we'll need!

# %%
import psycopg2
import pandas as pd

# %% [markdown]
# Now bring in all our functions we used in the lessons!

# %%
# Make our connection/cursor function
AWS_host_name = "ticketsdb.chwicm24ose3.us-east-1.rds.amazonaws.com"
AWS_dbname = "ticketsdb"
AWS_user_name = "postgres"
AWS_password = "ista322ticketsdb"

def get_conn_cur(): # define function name and arguments (there aren't any)
  # Make a connection
  conn = psycopg2.connect(
    host=AWS_host_name,
    database=AWS_dbname,
    user=AWS_user_name,
    password=AWS_password,
    port='5432')

  cur = conn.cursor()   # Make a cursor after

  return(conn, cur)   # Return both the connection and the cursor

# Same run_query function
def run_query(query_string):

  conn, cur = get_conn_cur() # get connection and cursor

  cur.execute(query_string) # executing string as before

  my_data = cur.fetchall() # fetch query data as before

  # here we're extracting the 0th element for each item in cur.description
  colnames = [desc[0] for desc in cur.description]

  cur.close() # close
  conn.close() # close

  return(colnames, my_data) # return column names AND data

# Column name function for checking out what's in a table
def get_column_names(table_name): # arguement of table_name
  conn, cur = get_conn_cur() # get connection and cursor

  # Now select column names while inserting the table name into the WERE
  column_name_query =  """SELECT column_name FROM information_schema.columns
       WHERE table_name = '%s' """ %table_name

  cur.execute(column_name_query) # exectue
  my_data = cur.fetchall() # store

  cur.close() # close
  conn.close() # close

  return(my_data) # return

# Check table_names
def get_table_names():
  conn, cur = get_conn_cur() # get connection and cursor

  # query to get table names
  table_name_query = """SELECT table_name FROM information_schema.tables
       WHERE table_schema = 'public' """

  cur.execute(table_name_query) # execute
  my_data = cur.fetchall() # fetch results

  cur.close() #close cursor
  conn.close() # close connection

  return(my_data) # return your fetched results

# %% [markdown]
# ## Q1 Make a SQL head function - 5 point
#
# Make function to get the pandas equivalent of `.head()`
#
# This function should be called `sql_head` and take a single argument of `table_name` where you specify the table name you want the head information from.  It should return the column names along with the first five rows of the table along.
#
# **For full points, return a pandas dataframe with this information so it displays nicely :)**

# %%
## Q1 Your function starts here
# make sql_head function
def sql_head(table_name):
    conn, cur = get_conn_cur()
    query = f"SELECT * FROM {table_name} LIMIT 5"
    sql_head_df = pd.read_sql_query(query, conn)
    cur.close()
    conn.close()

    return sql_head_df

get_table_names()
# Out:
# [('sales',),
#  ('venue',),
#  ('event',),
#  ('users',),
#  ('category',),
#  ('listing',),
#  ('date',)]

# %%
# Check that it works!
sql_head(table_name = 'sales')
## Q1 Your function ends here - Any code outside of these start/end markers won't be graded
# Out:
# <ipython-input-3-4e7c988bffb5>:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_head_df = pd.read_sql_query(query, conn)
#    sales_id  list_id  seller_id  buyer_id  event_id  date_id  qty_sold  \
# 0         2        4       8117     11498      4337     1983         2
# 1         3        5       1616     17433      8647     1983         2
# 2         4        5       1616     19715      8647     1986         1
# 3         5        6      47402     14115      8240     2069         2
# 4         6       10      24858     24888      3375     2023         2
#
#    price_paid  commission           sale_time
# 0          76       11.40   6/6/2008 05:00:16
# 1         350       52.50   6/6/2008 08:26:17
# 2         175       26.25   6/9/2008 08:38:52
# 3         154       23.10  8/31/2008 09:17:02
# 4         394       59.10  7/16/2008 11:59:24

# %% [markdown]
# ## Q2 Explore and SELECT - 5 point
#
# Let's start this homework with some basic queries to get a look at what's in the various tables.  I want you to do the following.
#
# * Use your get_table_names() function to see what tables are in the database.
# * Use your get_column_names() to get the column names of each of the tables.  **Do this all within a single cell to keep it neat**.
# * Make and run a query that selects all columns from the event table.  Only return the first 5 rows.
# * Use the `sql_head()` function you created to get the first five rows of the sales table.

# %%
## Q2 Your function starts here
# Getting table names
get_table_names()
# Out:
# [('sales',),
#  ('venue',),
#  ('event',),
#  ('users',),
#  ('category',),
#  ('listing',),
#  ('date',)]

# %%
# Getting column names
for i in get_table_names():
  print(get_column_names(table_name = i[0]))
# Out:
# [('sales_id',), ('list_id',), ('seller_id',), ('buyer_id',), ('event_id',), ('date_id',), ('qty_sold',), ('price_paid',), ('commission',), ('sale_time',)]
# [('venue_id',), ('venue_seats',), ('venue_name',), ('venue_city',), ('venue_state',)]
# [('event_id',), ('venue_id',), ('cat_id',), ('date_id',), ('start_time',), ('event_name',)]
# [('user_id',), ('user_name',), ('first_name',), ('last_name',), ('city',), ('state',), ('email',), ('phone',), ('like_sports',), ('like_theatre',), ('like_concerts',), ('like_jazz',), ('like_classical',), ('like_opera',), ('like_rock',), ('like_vegas',), ('like_broadway',), ('like_musicals',)]
# [('cat_id',), ('cat_group',), ('cat_name',), ('cat_desc',)]
# [('list_id',), ('seller_id',), ('event_id',), ('date_id',), ('num_tickets',), ('price_per_ticket',), ('total_price',), ('list_time',)]
# [('date_id',), ('qtr',), ('year',), ('holiday',), ('week',), ('cal_date',), ('day',), ('month',)]

# %%
# Could also just use a list comprehension vs a bunch of print statements :)
names = get_table_names()
[get_column_names(table_name= x) for x in names]
# Out:
# [[('sales_id',),
#   ('list_id',),
#   ('seller_id',),
#   ('buyer_id',),
#   ('event_id',),
#   ('date_id',),
#   ('qty_sold',),
#   ('price_paid',),
#   ('commission',),
#   ('sale_time',)],
#  [('venue_id',),
#   ('venue_seats',),
#   ('venue_name',),
#   ('venue_city',),
#   ('venue_state',)],
#  [('event_id',),
#   ('venue_id',),
#   ('cat_id',),
#   ('date_id',),
#   ('start_time',),
#   ('event_name',)],
#  [('user_id',),
#   ('user_name',),
#   ('first_name',),
#   ('last_name',),
#   ('city',),
#   ('state',),
#   ('email',),
#   ('phone',),
#   ('like_sports',),
#   ('like_theatre',),
#   ('like_concerts',),
#   ('like_jazz',),
#   ('like_classical',),
#   ('like_opera',),
#   ('like_rock',),
#   ('like_vegas',),
#   ('like_broadway',),
#   ('like_musicals',)],
#  [('cat_id',), ('cat_group',), ('cat_name',), ('cat_desc',)],
#  [('list_id',),
#   ('seller_id',),
#   ('event_id',),
#   ('date_id',),
#   ('num_tickets',),
#   ('price_per_ticket',),
#   ('total_price',),
#   ('list_time',)],
#  [('date_id',),
#   ('qtr',),
#   ('year',),
#   ('holiday',),
#   ('week',),
#   ('cal_date',),
#   ('day',),
#   ('month',)]]

# %%
# Query on events
sq = """ SELECT *
FROM event
LIMIT 5"""
run_query(sq)
# Out:
# (['event_id', 'venue_id', 'cat_id', 'date_id', 'event_name', 'start_time'],
#  [(2, 306, 8, 2114, 'Boris Godunov', datetime.datetime(2008, 10, 15, 20, 0)),
#   (3, 302, 8, 1935, 'Salome', datetime.datetime(2008, 4, 19, 14, 30)),
#   (4,
#    309,
#    8,
#    2090,
#    'La Cenerentola (Cinderella)',
#    datetime.datetime(2008, 9, 21, 14, 30)),
#   (5, 302, 8, 1982, 'Il Trovatore', datetime.datetime(2008, 6, 5, 19, 0)),
#   (6,
#    308,
#    8,
#    2109,
#    'L Elisir d Amore',
#    datetime.datetime(2008, 10, 10, 19, 30))])

# %%
# Use sql_head to get the head of sales
sql_head(table_name = 'sales')
## Q2 Your function ends here - Any code outside of these start/end markers won't be graded
# Out:
# <ipython-input-3-4e7c988bffb5>:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_head_df = pd.read_sql_query(query, conn)
#    sales_id  list_id  seller_id  buyer_id  event_id  date_id  qty_sold  \
# 0         2        4       8117     11498      4337     1983         2
# 1         3        5       1616     17433      8647     1983         2
# 2         4        5       1616     19715      8647     1986         1
# 3         5        6      47402     14115      8240     2069         2
# 4         6       10      24858     24888      3375     2023         2
#
#    price_paid  commission           sale_time
# 0          76       11.40   6/6/2008 05:00:16
# 1         350       52.50   6/6/2008 08:26:17
# 2         175       26.25   6/9/2008 08:38:52
# 3         154       23.10  8/31/2008 09:17:02
# 4         394       59.10  7/16/2008 11:59:24

# %% [markdown]
# ## Q3 WHERE - 5 points
#
# Now let's do a bit of filtering with WHERE.  Write and run queries to get the following results.
# **LIMIT all returns to first five rows.**
#
# * Get venues (**full row of data, including venue_id, etc.**) with >= 10000 seats from the venues table
# * Get venues (**full row of data, including venue_id, etc.**) in Arizona
# * Get users (**just the first names**) who have a first name that starts with H
# * Get the email addresses (**just the email addresses**) of users who gave a .edu email address

# %%
## Q3 Your function starts here
# Get big venues... so those with >= than 10000 seats
sq1 = """ SELECT *
          FROM venue
          WHERE venue_seats >= 10000
          LIMIT 5"""

run_query(sq1)
# Out:
# (['venue_id', 'venue_name', 'venue_city', 'venue_state', 'venue_seats'],
#  [(5, 'Gillette Stadium', 'Foxborough', 'MA', 68756),
#   (6, 'New York Giants Stadium', 'East Rutherford', 'NJ', 80242),
#   (15, 'McAfee Coliseum', 'Oakland', 'CA', 63026),
#   (18, 'Madison Square Garden', 'New York City', 'NY', 20000),
#   (67, 'Ralph Wilson Stadium', 'Orchard Park', 'NY', 73967)])

# %%
# Get venues in AZ
sq2 = """ SELECT *
          FROM venue
          WHERE venue_state = 'AZ'
          LIMIT 5;"""
run_query(sq2)
# Out:
# (['venue_id', 'venue_name', 'venue_city', 'venue_state', 'venue_seats'],
#  [(38, 'US Airways Center', 'Phoenix', 'AZ', 0),
#   (65, 'Jobing.com Arena', 'Glendale', 'AZ', 0),
#   (92, 'University of Phoenix Stadium', 'Glendale', 'AZ', 0),
#   (117, 'Chase Field', 'Phoenix', 'AZ', 0)])

# %%
#Get users who have a first name that starts with H
sq3 = """ SELECT first_name
          FROM users
          WHERE first_name LIKE 'H%'
          LIMIT 5;"""
run_query(sq3)
# Out:
# (['first_name'],
#  [('Henry',), ('Hermione',), ('Helen',), ('Howard',), ('Herman',)])

# %%
# Get all .edu email addresses... just the email addresses
sq4 = """ SELECT email
          FROM users
          WHERE email LIKE '%.edu'
          LIMIT 5;"""
run_query(sq4)
## Q3 Your function ends here - Any code outside of these start/end markers won't be graded
# Out:
# (['email'],
#  [('Suspendisse.tristique@nonnisiAenean.edu',),
#   ('ullamcorper.nisl@Cras.edu',),
#   ('vel.est@velitegestas.edu',),
#   ('justo.nec.ante@quismassa.edu',),
#   ('non.justo.Proin@ametconsectetuer.edu',)])

# %% [markdown]
# ## Q4 GROUP BY and HAVING - 5 points
#
# Time to practice some GROUP BY and HAVING operations. Please write and run queries that do the following:
#
# GROUP BY application
# * Find the top five venues that hosted the most events: Alias the count of events as 'events_hosted'. Also return the venue ID
# * Get the number of events hosted in each month. You'll need to use `date_part()` in your select to select just the months. Alias this as 'month' and then the count of the number of events hosted as 'events_hosted'.
# * Get the top five sellers who made the most commission. Alias their total commission made as 'total_com'. Also get their average commission made and alias as 'avg_com'.  Be sure to also display the seller_id.
#
# HAVING application
# * Using the same query as the last one, instead of getting the top five sellers get all sellers who have made a total commission greater than $4000.
# * Using the same query as the first groupby, instead of returning the top five venues, return just the ID's of venues that have had greater than 60 events.

# %%
## Q4 Your function starts here
### GROUP BY application
# Find the top five venues that hosted the most events: Alias the count of events as 'events_hosted'. Also return the venue ID
sq1 = """ SELECT venue_id,
          COUNT(*) AS events_hosted
          FROM venue
          GROUP BY venue_id
          ORDER BY events_hosted DESC
          LIMIT 5;"""
run_query(sq1)
# Out:
# (['venue_id', 'events_hosted'],
#  [(87, 1), (71, 1), (229, 1), (68, 1), (116, 1)])

# %%
# Get the number of events hosted in each month. You'll need to use `date_part()` in your select to select just the months.
# Alias this as 'month' and then the count of the number of events hosted as 'events_hosted'
sq2 = """ SELECT date_part('month', start_time) AS month,
          COUNT(*) AS events_hosted
          FROM event
          GROUP BY month
          ORDER BY month;"""
run_query(sq2)
# Out:
# (['month', 'events_hosted'],
#  [(1.0, 777),
#   (2.0, 711),
#   (3.0, 753),
#   (4.0, 725),
#   (5.0, 727),
#   (6.0, 709),
#   (7.0, 729),
#   (8.0, 737),
#   (9.0, 746),
#   (10.0, 735),
#   (11.0, 726),
#   (12.0, 722)])

# %%
sql_head(table_name = 'event')
# Out:
# <ipython-input-3-4e7c988bffb5>:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_head_df = pd.read_sql_query(query, conn)
#    event_id  venue_id  cat_id  date_id                   event_name  \
# 0         2       306       8     2114                Boris Godunov
# 1         3       302       8     1935                       Salome
# 2         4       309       8     2090  La Cenerentola (Cinderella)
# 3         5       302       8     1982                 Il Trovatore
# 4         6       308       8     2109             L Elisir d Amore
#
#            start_time
# 0 2008-10-15 20:00:00
# 1 2008-04-19 14:30:00
# 2 2008-09-21 14:30:00
# 3 2008-06-05 19:00:00
# 4 2008-10-10 19:30:00

# %%
# Get the top five sellers who made the most commission. Alias their total commission made as 'total_com'.
# Also get their average commission made and alias as 'avg_com'. Be sure to also display the seller_id
sq3 = """ SELECT seller_id,
       SUM(commission) AS total_com,
       AVG(commission) AS avg_com
       FROM sales
       GROUP BY seller_id
       ORDER BY total_com DESC
       LIMIT 5;"""
run_query(sq3)
# Out:
# (['seller_id', 'total_com', 'avg_com'],
#  [(1140, 4859.85, 347.13214285714287),
#   (43551, 4704.75, 470.475),
#   (13385, 4274.25, 388.5681818181818),
#   (25433, 4147.95, 518.49375),
#   (2372, 4073.85, 678.975)])

# %%
### HAVING application
# Using the same query as the last groupby, instead of getting the top five sellers get all sellers who have made a total commission greater than $4000
sq4 = """ SELECT seller_id,
          SUM(commission) AS total_com,
          AVG(commission) AS avg_com
          FROM sales
          GROUP BY seller_id
          HAVING SUM(commission) > 4000
          ORDER BY total_com DESC;"""
run_query(sq4)
# Out:
# (['seller_id', 'total_com', 'avg_com'],
#  [(1140, 4859.85, 347.13214285714287),
#   (43551, 4704.75, 470.475),
#   (13385, 4274.25, 388.5681818181818),
#   (25433, 4147.95, 518.49375),
#   (2372, 4073.85, 678.975)])

# %%
# Using the same query as the first groupby, instead of returning the top five venues, return just the ID's of venues that have had greater than 60 events
sq5 = """ SELECT venue_id
          FROM event
          GROUP BY venue_id
          HAVING COUNT(*) > 60
          LIMIT 5;"""
run_query(sq5)
## Q4 Your function ends here - Any code outside of these start/end markers won't be graded
# Out:
# (['venue_id'], [(237,), (238,), (239,), (226,), (209,)])

# %% [markdown]
# ## Q5 JOIN - 5 points
#
# Time for some joins. You've probably noticed by now that there is at least one relational key in each table, but some have more.  For example, sales has a unique sale id, listing id, seller id, buyer id, date id.  This allows you to link each sale to relevant information in other tables.
# **LIMIT each output to 5**
#
# Please write queries to do the following items:
#
# * Join information of users to each sale made.
# * Join information about each venue to each event.

# %%
## Q5 Your function starts here
sq1 = """ SELECT * FROM sales
          LIMIT 5;"""
run_query(sq1)
# Out:
# (['sales_id',
#   'list_id',
#   'seller_id',
#   'buyer_id',
#   'event_id',
#   'date_id',
#   'qty_sold',
#   'price_paid',
#   'commission',
#   'sale_time'],
#  [(2, 4, 8117, 11498, 4337, 1983, 2, 76, 11.4, '6/6/2008 05:00:16'),
#   (3, 5, 1616, 17433, 8647, 1983, 2, 350, 52.5, '6/6/2008 08:26:17'),
#   (4, 5, 1616, 19715, 8647, 1986, 1, 175, 26.25, '6/9/2008 08:38:52'),
#   (5, 6, 47402, 14115, 8240, 2069, 2, 154, 23.1, '8/31/2008 09:17:02'),
#   (6, 10, 24858, 24888, 3375, 2023, 2, 394, 59.1, '7/16/2008 11:59:24')])

# %%
sq2 = """ SELECT * FROM users
          LIMIT 5;"""
run_query(sq2)
# Out:
# (['user_id',
#   'user_name',
#   'first_name',
#   'last_name',
#   'city',
#   'state',
#   'email',
#   'phone',
#   'like_sports',
#   'like_theatre',
#   'like_concerts',
#   'like_jazz',
#   'like_classical',
#   'like_opera',
#   'like_rock',
#   'like_vegas',
#   'like_broadway',
#   'like_musicals'],
#  [(2,
#    'PGL08LJI',
#    'Vladimir',
#    'Humphrey',
#    'Murfreesboro',
#    'SK',
#    'Suspendisse.tristique@nonnisiAenean.edu',
#    '(783) 492-1886',
#    None,
#    None,
#    None,
#    'True',
#    'True',
#    None,
#    None,
#    'True',
#    'False',
#    'True'),
#   (3,
#    'IFT66TXU',
#    'Lars',
#    'Ratliff',
#    'High Point',
#    'ME',
#    'amet.faucibus.ut@condimentumegetvolutpat.ca',
#    '(624) 767-2465',
#    'True',
#    'False',
#    None,
#    'False',
#    None,
#    'False',
#    'True',
#    None,
#    None,
#    'True'),
#   (4,
#    'XDZ38RDD',
#    'Barry',
#    'Roy',
#    'Omaha',
#    'AB',
#    'sed@lacusUtnec.ca',
#    '(355) 452-8168',
#    'False',
#    'True',
#    None,
#    'False',
#    None,
#    None,
#    None,
#    None,
#    None,
#    'False'),
#   (5,
#    'AEB55QTM',
#    'Reagan',
#    'Hodge',
#    'Forest Lake',
#    'NS',
#    'Cum@accumsan.com',
#    '(476) 519-9131',
#    None,
#    None,
#    'True',
#    'False',
#    None,
#    None,
#    'True',
#    'True',
#    'False',
#    'True'),
#   (6,
#    'NDQ15VBM',
#    'Victor',
#    'Hernandez',
#    'Naperville',
#    'GA',
#    'turpis@accumsanlaoreet.org',
#    '(818) 765-4255',
#    'False',
#    None,
#    None,
#    'True',
#    None,
#    'True',
#    'True',
#    'True',
#    'True',
#    'True')])

# %%
get_column_names(table_name='users')
# Out:
# [('user_id',),
#  ('user_name',),
#  ('first_name',),
#  ('last_name',),
#  ('city',),
#  ('state',),
#  ('email',),
#  ('phone',),
#  ('like_sports',),
#  ('like_theatre',),
#  ('like_concerts',),
#  ('like_jazz',),
#  ('like_classical',),
#  ('like_opera',),
#  ('like_rock',),
#  ('like_vegas',),
#  ('like_broadway',),
#  ('like_musicals',)]

# %%
get_column_names(table_name='sales')
# Out:
# [('sales_id',),
#  ('list_id',),
#  ('seller_id',),
#  ('buyer_id',),
#  ('event_id',),
#  ('date_id',),
#  ('qty_sold',),
#  ('price_paid',),
#  ('commission',),
#  ('sale_time',)]

# %%
# Join users information to each sale
sq3 = """ SELECT *
          FROM sales
          JOIN users
          ON sales.buyer_id = users.user_id
          LIMIT 5;"""
run_query(sq3)
# Out:
# (['sales_id',
#   'list_id',
#   'seller_id',
#   'buyer_id',
#   'event_id',
#   'date_id',
#   'qty_sold',
#   'price_paid',
#   'commission',
#   'sale_time',
#   'user_id',
#   'user_name',
#   'first_name',
#   'last_name',
#   'city',
#   'state',
#   'email',
#   'phone',
#   'like_sports',
#   'like_theatre',
#   'like_concerts',
#   'like_jazz',
#   'like_classical',
#   'like_opera',
#   'like_rock',
#   'like_vegas',
#   'like_broadway',
#   'like_musicals'],
#  [(4,
#    5,
#    1616,
#    19715,
#    8647,
#    1986,
#    1,
#    175,
#    26.25,
#    '6/9/2008 08:38:52',
#    19715,
#    'PZY80KEH',
#    'Alexander',
#    'Spencer',
#    'Jordan Valley',
#    'ID',
#    'amet@est.edu',
#    '(963) 349-0806',
#    'False',
#    'False',
#    None,
#    'False',
#    None,
#    None,
#    None,
#    None,
#    'False',
#    None),
#   (5,
#    6,
#    47402,
#    14115,
#    8240,
#    2069,
#    2,
#    154,
#    23.1,
#    '8/31/2008 09:17:02',
#    14115,
#    'XPD71EYG',
#    'Pamela',
#    'Foster',
#    'Wheeling',
#    'VA',
#    'sociis.natoque.penatibus@magnisdis.org',
#    '(370) 761-6313',
#    'False',
#    'False',
#    None,
#    'True',
#    'False',
#    None,
#    None,
#    'False',
#    'False',
#    None),
#   (6,
#    10,
#    24858,
#    24888,
#    3375,
#    2023,
#    2,
#    394,
#    59.1,
#    '7/16/2008 11:59:24',
#    24888,
#    'QDE27MBM',
#    'Simon',
#    'Battle',
#    'Lockport',
#    'NH',
#    'fermentum.arcu@sitametante.org',
#    '(512) 901-0259',
#    None,
#    None,
#    'True',
#    'True',
#    None,
#    'True',
#    None,
#    None,
#    'False',
#    'False'),
#   (8,
#    10,
#    24858,
#    19715,
#    3375,
#    2017,
#    1,
#    197,
#    29.55,
#    '7/10/2008 02:12:36',
#    19715,
#    'PZY80KEH',
#    'Alexander',
#    'Spencer',
#    'Jordan Valley',
#    'ID',
#    'amet@est.edu',
#    '(963) 349-0806',
#    'False',
#    'False',
#    None,
#    'False',
#    None,
#    None,
#    None,
#    None,
#    'False',
#    None),
#   (9,
#    10,
#    24858,
#    29891,
#    3375,
#    2029,
#    3,
#    591,
#    88.65,
#    '7/22/2008 02:23:17',
#    29891,
#    'YVR43ZZK',
#    'Stone',
#    'Wiggins',
#    'Sierra Vista',
#    'OK',
#    'vitae.risus.Duis@nonantebibendum.ca',
#    '(225) 417-7016',
#    None,
#    None,
#    None,
#    'False',
#    None,
#    'False',
#    'True',
#    None,
#    None,
#    None)])

# %%
# For each event attach the venue information
sq4 = """ SELECT *
          FROM event
          JOIN venue
          ON event.venue_id = venue.venue_id
          LIMIT 5;"""
run_query(sq4)
## Q5 Your function ends here - Any code outside of these start/end markers won't be graded
# Out:
# (['event_id',
#   'venue_id',
#   'cat_id',
#   'date_id',
#   'event_name',
#   'start_time',
#   'venue_id',
#   'venue_name',
#   'venue_city',
#   'venue_state',
#   'venue_seats'],
#  [(2,
#    306,
#    8,
#    2114,
#    'Boris Godunov',
#    datetime.datetime(2008, 10, 15, 20, 0),
#    306,
#    'Lyric Opera House',
#    'Baltimore',
#    'MD',
#    0),
#   (3,
#    302,
#    8,
#    1935,
#    'Salome',
#    datetime.datetime(2008, 4, 19, 14, 30),
#    302,
#    'Detroit Opera House',
#    'Detroit',
#    'MI',
#    0),
#   (4,
#    309,
#    8,
#    2090,
#    'La Cenerentola (Cinderella)',
#    datetime.datetime(2008, 9, 21, 14, 30),
#    309,
#    'Los Angeles Opera',
#    'Los Angeles',
#    'CA',
#    0),
#   (5,
#    302,
#    8,
#    1982,
#    'Il Trovatore',
#    datetime.datetime(2008, 6, 5, 19, 0),
#    302,
#    'Detroit Opera House',
#    'Detroit',
#    'MI',
#    0),
#   (6,
#    308,
#    8,
#    2109,
#    'L Elisir d Amore',
#    datetime.datetime(2008, 10, 10, 19, 30),
#    308,
#    'Metropolitan Opera',
#    'New York City',
#    'NY',
#    0)])

# %% [markdown]
# ## Q 6 Subqueries - 5 points
#
# To wrap up let's do several subqueries. Please do the following:
#
# * Get all purchases made by users of live in Arizona
# * Get event information for all events that took place in a venue where the venue name ends with 'Stadium'.
# * Get event information for all events where the total ticket sales were greater than $50,000.

# %%
## Q6 Your function starts here
# Get all purchases from users who live in Arizona
sq1 = """ SELECT *
          FROM sales
          WHERE buyer_id IN (SELECT user_id
          FROM users
          WHERE state = 'AZ');"""
run_query(sq1)
# Out:
# (['sales_id',
#   'list_id',
#   'seller_id',
#   'buyer_id',
#   'event_id',
#   'date_id',
#   'qty_sold',
#   'price_paid',
#   'commission',
#   'sale_time'],
#  [(43, 47, 49346, 33489, 8577, 2141, 2, 378, 56.7, '11/11/2008 09:51:06'),
#   (79, 101, 37592, 7079, 3340, 1878, 1, 36, 5.4, '2/21/2008 10:32:10'),
#   (81, 103, 26314, 7079, 15, 2033, 1, 181, 27.15, '7/26/2008 11:04:13'),
#   (83, 106, 12538, 7079, 250, 1884, 1, 109, 16.35, '2/27/2008 11:58:35'),
#   (154, 162, 27703, 46451, 2906, 1907, 3, 426, 63.9, '3/22/2008 05:21:40'),
#   (173, 176, 3941, 10086, 3097, 2155, 2, 40, 6.0, '11/25/2008 09:20:09'),
#   (218, 231, 21568, 41178, 1077, 2140, 2, 458, 68.7, '11/10/2008 04:12:53'),
#   (260, 267, 23965, 7079, 4288, 2135, 2, 270, 40.5, '11/5/2008 11:27:05'),
#   (327, 321, 44084, 41178, 1237, 1893, 2, 396, 59.4, '3/8/2008 10:10:23'),
#   (368, 361, 36225, 7079, 7857, 2139, 2, 396, 59.4, '11/9/2008 03:12:00'),
#   (591, 597, 4168, 3181, 8131, 2039, 4, 844, 126.6, '8/1/2008 05:38:55'),
#   (717, 743, 6621, 24584, 2233, 1965, 4, 300, 45.0, '5/19/2008 06:42:34'),
#   (767, 782, 24749, 21507, 2120, 1930, 2, 110, 16.5, '4/14/2008 11:32:51'),
#   (860, 872, 15798, 40597, 2249, 1997, 4, 372, 55.8, '6/20/2008 08:57:51'),
#   (989, 999, 8141, 3181, 7284, 2097, 4, 772, 115.8, '9/28/2008 07:48:18'),
#   (1176, 1221, 233, 1285, 7973, 1860, 2, 320, 48.0, '2/3/2008 11:09:38'),
#   (1306, 1380, 7634, 27494, 7982, 2057, 4, 564, 84.6, '8/19/2008 09:04:04'),
#   (1572, 1678, 32145, 7079, 6646, 2086, 2, 414, 62.1, '9/17/2008 04:57:57'),
#   (1951, 2097, 33908, 24449, 8536, 1909, 2, 434, 65.1, '3/24/2008 03:05:31'),
#   (2053, 2198, 17797, 3181, 610, 2156, 4, 728, 109.2, '11/26/2008 08:31:54'),
#   (2066, 2217, 42102, 1285, 8234, 1898, 2, 464, 69.6, '3/13/2008 09:40:34'),
#   (2101, 2246, 48938, 39155, 1788, 2128, 1, 115, 17.25, '10/29/2008 12:05:45'),
#   (2283, 2457, 46008, 26052, 1241, 2110, 3, 606, 90.9, '10/11/2008 09:31:50'),
#   (2319, 2489, 31876, 1285, 2016, 1945, 2, 354, 53.1, '4/29/2008 11:26:23'),
#   (2454, 2627, 38477, 1285, 4556, 1840, 2, 192, 28.8, '1/14/2008 06:54:01'),
#   (2507, 2680, 37228, 33935, 2074, 1989, 3, 423, 63.45, '6/12/2008 10:06:55'),
#   (2515, 2687, 29895, 27494, 722, 1881, 4, 776, 116.4, '2/24/2008 10:22:19'),
#   (2550, 2736, 5999, 10086, 6778, 2149, 2, 60, 9.0, '11/19/2008 11:53:38'),
#   (2611, 2798, 25075, 12900, 3514, 1989, 4, 508, 76.2, '6/12/2008 02:11:32'),
#   (2722, 2930, 36164, 21507, 8124, 1953, 2, 174, 26.1, '5/7/2008 07:31:46'),
#   (2808, 3003, 47329, 39155, 222, 1973, 1, 226, 33.9, '5/27/2008 12:11:31'),
#   (2849, 3045, 9358, 21507, 1488, 1883, 2, 128, 19.2, '2/26/2008 01:58:10'),
#   (2867, 3064, 37318, 10086, 2952, 1937, 2, 296, 44.4, '4/21/2008 03:08:59'),
#   (2970, 3166, 7451, 2921, 1560, 2088, 2, 68, 10.2, '9/19/2008 07:48:21'),
#   (3058, 3276, 1599, 43099, 6700, 2075, 2, 334, 50.1, '9/6/2008 12:04:37'),
#   (3094, 3314, 36103, 20334, 2948, 1904, 1, 25, 3.75, '3/19/2008 02:12:27'),
#   (3151, 3377, 18670, 20334, 3875, 1914, 1, 250, 37.5, '3/29/2008 04:43:27'),
#   (3174, 3406, 38736, 24584, 161, 2007, 4, 944, 141.6, '6/30/2008 05:37:39'),
#   (3238, 3484, 47920, 21784, 4098, 2072, 4, 204, 30.6, '9/3/2008 08:06:35'),
#   (3288, 3555, 27182, 22897, 1165, 1911, 1, 35, 5.25, '3/26/2008 10:19:25'),
#   (3514, 3785, 33751, 2508, 3882, 2050, 1, 75, 11.25, '8/12/2008 07:32:39'),
#   (3531, 3810, 36154, 2508, 3215, 2150, 1, 244, 36.6, '11/20/2008 08:27:30'),
#   (3682, 3982, 30455, 24584, 859, 2107, 4, 356, 53.4, '10/8/2008 02:34:06'),
#   (3708, 4009, 24486, 813, 1361, 2066, 2, 190, 28.5, '8/28/2008 03:48:36'),
#   (3864, 4166, 13860, 34913, 1019, 2179, 2, 220, 33.0, '12/19/2008 10:02:22'),
#   (3911, 4207, 10339, 2508, 156, 2026, 1, 143, 21.45, '7/19/2008 11:35:19'),
#   (4066, 4362, 24791, 21131, 4182, 2016, 4, 532, 79.8, '7/9/2008 05:26:09'),
#   (4122, 4431, 44033, 2921, 7355, 2115, 2, 224, 33.6, '10/16/2008 08:10:02'),
#   (4163, 4473, 27726, 2921, 283, 2070, 2, 228, 34.2, '9/1/2008 09:52:04'),
#   (4229, 4558, 48741, 813, 1908, 2065, 2, 204, 30.6, '8/27/2008 12:41:06'),
#   (4308, 4651, 5851, 813, 1273, 1919, 2, 428, 64.2, '4/3/2008 03:51:11'),
#   (4310, 4657, 20890, 2508, 4186, 2022, 1, 146, 21.9, '7/15/2008 03:52:35'),
#   (4330, 4673, 43204, 813, 5199, 2031, 2, 164, 24.6, '7/24/2008 04:45:32'),
#   (4469, 4809, 36237, 22897, 8634, 1900, 1, 80, 12.0, '3/15/2008 09:48:09'),
#   (4498, 4840, 37129, 2054, 6040, 2119, 2, 426, 63.9, '10/20/2008 10:42:56'),
#   (4657, 5013, 24019, 24381, 7243, 2095, 1, 106, 15.9, '9/26/2008 04:32:43'),
#   (4753, 5116, 42257, 12347, 4843, 2032, 1, 171, 25.65, '7/25/2008 08:06:01'),
#   (4804, 5174, 19494, 37112, 5587, 2128, 2, 112, 16.8, '10/29/2008 09:49:15'),
#   (4806, 5174, 19494, 12347, 5587, 2098, 1, 56, 8.4, '9/29/2008 09:56:05'),
#   (4853, 5215, 33446, 29529, 1562, 1991, 4, 104, 15.6, '6/14/2008 11:40:09'),
#   (4873, 5239, 18550, 22897, 3199, 2067, 1, 188, 28.2, '8/29/2008 12:20:53'),
#   (5000, 5354, 31179, 2921, 3556, 2027, 2, 52, 7.8, '7/20/2008 05:04:42'),
#   (5097, 5480, 34701, 12347, 7866, 2068, 1, 30, 4.5, '8/30/2008 08:20:37'),
#   (5161, 5542, 7981, 22441, 2170, 2177, 2, 374, 56.1, '12/17/2008 10:19:59'),
#   (5225, 5624, 34224, 14366, 2019, 1967, 2, 332, 49.8, '5/21/2008 12:38:01'),
#   (5478, 5916, 38181, 12822, 5088, 2029, 1, 105, 15.75, '7/22/2008 09:35:44'),
#   (5483, 5919, 20473, 12900, 7996, 2111, 4, 424, 63.6, '10/12/2008 09:40:22'),
#   (5497, 5941, 26792, 9215, 3612, 2151, 2, 130, 19.5, '11/21/2008 10:06:33'),
#   (5823, 6322, 26748, 27305, 4190, 1972, 1, 107, 16.05, '5/26/2008 09:01:34'),
#   (5824, 6324, 44927, 27305, 4926, 1948, 1, 51, 7.65, '5/2/2008 09:01:42'),
#   (5885, 6384, 36684, 12900, 3609, 2128, 4, 216, 32.4, '10/29/2008 11:42:06'),
#   (5886, 6385, 20911, 27305, 8429, 1870, 1, 130, 19.5, '2/13/2008 11:43:34'),
#   (5989, 6511, 48832, 2054, 8309, 1993, 2, 338, 50.7, '6/16/2008 02:42:26'),
#   (6075, 6599, 15093, 429, 553, 1982, 1, 30, 4.5, '6/5/2008 05:34:54'),
#   (6112, 6637, 3308, 429, 3485, 2064, 1, 60, 9.0, '8/26/2008 06:54:21'),
#   (6113, 6638, 1099, 22441, 296, 2053, 2, 210, 31.5, '8/15/2008 06:55:41'),
#   (6210, 6745, 22095, 2054, 8230, 2138, 2, 240, 36.0, '11/8/2008 10:17:57'),
#   (6494, 7063, 43265, 429, 2855, 1949, 1, 70, 10.5, '5/3/2008 07:52:21'),
#   (6507, 7077, 24714, 429, 3740, 2001, 1, 188, 28.2, '6/24/2008 08:13:45'),
#   (6740, 7338, 42617, 30326, 4907, 2044, 2, 236, 35.4, '8/6/2008 04:39:35'),
#   (6813, 7398, 41223, 24399, 2910, 2048, 4, 584, 87.6, '8/10/2008 07:03:53'),
#   (6834, 7419, 5914, 21131, 7133, 2156, 4, 636, 95.4, '11/26/2008 07:41:01'),
#   (6864, 7439, 25416, 38238, 3817, 1992, 1, 89, 13.35, '6/15/2008 08:41:45'),
#   (7010, 7610, 39860, 30326, 8630, 2094, 2, 184, 27.6, '9/25/2008 01:51:43'),
#   (7138, 7737, 46375, 25273, 3611, 2093, 2, 274, 41.1, '9/24/2008 05:20:51'),
#   (7149, 7741, 33190, 29055, 6629, 2032, 3, 696, 104.4, '7/25/2008 05:36:19'),
#   (7288, 7884, 25673, 21131, 832, 1932, 4, 384, 57.6, '4/16/2008 10:03:52'),
#   (7354, 7955, 668, 17376, 3682, 2026, 2, 200, 30.0, '7/19/2008 12:02:21'),
#   (7552, 8188, 21588, 38445, 6121, 2150, 1, 77, 11.55, '11/20/2008 06:09:59'),
#   (7566, 8196, 46659, 12822, 3279, 1893, 1, 71, 10.65, '3/8/2008 06:39:05'),
#   (7591, 8219, 42044, 12347, 6990, 2055, 1, 213, 31.95, '8/17/2008 07:28:58'),
#   (7626, 8252, 18736, 8381, 2717, 1949, 1, 245, 36.75, '5/3/2008 08:28:14'),
#   (7752, 8361, 14286, 25273, 4570, 1975, 2, 330, 49.5, '5/29/2008 11:36:55'),
#   (7817, 8437, 8336, 2054, 8146, 2095, 2, 186, 27.9, '9/26/2008 02:00:02'),
#   (7989, 8598, 40442, 12822, 7674, 2097, 1, 179, 26.85, '9/28/2008 07:38:21'),
#   (7994, 8604, 41814, 12822, 6992, 1965, 1, 218, 32.7, '5/19/2008 07:41:45'),
#   (8063, 8675, 41226, 19909, 3790, 2007, 2, 374, 56.1, '6/30/2008 09:53:17'),
#   (8088, 8696, 534, 33418, 2083, 2039, 4, 724, 108.6, '8/1/2008 10:37:36'),
#   (8169, 8777, 36730, 8381, 546, 2062, 1, 153, 22.95, '8/24/2008 12:52:00'),
#   (8338, 8960, 13115, 21131, 5778, 2131, 4, 168, 25.2, '11/1/2008 05:38:50'),
#   (8408, 9030, 43919, 26024, 2251, 1943, 2, 268, 40.2, '4/27/2008 07:13:48'),
#   (8507, 9151, 9867, 29494, 7866, 2092, 1, 109, 16.35, '9/23/2008 10:07:01'),
#   (8522, 9172, 9271, 19909, 2930, 2179, 2, 210, 31.5, '12/19/2008 10:27:34'),
#   (8726, 9412, 41000, 25273, 6738, 1941, 2, 362, 54.3, '4/25/2008 04:28:51'),
#   (8738, 9418, 42721, 8381, 8707, 2143, 1, 115, 17.25, '11/13/2008 04:55:29'),
#   (8789, 9475, 30243, 24399, 7075, 2119, 4, 96, 14.4, '10/20/2008 06:13:23'),
#   (8809, 9491, 29804, 2379, 5940, 1981, 1, 111, 16.65, '6/4/2008 06:32:10'),
#   (9177, 9933, 32587, 34959, 7639, 2083, 1, 164, 24.6, '9/14/2008 04:17:19'),
#   (9223, 9983, 34378, 38399, 5796, 1901, 4, 152, 22.8, '3/16/2008 05:29:24'),
#   (9266, 10041, 45370, 38399, 3626, 1943, 4, 904, 135.6, '4/27/2008 06:13:51'),
#   (9310, 10079, 8974, 9378, 7869, 1912, 3, 366, 54.9, '3/27/2008 07:28:31'),
#   (9369, 10153, 47280, 25273, 1892, 2117, 2, 406, 60.9, '10/18/2008 09:02:14'),
#   (9683, 10490, 8969, 2649, 4673, 2084, 1, 89, 13.35, '9/15/2008 05:34:34'),
#   (9754, 10584, 5246, 29494, 6909, 2131, 1, 205, 30.75, '11/1/2008 07:06:27'),
#   (9784, 10614, 28558, 10513, 6694, 2099, 3, 684, 102.6, '9/30/2008 07:54:07'),
#   (9908, 10777, 14991, 19909, 6688, 1966, 2, 66, 9.9, '5/20/2008 10:40:40'),
#   (10011, 10898, 28059, 2649, 4870, 2125, 1, 48, 7.2, '10/26/2008 12:46:58'),
#   (10024, 10912, 13520, 2649, 2225, 2036, 1, 29, 4.35, '7/29/2008 01:04:57'),
#   (10096, 10998, 43046, 19163, 6752, 1858, 2, 434, 65.1, '2/1/2008 02:47:35'),
#   (10128, 11044, 26553, 26024, 186, 2042, 2, 118, 17.7, '8/4/2008 03:39:39'),
#   (10139, 11052, 14114, 24399, 3913, 1958, 4, 136, 20.4, '5/12/2008 03:55:32'),
#   (10213, 11135, 38644, 2649, 439, 2080, 1, 161, 24.15, '9/11/2008 05:46:53'),
#   (10253, 11175, 17299, 19163, 2338, 1932, 2, 348, 52.2, '4/16/2008 06:54:33'),
#   (10269, 11194, 14096, 5729, 7356, 1933, 1, 88, 13.2, '4/17/2008 07:14:37'),
#   (10585, 11509, 16, 22326, 6304, 2026, 1, 42, 6.3, '7/19/2008 03:38:54'),
#   (10772, 11702, 26448, 2379, 1621, 1864, 1, 124, 18.6, '2/7/2008 08:21:33'),
#   (10892, 11813, 9220, 26024, 6052, 1885, 2, 486, 72.9, '2/28/2008 11:54:48'),
#   (10898, 11817, 22342, 5729, 2718, 1939, 1, 198, 29.7, '4/23/2008 12:04:59'),
#   (11006,
#    11935,
#    11414,
#    22326,
#    3228,
#    1876,
#    1,
#    175,
#    26.25,
#    '2/19/2008 03:09:55'),
#   (11067, 12006, 35506, 5729, 7254, 2074, 1, 85, 12.75, '9/5/2008 04:36:17'),
#   (11094, 12039, 7041, 2379, 724, 2071, 1, 61, 9.15, '9/2/2008 05:19:02'),
#   (11240, 12181, 42032, 20202, 2177, 1892, 1, 123, 18.45, '3/7/2008 08:58:22'),
#   (11286,
#    12226,
#    41655,
#    20202,
#    5812,
#    1883,
#    1,
#    147,
#    22.05,
#    '2/26/2008 10:11:16'),
#   (11288, 12230, 18017, 3563, 988, 2063, 2, 400, 60.0, '8/25/2008 10:16:21'),
#   (11464, 12412, 2563, 5729, 3197, 2011, 1, 125, 18.75, '7/4/2008 02:28:29'),
#   (11499, 12449, 20572, 2379, 7192, 2157, 1, 35, 5.25, '11/27/2008 03:22:07'),
#   (11523,
#    12462,
#    36512,
#    26024,
#    7684,
#    2119,
#    2,
#    190,
#    28.5,
#    '10/20/2008 03:52:46'),
#   (11673, 12613, 13035, 10159, 7369, 2076, 2, 126, 18.9, '9/7/2008 07:20:36'),
#   (11689, 12627, 35733, 10297, 7432, 2036, 1, 77, 11.55, '7/29/2008 07:52:36'),
#   (11725, 12673, 4538, 19040, 4014, 1966, 2, 60, 9.0, '5/20/2008 08:38:48'),
#   (11730,
#    12675,
#    29102,
#    11170,
#    4517,
#    2110,
#    1,
#    77,
#    11.55,
#    '10/11/2008 08:46:40'),
#   (11734, 12682, 27774, 9327, 2168, 2115, 2, 196, 29.4, '10/16/2008 08:52:29'),
#   (11737, 12687, 5395, 3563, 4925, 1935, 2, 116, 17.4, '4/19/2008 08:56:51'),
#   (11896, 12868, 46878, 9327, 7537, 1865, 2, 76, 11.4, '2/8/2008 12:54:23'),
#   (12186,
#    13173,
#    28463,
#    36719,
#    3803,
#    2177,
#    1,
#    237,
#    35.55,
#    '12/17/2008 07:19:43'),
#   (12598, 13610, 48284, 33418, 257, 2028, 4, 488, 73.2, '7/21/2008 04:58:35'),
#   (12620, 13632, 9747, 20202, 656, 1908, 1, 86, 12.9, '3/23/2008 05:26:22'),
#   (12729, 13738, 42945, 35271, 1266, 2067, 2, 418, 62.7, '8/29/2008 07:57:47'),
#   (12749, 13752, 27506, 9327, 1394, 2019, 2, 438, 65.7, '7/12/2008 08:19:44'),
#   (12793, 13789, 8205, 3563, 1016, 2035, 2, 316, 47.4, '7/28/2008 09:20:56'),
#   (12864, 13854, 45726, 10297, 1223, 2061, 1, 64, 9.6, '8/23/2008 10:35:19'),
#   (12889,
#    13881,
#    35566,
#    10297,
#    4591,
#    2063,
#    1,
#    235,
#    35.25,
#    '8/25/2008 11:13:36'),
#   (12895, 13884, 31382, 29055, 667, 2020, 3, 456, 68.4, '7/13/2008 11:20:50'),
#   (12919, 13910, 7099, 11170, 3637, 2041, 1, 28, 4.2, '8/3/2008 11:57:44'),
#   (12944,
#    13937,
#    38307,
#    11170,
#    3076,
#    2027,
#    1,
#    189,
#    28.35,
#    '7/20/2008 12:38:33'),
#   (13182, 14242, 22003, 11170, 3247, 1924, 1, 108, 16.2, '4/8/2008 05:55:32'),
#   (13189, 14247, 11591, 35271, 2569, 2015, 2, 324, 48.6, '7/8/2008 06:00:54'),
#   (13259, 14316, 19438, 10159, 3843, 1975, 2, 350, 52.5, '5/29/2008 07:47:14'),
#   (13284, 14345, 48559, 44817, 2411, 2105, 2, 442, 66.3, '10/6/2008 08:28:14'),
#   (13295, 14358, 46743, 3563, 194, 2124, 2, 130, 19.5, '10/25/2008 08:44:55'),
#   (13306, 14374, 43883, 37202, 454, 1994, 1, 217, 32.55, '6/17/2008 08:59:07'),
#   (13457, 14563, 41718, 19014, 8011, 1932, 2, 44, 6.6, '4/16/2008 12:13:35'),
#   (13508, 14621, 33136, 9378, 7375, 1838, 3, 594, 89.1, '1/12/2008 01:30:49'),
#   (13524, 14656, 33851, 26702, 7241, 1903, 2, 208, 31.2, '3/18/2008 01:56:44'),
#   (13553, 14685, 42862, 19014, 8631, 2042, 2, 124, 18.6, '8/4/2008 02:38:47'),
#   (13569, 14706, 34636, 10159, 2232, 1926, 2, 468, 70.2, '4/10/2008 02:56:07'),
#   (13591,
#    14727,
#    35703,
#    29055,
#    2951,
#    2155,
#    3,
#    633,
#    94.95,
#    '11/25/2008 03:22:35'),
#   (13644, 14772, 40737, 3183, 8044, 2005, 3, 522, 78.3, '6/28/2008 04:33:17'),
#   (13672, 14807, 18802, 36719, 8491, 2070, 1, 105, 15.75, '9/1/2008 05:06:01'),
#   (13874, 15025, 10508, 9327, 3146, 2011, 1, 147, 22.05, '7/4/2008 09:08:18'),
#   (13895, 15053, 15235, 39343, 7696, 2077, 2, 82, 12.3, '9/8/2008 09:34:26'),
#   (14078, 15223, 40296, 10159, 8135, 1987, 2, 194, 29.1, '6/10/2008 01:25:57'),
#   (14187, 15329, 48906, 9378, 5630, 2156, 3, 234, 35.1, '11/26/2008 03:47:42'),
#   (14224, 15377, 14013, 38238, 3573, 2037, 1, 106, 15.9, '7/30/2008 04:46:59'),
#   (14340,
#    15512,
#    27557,
#    41229,
#    6725,
#    2144,
#    4,
#    868,
#    130.2,
#    '11/14/2008 07:31:08'),
#   (14423,
#    15593,
#    21535,
#    10159,
#    8590,
#    1991,
#    4,
#    688,
#    103.2,
#    '6/14/2008 09:23:10'),
#   (14452, 15625, 35988, 30339, 6914, 2023, 2, 316, 47.4, '7/16/2008 10:03:25'),
#   (14550, 15724, 30882, 33418, 1043, 2072, 4, 680, 102.0, '9/3/2008 12:22:54'),
#   (14561, 15737, 27759, 3343, 2275, 2096, 2, 404, 60.6, '9/27/2008 12:39:28'),
#   (14629, 15815, 2743, 3343, 8675, 1885, 2, 370, 55.5, '2/28/2008 01:56:04'),
#   (14712, 15907, 2261, 38238, 1234, 2146, 1, 186, 27.9, '11/16/2008 03:39:52'),
#   (14731,
#    15930,
#    46716,
#    33418,
#    5058,
#    2150,
#    4,
#    204,
#    30.6,
#    '11/20/2008 04:02:52'),
#   (14834, 16056, 5226, 29015, 642, 2045, 1, 177, 26.55, '8/7/2008 06:33:51'),
#   (14852, 16070, 40574, 9378, 3851, 2132, 3, 570, 85.5, '11/2/2008 06:47:31'),
#   (14905, 16134, 11924, 19014, 7384, 2104, 2, 158, 23.7, '10/5/2008 07:54:25'),
#   (15023, 16269, 30250, 9327, 2123, 1963, 1, 39, 5.85, '5/17/2008 10:45:11'),
#   (15103, 16345, 31015, 39343, 1288, 2148, 2, 78, 11.7, '11/18/2008 12:15:35'),
#   (15142, 16375, 40881, 9327, 353, 2148, 1, 24, 3.6, '11/18/2008 01:14:57'),
#   (15250, 16510, 23067, 17342, 892, 1895, 2, 66, 9.9, '3/10/2008 03:43:13'),
#   (15375, 16642, 38501, 3343, 2888, 2128, 2, 96, 14.4, '10/29/2008 06:13:45'),
#   (15430, 16695, 10946, 9327, 1582, 2132, 1, 94, 14.1, '11/2/2008 07:34:03'),
#   (15463, 16729, 14856, 10159, 691, 1853, 4, 768, 115.2, '1/27/2008 08:06:19'),
#   (15493, 16767, 24377, 17342, 2700, 2010, 2, 416, 62.4, '7/3/2008 08:50:17'),
#   (15645, 16931, 44641, 10159, 7702, 1993, 4, 168, 25.2, '6/16/2008 11:46:38'),
#   (15679, 16967, 39548, 10513, 927, 1971, 3, 312, 46.8, '5/25/2008 12:34:44'),
#   (15750,
#    17028,
#    29403,
#    29015,
#    8335,
#    1974,
#    1,
#    127,
#    19.05,
#    '5/28/2008 01:53:56'),
#   (15778, 17056, 36073, 20507, 6147, 1930, 1, 232, 34.8, '4/14/2008 02:35:58'),
#   (15841, 17111, 48749, 3343, 1923, 1842, 2, 126, 18.9, '1/16/2008 03:45:26'),
#   (15877, 17159, 24809, 38238, 7346, 1907, 1, 78, 11.7, '3/22/2008 04:37:25'),
#   (16308, 17642, 5838, 22232, 8741, 1970, 4, 964, 144.6, '5/24/2008 02:01:11'),
#   (16331, 17676, 47292, 33938, 563, 1874, 4, 156, 23.4, '2/17/2008 02:26:04'),
#   (16470, 17815, 12022, 26567, 8712, 2019, 2, 302, 45.3, '7/12/2008 05:09:48'),
#   (16648, 17993, 48305, 551, 6252, 1999, 1, 239, 35.85, '6/22/2008 08:48:42'),
#   (17079, 18474, 20421, 2379, 2946, 1943, 2, 454, 68.1, '4/27/2008 06:06:44'),
#   (17368,
#    18830,
#    29371,
#    41229,
#    7816,
#    2091,
#    4,
#    736,
#    110.4,
#    '9/22/2008 11:51:32'),
#   (17405, 18883, 45808, 2379, 7390, 1984, 2, 134, 20.1, '6/7/2008 12:30:05'),
#   (17407, 18884, 39266, 27208, 3507, 1976, 2, 308, 46.2, '5/30/2008 12:32:56'),
#   (17615, 19121, 33707, 30993, 750, 1870, 3, 738, 110.7, '2/13/2008 03:55:05'),
#   (17649, 19165, 19203, 34627, 4108, 2010, 2, 164, 24.6, '7/3/2008 04:31:31'),
#   (17796, 19311, 14970, 551, 8523, 2076, 1, 66, 9.9, '9/7/2008 07:48:05'),
#   (17871, 19361, 6097, 22232, 87, 2162, 4, 648, 97.2, '12/2/2008 09:15:03'),
#   (18186, 19695, 42704, 551, 8588, 2046, 1, 23, 3.45, '8/8/2008 03:00:09'),
#   (18290,
#    19806,
#    46840,
#    26864,
#    3408,
#    1874,
#    1,
#    149,
#    22.35,
#    '2/17/2008 05:06:25'),
#   (18352, 19869, 42095, 551, 3132, 2047, 1, 154, 23.1, '8/9/2008 06:03:53'),
#   (18424, 19952, 45483, 24038, 3785, 1883, 1, 124, 18.6, '2/26/2008 07:38:29'),
#   (18485, 20045, 38714, 2379, 6039, 1963, 2, 236, 35.4, '5/17/2008 08:52:42'),
#   (18634, 20186, 6232, 6389, 1992, 1984, 4, 200, 30.0, '6/7/2008 11:42:17'),
#   (18674, 20243, 1181, 2379, 7383, 2017, 2, 422, 63.3, '7/10/2008 12:31:19'),
#   (18926, 20503, 3550, 27208, 7241, 1922, 2, 340, 51.0, '4/6/2008 05:33:26'),
#   (19008, 20588, 21330, 34627, 2900, 1934, 2, 310, 46.5, '4/18/2008 06:47:10'),
#   (19012, 20593, 26299, 23015, 6222, 1994, 2, 60, 9.0, '6/17/2008 06:50:04'),
#   (19271,
#    20864,
#    11415,
#    18741,
#    1253,
#    2160,
#    2,
#    304,
#    45.6,
#    '11/30/2008 11:38:10'),
#   (19414, 21014, 23813, 34627, 5978, 2091, 2, 342, 51.3, '9/22/2008 02:33:31'),
#   (19499, 21124, 5761, 38174, 1325, 1997, 2, 474, 71.1, '6/20/2008 04:21:39'),
#   (19507, 21128, 38499, 2583, 7346, 1888, 2, 332, 49.8, '3/3/2008 04:26:38'),
#   (19763, 21395, 29394, 2583, 3919, 1836, 2, 292, 43.8, '1/10/2008 09:05:13'),
#   (19829,
#    21454,
#    27165,
#    33938,
#    8722,
#    2154,
#    4,
#    812,
#    121.8,
#    '11/24/2008 10:22:47'),
#   (19923, 21567, 3100, 551, 5185, 1961, 2, 144, 21.6, '5/15/2008 12:15:42'),
#   (20015,
#    21674,
#    35232,
#    33938,
#    2157,
#    1873,
#    4,
#    700,
#    105.0,
#    '2/16/2008 01:59:12'),
#   (20184,
#    21855,
#    49246,
#    23130,
#    1927,
#    2160,
#    4,
#    536,
#    80.4,
#    '11/30/2008 04:57:54'),
#   (20221, 21896, 43669, 3183, 469, 2068, 3, 441, 66.15, '8/30/2008 05:48:14'),
#   (20460, 22190, 38690, 551, 2349, 1980, 4, 300, 45.0, '6/3/2008 10:04:18'),
#   (20468, 22199, 33879, 6389, 6685, 2069, 4, 864, 129.6, '8/31/2008 10:13:04'),
#   (20469, 22200, 25395, 38238, 4060, 2018, 2, 74, 11.1, '7/11/2008 10:13:10'),
#   (20637, 22420, 3847, 6389, 5004, 2003, 4, 572, 85.8, '6/26/2008 01:19:52'),
#   (20887, 22708, 19429, 26737, 4400, 2168, 2, 234, 35.1, '12/8/2008 05:50:38'),
#   (20924, 22758, 23894, 9902, 5262, 2003, 1, 227, 34.05, '6/26/2008 06:22:32'),
#   (20995, 22831, 37920, 24449, 4084, 2023, 1, 49, 7.35, '7/16/2008 07:42:54'),
#   (21027,
#    22868,
#    36144,
#    13547,
#    8200,
#    2143,
#    4,
#    220,
#    33.0,
#    '11/13/2008 08:23:08'),
#   (21042, 22877, 6645, 551, 3199, 2073, 2, 98, 14.7, '9/4/2008 08:36:31'),
#   (21066, 22905, 28145, 429, 3701, 2044, 1, 24, 3.6, '8/6/2008 09:06:47'),
#   (21098,
#    22966,
#    47806,
#    24449,
#    1920,
#    1901,
#    1,
#    219,
#    32.85,
#    '3/16/2008 09:42:47'),
#   (21161, 23055, 43847, 429, 4363, 2181, 1, 57, 8.55, '12/21/2008 11:05:25'),
#   (21201, 23106, 41469, 551, 643, 1987, 2, 386, 57.9, '6/10/2008 11:50:25'),
#   (21427, 23350, 48733, 38238, 3930, 1913, 2, 76, 11.4, '3/28/2008 04:13:22'),
#   (21511, 23437, 35901, 3183, 972, 2095, 3, 279, 41.85, '9/26/2008 06:11:03'),
#   (21586, 23508, 19111, 38238, 1463, 1950, 2, 236, 35.4, '5/4/2008 07:29:12'),
#   (21598, 23517, 6015, 22897, 3297, 1969, 1, 180, 27.0, '5/23/2008 07:37:24'),
#   (21680,
#    23596,
#    10845,
#    28626,
#    1120,
#    2057,
#    4,
#    696,
#    104.4,
#    '8/19/2008 08:53:49'),
#   (21772, 23684, 17687, 22021, 1372, 1942, 2, 132, 19.8, '4/26/2008 10:31:11'),
#   (21803, 23712, 7218, 6389, 779, 2024, 4, 680, 102.0, '7/17/2008 11:04:57'),
#   (22037, 23938, 39363, 3745, 5221, 2028, 4, 124, 18.6, '7/21/2008 03:45:06'),
#   (22106, 24022, 9402, 18218, 6426, 2116, 1, 204, 30.6, '10/17/2008 05:00:05'),
#   (22124, 24032, 2532, 3183, 5229, 1970, 3, 696, 104.4, '5/24/2008 05:22:10'),
#   (22197, 24089, 47609, 551, 1717, 1929, 2, 54, 8.1, '4/13/2008 06:53:36'),
#   (22233, 24120, 38792, 9902, 3748, 2151, 1, 220, 33.0, '11/21/2008 07:40:44'),
#   (22370, 24261, 11899, 18218, 2953, 2062, 1, 178, 26.7, '8/24/2008 10:11:59'),
#   (22398, 24299, 39291, 9902, 3228, 1841, 1, 179, 26.85, '1/15/2008 10:39:52'),
#   (22435,
#    24334,
#    34067,
#    13547,
#    6728,
#    2146,
#    4,
#    952,
#    142.8,
#    '11/16/2008 11:13:33'),
#   (22499, 24408, 31187, 429, 880, 1868, 1, 195, 29.25, '2/11/2008 12:07:51'),
#   (22510, 24418, 4375, 429, 3032, 2082, 1, 224, 33.6, '9/13/2008 12:16:39'),
#   (22609, 24558, 7872, 23944, 1506, 2128, 1, 24, 3.6, '10/29/2008 01:59:28'),
#   (22616, 24568, 25193, 23944, 792, 1879, 1, 109, 16.35, '2/22/2008 02:10:20'),
#   (22693, 24641, 35486, 551, 2653, 1883, 4, 552, 82.8, '2/26/2008 03:42:23'),
#   (22767,
#    24732,
#    40833,
#    19040,
#    2466,
#    2018,
#    1,
#    179,
#    26.85,
#    '7/11/2008 05:04:18'),
#   (22880, 24877, 49159, 551, 8536, 1868, 4, 712, 106.8, '2/11/2008 07:14:29'),
#   (22942,
#    24958,
#    15506,
#    43111,
#    6872,
#    1969,
#    1,
#    187,
#    28.05,
#    '5/23/2008 08:21:25'),
#   (23194,
#    25268,
#    16085,
#    30993,
#    1084,
#    2004,
#    3,
#    183,
#    27.45,
#    '6/27/2008 01:00:56'),
#   (23195, 25268, 16085, 46083, 1084, 2022, 2, 122, 18.3, '7/15/2008 01:02:51'),
#   (23221,
#    25299,
#    49858,
#    24381,
#    4061,
#    2155,
#    2,
#    228,
#    34.2,
#    '11/25/2008 01:36:39'),
#   (23273, 25383, 48654, 41892, 6643, 1935, 1, 90, 13.5, '4/19/2008 02:40:19'),
#   (23292, 25406, 16587, 11524, 5452, 1907, 2, 476, 71.4, '3/22/2008 02:56:07'),
#   (23429, 25586, 24977, 29455, 1599, 2067, 4, 656, 98.4, '8/29/2008 05:20:32'),
#   (23510, 25695, 48683, 13547, 6541, 2002, 4, 100, 15.0, '6/25/2008 06:42:45'),
#   (23517, 25699, 2805, 9006, 6574, 1952, 2, 298, 44.7, '5/6/2008 06:52:28'),
#   (23572, 25776, 22382, 17177, 7162, 2132, 2, 304, 45.6, '11/2/2008 07:50:41'),
#   (23612, 25817, 40726, 9006, 1908, 2041, 2, 216, 32.4, '8/3/2008 08:44:53'),
#   (23727, 25948, 22845, 9006, 6182, 1855, 2, 424, 63.6, '1/29/2008 10:42:58'),
#   (23832, 26066, 15739, 11524, 123, 2061, 2, 118, 17.7, '8/23/2008 12:25:40'),
#   (23854, 26093, 27794, 32924, 8425, 1902, 1, 108, 16.2, '3/17/2008 12:48:07'),
#   (23855,
#    26097,
#    47873,
#    19014,
#    7875,
#    1902,
#    1,
#    237,
#    35.55,
#    '3/17/2008 12:49:28'),
#   (23867, 26108, 44579, 11524, 2644, 1972, 2, 292, 43.8, '5/26/2008 01:07:41'),
#   (23956, 26207, 4136, 11524, 898, 1989, 2, 52, 7.8, '6/12/2008 02:50:22'),
#   (23971, 26229, 11007, 11000, 2003, 1959, 1, 192, 28.8, '5/13/2008 03:04:01'),
#   (23987, 26244, 1679, 6389, 7793, 1993, 4, 748, 112.2, '6/16/2008 03:21:05'),
#   (24030, 26289, 27620, 17177, 7724, 2039, 2, 276, 41.4, '8/1/2008 04:06:23'),
#   (24036,
#    26292,
#    25931,
#    11541,
#    4228,
#    2121,
#    2,
#    192,
#    28.8,
#    '10/22/2008 04:13:01'),
#   (24084, 26353, 12721, 43231, 2195, 2071, 1, 203, 30.45, '9/2/2008 05:17:43'),
#   (24092, 26361, 30973, 19040, 319, 2089, 1, 204, 30.6, '9/20/2008 05:26:25'),
#   (24181,
#    26475,
#    13409,
#    24381,
#    5852,
#    2130,
#    2,
#    382,
#    57.3,
#    '10/31/2008 06:51:21'),
#   (24222, 26542, 3451, 551, 5656, 1903, 4, 560, 84.0, '3/18/2008 07:31:18'),
#   (24421, 26748, 10481, 11541, 3139, 1840, 2, 236, 35.4, '1/14/2008 11:44:08'),
#   (24573, 26914, 45920, 41892, 3011, 2018, 1, 31, 4.65, '7/11/2008 02:41:05'),
#   (24602, 26975, 10682, 11524, 1861, 2092, 2, 204, 30.6, '9/23/2008 03:12:55'),
#   (24770, 27148, 14291, 11524, 189, 2178, 2, 250, 37.5, '12/18/2008 06:14:21'),
#   (24779, 27161, 21894, 27525, 3116, 1975, 2, 86, 12.9, '5/29/2008 06:23:32'),
#   (24824, 27199, 22798, 929, 1210, 1951, 2, 360, 54.0, '5/5/2008 07:03:39'),
#   (24848, 27228, 47730, 11000, 4079, 1986, 1, 99, 14.85, '6/9/2008 07:42:33'),
#   (24947, 27318, 18008, 11524, 2875, 1845, 2, 288, 43.2, '1/19/2008 09:30:40'),
#   (24993, 27372, 33875, 19040, 841, 2030, 1, 114, 17.1, '7/23/2008 10:27:08'),
#   (25017,
#    27409,
#    34889,
#    11000,
#    4291,
#    1877,
#    1,
#    213,
#    31.95,
#    '2/20/2008 10:53:02'),
#   (25150, 27532, 49290, 3745, 560, 2164, 4, 612, 91.8, '12/4/2008 01:45:03'),
#   (25164, 27541, 46602, 28347, 4684, 2081, 1, 93, 13.95, '9/12/2008 01:59:04'),
#   (25283,
#    27667,
#    16807,
#    11541,
#    5396,
#    2113,
#    2,
#    270,
#    40.5,
#    '10/14/2008 04:12:01'),
#   (25306, 27689, 3420, 9006, 2485, 2050, 2, 74, 11.1, '8/12/2008 04:36:48'),
#   (25392, 27794, 24377, 11000, 4300, 2040, 1, 101, 15.15, '8/2/2008 06:13:24'),
#   (25452, 27877, 40135, 36719, 2353, 2102, 1, 38, 5.7, '10/3/2008 07:20:25'),
#   (25480,
#    27890,
#    16573,
#    28347,
#    5396,
#    2118,
#    1,
#    207,
#    31.05,
#    '10/19/2008 07:52:44'),
#   (25518, 27919, 30297, 6389, 6707, 1959, 4, 732, 109.8, '5/13/2008 08:34:55'),
#   (25617, 28037, 41000, 4473, 7180, 1957, 2, 494, 74.1, '5/11/2008 10:55:06'),
#   (25667, 28089, 12500, 29455, 6086, 1869, 4, 104, 15.6, '2/12/2008 11:54:17'),
#   (25810, 28241, 40636, 929, 3329, 1910, 2, 488, 73.2, '3/25/2008 02:57:40'),
#   (25920, 28358, 9372, 4473, 7991, 1952, 2, 154, 23.1, '5/6/2008 04:39:09'),
#   (25947, 28380, 7763, 3745, 4804, 1870, 4, 236, 35.4, '2/13/2008 05:05:42'),
#   (25979, 28409, 23084, 39155, 1849, 2083, 4, 512, 76.8, '9/14/2008 05:40:23'),
#   (26065, 28485, 44560, 33418, 5373, 1926, 4, 644, 96.6, '4/10/2008 07:22:12'),
#   (26149, 28560, 26136, 11541, 5243, 1843, 2, 274, 41.1, '1/17/2008 09:11:47'),
#   (26186, 28594, 26090, 4473, 2888, 2105, 2, 438, 65.7, '10/6/2008 10:06:23'),
#   (26354, 28754, 31779, 929, 7851, 1885, 2, 62, 9.3, '2/28/2008 01:03:21'),
#   (26385, 28785, 40586, 27494, 483, 1939, 4, 912, 136.8, '4/23/2008 01:40:05'),
#   (26449,
#    28855,
#    39474,
#    29869,
#    3395,
#    2143,
#    2,
#    310,
#    46.5,
#    '11/13/2008 03:04:58'),
#   (26652, 29078, 34437, 9902, 1093, 1908, 2, 368, 55.2, '3/23/2008 07:38:14'),
#   (26674,
#    29094,
#    25301,
#    27494,
#    2123,
#    1974,
#    4,
#    864,
#    129.6,
#    '5/28/2008 08:01:39'),
#   (26715, 29129, 10682, 7597, 2524, 1839, 2, 378, 56.7, '1/13/2008 08:46:46'),
#   (27054, 29500, 17156, 34435, 5575, 2084, 2, 118, 17.7, '9/15/2008 03:05:17'),
#   (27110, 29557, 32420, 16726, 1471, 1923, 1, 180, 27.0, '4/7/2008 04:09:41'),
#   (27118, 29571, 21945, 7597, 1606, 1838, 2, 148, 22.2, '1/12/2008 04:19:06'),
#   (27202, 29659, 17233, 22993, 2595, 2066, 3, 456, 68.4, '8/28/2008 05:58:33'),
#   (27249, 29714, 43529, 929, 6478, 2147, 2, 392, 58.8, '11/17/2008 06:54:25'),
#   (27281,
#    29747,
#    14466,
#    27525,
#    1234,
#    2122,
#    2,
#    210,
#    31.5,
#    '10/23/2008 07:21:00'),
#   (27300, 29764, 42682, 4473, 714, 1855, 2, 202, 30.3, '1/29/2008 07:39:17'),
#   (27325, 29791, 34938, 9902, 2036, 2044, 2, 130, 19.5, '8/6/2008 08:03:36'),
#   (27376, 29849, 21749, 16726, 6858, 2085, 1, 164, 24.6, '9/16/2008 09:00:13'),
#   (27510, 29994, 43880, 38736, 5496, 1939, 2, 104, 15.6, '4/23/2008 11:48:41'),
#   (27524, 30016, 49700, 3745, 1919, 1908, 4, 804, 120.6, '3/23/2008 12:04:32'),
#   (27585, 30089, 23860, 34435, 8242, 1942, 2, 168, 25.2, '4/26/2008 01:15:07'),
#   (27653, 30159, 88, 39155, 6645, 2022, 4, 176, 26.4, '7/15/2008 02:17:00'),
#   (27700, 30217, 25847, 20385, 4018, 1885, 1, 130, 19.5, '2/28/2008 03:09:11'),
#   (27872, 30418, 17020, 28347, 3233, 2056, 1, 93, 13.95, '8/18/2008 06:34:15'),
#   (27947, 30495, 27819, 9902, 16, 1980, 2, 318, 47.7, '6/3/2008 08:04:09'),
#   (27948, 30495, 27819, 6389, 16, 1976, 4, 636, 95.4, '5/30/2008 08:05:35'),
#   (27973, 30517, 693, 20303, 8288, 2120, 2, 262, 39.3, '10/21/2008 08:40:11'),
#   (28187, 30739, 18866, 9007, 8779, 1910, 2, 266, 39.9, '3/25/2008 12:53:52'),
#   (28387,
#    30985,
#    16870,
#    31046,
#    2695,
#    1997,
#    1,
#    309,
#    46.35,
#    '6/20/2008 04:10:02'),
#   (28489, 31112, 49023, 9007, 8763, 1903, 2, 474, 71.1, '3/18/2008 06:09:49'),
#   (28595, 31252, 40733, 7597, 7476, 1839, 2, 128, 19.2, '1/13/2008 08:17:16'),
#   (28742, 31433, 47669, 7597, 4249, 1953, 2, 224, 33.6, '5/7/2008 11:15:09'),
#   (28959, 31701, 4785, 27099, 8683, 2099, 2, 188, 28.2, '9/30/2008 03:23:36'),
#   (29047, 31808, 4017, 20385, 5061, 2174, 1, 224, 33.6, '12/14/2008 05:03:32'),
#   (29483, 32317, 17520, 1874, 6986, 2080, 3, 480, 72.0, '9/11/2008 01:21:50'),
#   (29706, 32577, 13517, 26043, 7360, 2115, 1, 65, 9.75, '10/16/2008 05:57:55'),
#   (29842,
#    32752,
#    22369,
#    26043,
#    6272,
#    2061,
#    1,
#    217,
#    32.55,
#    '8/23/2008 08:50:44'),
#   (30214, 33159, 17238, 17831, 7946, 1897, 1, 34, 5.1, '3/12/2008 03:13:52'),
#   (30426,
#    33415,
#    25297,
#    17831,
#    1307,
#    2108,
#    1,
#    259,
#    38.85,
#    '10/9/2008 07:04:16'),
#   (30669,
#    33730,
#    45067,
#    27099,
#    3499,
#    2117,
#    2,
#    476,
#    71.4,
#    '10/18/2008 11:56:30'),
#   (30819, 33932, 22475, 31274, 7316, 1933, 2, 494, 74.1, '4/17/2008 02:35:46'),
#   (30911, 34041, 21867, 9007, 7270, 1963, 2, 384, 57.6, '5/17/2008 04:13:07'),
#   (31165, 34328, 8953, 8258, 7140, 1943, 2, 296, 44.4, '4/27/2008 09:00:06'),
#   (31196, 34359, 11376, 20202, 7755, 1946, 4, 248, 37.2, '4/30/2008 09:28:39'),
#   (31338, 34551, 25529, 29869, 7317, 1879, 1, 108, 16.2, '2/22/2008 12:30:17'),
#   (31747, 35067, 6396, 31274, 7215, 1928, 2, 612, 91.8, '4/12/2008 08:12:36'),
#   (31892, 35227, 13999, 17831, 8336, 2048, 1, 144, 21.6, '8/10/2008 11:09:06'),
#   (32043, 35395, 28032, 29869, 3627, 1963, 1, 164, 24.6, '5/17/2008 01:43:39'),
#   (32107,
#    35487,
#    37917,
#    20202,
#    8783,
#    2088,
#    4,
#    1012,
#    151.8,
#    '9/19/2008 02:42:33'),
#   (32232,
#    35644,
#    25717,
#    2394,
#    6465,
#    2102,
#    3,
#    801,
#    120.15,
#    '10/3/2008 04:49:28'),
#   (32358, 35797, 11892, 23137, 5814, 1865, 2, 106, 15.9, '2/8/2008 07:22:39'),
#   (32390, 35840, 4974, 25128, 5882, 2081, 2, 292, 43.8, '9/12/2008 07:57:12'),
#   (32431, 35879, 27191, 8258, 2500, 2124, 2, 514, 77.1, '10/25/2008 08:58:01'),
#   (32485, 35918, 23301, 23137, 8497, 1965, 2, 256, 38.4, '5/19/2008 10:12:15'),
#   (32507, 35944, 35129, 20450, 1990, 1914, 2, 494, 74.1, '3/29/2008 10:38:16'),
#   (32616,
#    36039,
#    43748,
#    23137,
#    7300,
#    1941,
#    2,
#    680,
#    102.0,
#    '4/25/2008 12:27:51'),
#   (32643,
#    36065,
#    12480,
#    22993,
#    2655,
#    2047,
#    3,
#    765,
#    114.75,
#    '8/9/2008 12:58:40'),
#   (32668, 36092, 31503, 1874, 6084, 1849, 3, 540, 81.0, '1/23/2008 01:19:52'),
#   (32756,
#    36196,
#    14851,
#    38381,
#    6004,
#    2068,
#    1,
#    261,
#    39.15,
#    '8/30/2008 03:22:31'),
#   (32829, 36272, 7209, 9006, 8143, 2122, 2, 94, 14.1, '10/23/2008 04:39:37'),
#   (32839, 36281, 2078, 8258, 4922, 1884, 2, 96, 14.4, '2/27/2008 04:49:35'),
#   (32921, 36362, 1236, 20450, 7956, 2036, 2, 520, 78.0, '7/29/2008 06:10:05'),
#   (33012,
#    36467,
#    26151,
#    20202,
#    4946,
#    2041,
#    4,
#    1244,
#    186.6,
#    '8/3/2008 07:53:10'),
#   (33207, 36682, 27087, 34194, 8164, 2074, 1, 167, 25.05, '9/5/2008 11:58:34'),
#   (33366, 36867, 18229, 31274, 879, 2088, 2, 108, 16.2, '9/19/2008 03:01:27'),
#   (33435, 36948, 24200, 28558, 7061, 1881, 1, 346, 51.9, '2/24/2008 04:08:43'),
#   (33436, 36949, 20082, 28558, 7876, 1966, 1, 288, 43.2, '5/20/2008 04:09:19'),
#   (33633, 37180, 42695, 1874, 4262, 1853, 3, 339, 50.85, '1/27/2008 07:53:00'),
#   (33720, 37306, 39505, 1874, 8575, 2005, 3, 330, 49.5, '6/28/2008 09:18:50'),
#   (33758, 37349, 36181, 8258, 4657, 1984, 2, 376, 56.4, '6/7/2008 09:47:27'),
#   (33827, 37418, 38631, 9006, 4776, 1856, 2, 648, 97.2, '1/30/2008 10:57:55'),
#   (33843, 37432, 28226, 37202, 1838, 2132, 1, 98, 14.7, '11/2/2008 11:13:18'),
#   (33847,
#    37435,
#    38223,
#    34194,
#    3666,
#    1881,
#    1,
#    347,
#    52.05,
#    '2/24/2008 11:15:56'),
#   (33912, 37504, 16595, 9006, 5049, 2039, 2, 328, 49.2, '8/1/2008 12:30:42'),
#   (34218, 37853, 15258, 20450, 6514, 2085, 2, 332, 49.8, '9/16/2008 05:49:02'),
#   (34244, 37886, 26207, 46562, 2230, 1914, 2, 210, 31.5, '3/29/2008 06:10:28'),
#   (34283, 37942, 35764, 9006, 3830, 1976, 2, 610, 91.5, '5/30/2008 06:56:29'),
#   (34507, 38228, 41813, 30203, 2627, 1954, 1, 205, 30.75, '5/8/2008 11:22:55'),
#   (34582, 38307, 41517, 20192, 2121, 1868, 1, 46, 6.9, '2/11/2008 01:05:52'),
#   (34646, 38378, 14820, 36014, 7403, 2084, 1, 116, 17.4, '9/15/2008 02:25:43'),
#   (34652,
#    38396,
#    37509,
#    28558,
#    1685,
#    1968,
#    1,
#    251,
#    37.65,
#    '5/22/2008 02:29:18'),
#   (34770, 38537, 28672, 28333, 3423, 1996, 2, 214, 32.1, '6/19/2008 04:36:46'),
#   (34935,
#    38727,
#    6327,
#    20192,
#    7581,
#    2148,
#    1,
#    327,
#    49.05,
#    '11/18/2008 07:58:30'),
#   (34962, 38754, 41318, 28558, 6373, 1876, 1, 266, 39.9, '2/19/2008 08:21:46'),
#   (34976, 38777, 3337, 2741, 7484, 2124, 2, 498, 74.7, '10/25/2008 08:39:00'),
#   (35048, 38853, 7580, 25128, 5477, 2124, 2, 664, 99.6, '10/25/2008 09:47:25'),
#   (35152, 38985, 46871, 20450, 2674, 1934, 2, 78, 11.7, '4/18/2008 11:57:57'),
#   (35365, 39254, 27862, 20192, 8132, 2032, 1, 224, 33.6, '7/25/2008 03:51:45'),
#   (35378, 39270, 24505, 43668, 4141, 2044, 1, 80, 12.0, '8/6/2008 04:03:59'),
#   (35582, 39531, 3408, 6968, 4416, 2100, 1, 233, 34.95, '10/1/2008 08:07:34'),
#   (35648, 39594, 28947, 2741, 8044, 1987, 2, 328, 49.2, '6/10/2008 09:42:56'),
#   (35744, 39717, 11679, 16726, 4147, 2019, 1, 164, 24.6, '7/12/2008 11:49:18'),
#   (35757, 39734, 30500, 3563, 2813, 1949, 2, 466, 69.9, '5/3/2008 12:05:39'),
#   (35812, 39810, 43221, 1924, 1322, 2063, 2, 234, 35.1, '8/25/2008 01:12:51'),
#   (35957,
#    40005,
#    18474,
#    20192,
#    6465,
#    2116,
#    1,
#    265,
#    39.75,
#    '10/17/2008 03:59:25'),
#   (36233, 40335, 36284, 19355, 6307, 2109, 2, 66, 9.9, '10/10/2008 09:27:31'),
#   (36241, 40345, 7433, 11544, 8588, 2025, 2, 344, 51.6, '7/18/2008 09:32:30'),
#   (36389, 40488, 30203, 6968, 3437, 2058, 1, 297, 44.55, '8/20/2008 12:45:50'),
#   (36586,
#    40706,
#    9696,
#    11544,
#    3550,
#    2117,
#    2,
#    700,
#    105.0,
#    '10/18/2008 04:18:20'),
#   (36650, 40780, 18450, 37788, 3992, 2009, 1, 340, 51.0, '7/2/2008 05:33:44'),
#   (36663, 40793, 11036, 1587, 5446, 2057, 3, 261, 39.15, '8/19/2008 05:50:55'),
#   (36679, 40814, 36932, 3563, 1591, 1892, 2, 322, 48.3, '3/7/2008 06:11:33'),
#   (36695, 40833, 27109, 3563, 7207, 1865, 2, 460, 69.0, '2/8/2008 06:30:29'),
#   (36746, 40893, 48307, 1924, 6309, 2161, 2, 414, 62.1, '12/1/2008 07:30:46'),
#   (36749, 40898, 28596, 1924, 7101, 1935, 2, 420, 63.0, '4/19/2008 07:37:25'),
#   (36771, 40919, 16751, 19355, 7659, 2053, 2, 486, 72.9, '8/15/2008 08:21:10'),
#   (36801, 40946, 14412, 2394, 6773, 1845, 3, 138, 20.7, '1/19/2008 09:00:45'),
#   (36815, 40974, 42269, 6968, 1961, 2020, 1, 35, 5.25, '7/13/2008 09:16:47'),
#   (36833, 40993, 18955, 2394, 6547, 2060, 3, 852, 127.8, '8/22/2008 09:44:55'),
#   (36834, 40993, 18955, 6968, 6547, 2066, 1, 284, 42.6, '8/28/2008 09:45:10'),
#   (36841, 41001, 42180, 21784, 6738, 1939, 4, 140, 21.0, '4/23/2008 09:56:30'),
#   (37142, 41377, 25271, 2741, 4659, 1942, 2, 486, 72.9, '4/26/2008 03:44:52'),
#   (37164, 41403, 24966, 7597, 3901, 1853, 3, 900, 135.0, '1/27/2008 04:05:28'),
#   (37178, 41416, 19842, 2741, 135, 1974, 2, 284, 42.6, '5/28/2008 04:24:27'),
#   (37247, 41488, 35873, 16726, 4313, 2064, 1, 90, 13.5, '8/26/2008 05:44:21'),
#   (37267, 41505, 24982, 16726, 3392, 2074, 1, 307, 46.05, '9/5/2008 06:06:28'),
#   (37435, 41713, 13704, 3563, 3645, 1990, 2, 538, 80.7, '6/13/2008 09:02:41'),
#   (37501, 41777, 38606, 1924, 6550, 1904, 2, 466, 69.9, '3/19/2008 10:16:06'),
#   (37562,
#    41850,
#    47762,
#    24187,
#    6624,
#    1936,
#    3,
#    333,
#    49.95,
#    '4/20/2008 11:38:49'),
#   (37719, 42033, 20383, 16726, 689, 2073, 1, 183, 27.45, '9/4/2008 02:27:36'),
#   (37739, 42047, 11067, 12900, 509, 1851, 3, 474, 71.1, '1/25/2008 02:44:47'),
#   (37785, 42102, 22042, 12900, 8483, 2079, 3, 540, 81.0, '9/10/2008 03:41:06'),
#   (37948, 42269, 47454, 519, 8304, 1909, 4, 576, 86.4, '3/24/2008 07:07:41'),
#   (38005, 42348, 35962, 14861, 8168, 2164, 2, 434, 65.1, '12/4/2008 08:23:04'),
#   (38101, 42478, 26506, 34435, 4708, 1951, 2, 184, 27.6, '5/5/2008 10:17:50'),
#   (38310, 42687, 2479, 20441, 3541, 1858, 2, 186, 27.9, '2/1/2008 02:33:52'),
#   (38317,
#    42694,
#    20457,
#    20441,
#    5620,
#    2128,
#    2,
#    478,
#    71.7,
#    '10/29/2008 02:48:14'),
#   (38466, 42869, 47994, 37788, 8749, 2024, 1, 97, 14.55, '7/17/2008 05:37:28'),
#   (38520, 42944, 9943, 27843, 2671, 2161, 4, 504, 75.6, '12/1/2008 06:40:01'),
#   (38550, 42980, 6574, 20441, 5645, 2038, 2, 520, 78.0, '7/31/2008 07:09:38'),
#   (38682, 43128, 35627, 10186, 7296, 2030, 1, 276, 41.4, '7/23/2008 09:56:49'),
#   (38850, 43315, 4902, 7871, 6234, 2071, 2, 262, 39.3, '9/2/2008 01:09:20'),
#   (38869,
#    43331,
#    34610,
#    26325,
#    5360,
#    2113,
#    1,
#    316,
#    47.4,
#    '10/14/2008 01:29:00'),
#   (38937, 43410, 49005, 26325, 3005, 1915, 1, 75, 11.25, '3/30/2008 02:52:44'),
#   (38977, 43448, 27364, 27843, 5017, 1950, 4, 760, 114.0, '5/4/2008 03:37:23'),
#   (39120, 43613, 26109, 34435, 4938, 1877, 2, 494, 74.1, '2/20/2008 06:40:33'),
#   (39214, 43738, 291, 10651, 4821, 2004, 2, 564, 84.6, '6/27/2008 08:43:45'),
#   (39306, 43856, 23008, 7597, 6148, 1883, 3, 501, 75.15, '2/26/2008 10:42:27'),
#   (39316,
#    43869,
#    31595,
#    20441,
#    4847,
#    2155,
#    2,
#    598,
#    89.7,
#    '11/25/2008 10:52:22'),
#   (39370,
#    43935,
#    34947,
#    37573,
#    3038,
#    2103,
#    1,
#    105,
#    15.75,
#    '10/4/2008 11:52:04'),
#   (39445, 44024, 2804, 10186, 215, 1952, 1, 164, 24.6, '5/6/2008 01:20:18'),
#   (39500,
#    44080,
#    37410,
#    1587,
#    4060,
#    1977,
#    3,
#    705,
#    105.75,
#    '5/31/2008 02:14:44'),
#   (39519, 44095, 29841, 7871, 3942, 2114, 2, 588, 88.2, '10/15/2008 02:31:05'),
#   (39536, 44118, 23638, 7871, 5650, 1956, 2, 84, 12.6, '5/10/2008 02:46:46'),
#   (39813,
#    44459,
#    19319,
#    12900,
#    6938,
#    2083,
#    3,
#    987,
#    148.05,
#    '9/14/2008 07:52:10'),
#   (39842, 44494, 46583, 10651, 2264, 2093, 2, 144, 21.6, '9/24/2008 08:20:39'),
#   (39904, 44566, 8869, 20450, 6929, 2126, 4, 616, 92.4, '10/27/2008 09:39:55'),
#   (40085, 44786, 821, 1587, 1823, 2036, 3, 159, 23.85, '7/29/2008 01:29:41'),
#   (40096, 44796, 17111, 24187, 960, 1887, 1, 332, 49.8, '3/2/2008 01:44:57'),
#   (40130, 44825, 31854, 37573, 4350, 2033, 1, 73, 10.95, '7/26/2008 02:24:28'),
#   (40149,
#    44844,
#    38600,
#    24362,
#    8355,
#    2118,
#    1,
#    252,
#    37.8,
#    '10/19/2008 02:50:41'),
#   (40151, 44848, 16090, 7414, 4458, 1870, 2, 96, 14.4, '2/13/2008 02:52:47'),
#   (40156,
#    44855,
#    45011,
#    7428,
#    7473,
#    1937,
#    4,
#    1068,
#    160.2,
#    '4/21/2008 03:02:58'),
#   (40197, 44927, 32034, 37573, 5931, 1876, 1, 108, 16.2, '2/19/2008 03:41:48'),
#   (40228, 44970, 46055, 7871, 8775, 2107, 2, 216, 32.4, '10/8/2008 04:10:18'),
#   (40370, 45164, 28839, 10651, 357, 2085, 2, 142, 21.3, '9/16/2008 06:43:30'),
#   (40453, 45250, 29114, 14861, 4546, 1874, 2, 114, 17.1, '2/17/2008 08:16:08'),
#   (40508, 45308, 25487, 7428, 6417, 1919, 4, 360, 54.0, '4/3/2008 09:15:02'),
#   (40582, 45381, 48303, 2394, 2971, 2038, 3, 393, 58.95, '7/31/2008 10:48:46'),
#   (40666, 45487, 36739, 519, 1846, 1988, 4, 1128, 169.2, '6/11/2008 12:14:39'),
#   (40815, 45661, 42181, 7414, 1971, 1954, 2, 222, 33.3, '5/8/2008 02:59:09'),
#   (40913, 45787, 42848, 27729, 8118, 1913, 1, 37, 5.55, '3/28/2008 04:43:43'),
#   (41093,
#    45997,
#    14689,
#    10651,
#    5061,
#    2157,
#    2,
#    510,
#    76.5,
#    '11/27/2008 07:43:11'),
#   (41154, 46078, 25444, 14861, 6843, 2111, 2, 76, 11.4, '10/12/2008 08:39:23'),
#   (41192, 46121, 27594, 14861, 938, 1916, 2, 682, 102.3, '3/31/2008 09:22:24'),
#   (41255, 46185, 10876, 1587, 3167, 1981, 3, 723, 108.45, '6/4/2008 10:28:16'),
#   (41320, 46273, 49640, 18013, 2702, 2009, 1, 255, 38.25, '7/2/2008 11:48:47'),
#   (41442, 46426, 14941, 7414, 3251, 2031, 2, 248, 37.2, '7/24/2008 02:21:46'),
#   (41458, 46446, 1121, 20450, 1930, 1870, 4, 164, 24.6, '2/13/2008 02:39:15'),
#   (41677, 46701, 34345, 7414, 51, 1865, 2, 460, 69.0, '2/8/2008 06:45:13'),
#   (41752, 46785, 31105, 519, 306, 1897, 4, 740, 111.0, '3/12/2008 08:04:52'),
#   (41753, 46785, 31105, 24362, 306, 1926, 1, 185, 27.75, '4/10/2008 08:05:13'),
#   (41797, 46834, 19475, 6389, 6663, 2136, 3, 240, 36.0, '11/6/2008 09:02:16'),
#   (41905, 46957, 2629, 519, 4041, 1981, 4, 984, 147.6, '6/4/2008 10:55:18'),
#   (41917, 46966, 8882, 16299, 8147, 2154, 4, 132, 19.8, '11/24/2008 11:04:53'),
#   (42105, 47168, 41008, 24187, 1271, 2009, 3, 234, 35.1, '7/2/2008 02:20:17'),
#   (42136,
#    47199,
#    21650,
#    7597,
#    8108,
#    2088,
#    3,
#    909,
#    136.35,
#    '9/19/2008 02:52:42'),
#   (42188,
#    47268,
#    47816,
#    7597,
#    2960,
#    2142,
#    3,
#    936,
#    140.4,
#    '11/12/2008 03:42:08'),
#   (42205,
#    47297,
#    44700,
#    36015,
#    1792,
#    1994,
#    2,
#    686,
#    102.9,
#    '6/17/2008 03:57:59'),
#   (42291, 47410, 35291, 7428, 4010, 2027, 4, 724, 108.6, '7/20/2008 05:44:33'),
#   (42425, 47574, 5978, 24187, 4465, 2051, 1, 262, 39.3, '8/13/2008 08:30:37'),
#   (42585, 47756, 49826, 37273, 843, 2043, 2, 252, 37.8, '8/5/2008 11:44:19'),
#   (42617, 47795, 516, 10651, 8528, 1840, 2, 490, 73.5, '1/14/2008 12:17:39'),
#   (42762, 47988, 38076, 33938, 4022, 1882, 2, 400, 60.0, '2/25/2008 03:04:11'),
#   (42910, 48165, 29265, 30326, 5695, 2064, 4, 624, 93.6, '8/26/2008 06:01:40'),
#   (43030, 48299, 39688, 26981, 827, 2047, 2, 622, 93.3, '8/9/2008 08:16:10'),
#   (43094, 48382, 26766, 16299, 8753, 1880, 4, 604, 90.6, '2/23/2008 09:10:10'),
#   (43103, 48390, 45805, 20334, 1157, 1993, 2, 552, 82.8, '6/16/2008 09:18:22'),
#   (43176, 48495, 8414, 10186, 254, 2078, 1, 311, 46.65, '9/9/2008 10:31:40'),
#   (43227, 48567, 8205, 16299, 7630, 1987, 4, 588, 88.2, '6/10/2008 11:23:19'),
#   (43260, 48593, 44890, 33938, 8777, 1931, 2, 318, 47.7, '4/15/2008 12:05:27'),
#   (43263, 48599, 47331, 26981, 8754, 2186, 2, 72, 10.8, '12/26/2008 12:08:16'),
#   (43376, 48729, 9392, 24381, 2997, 2136, 3, 762, 114.3, '11/6/2008 02:13:35'),
#   (43386, 48744, 23575, 2741, 8307, 1953, 2, 386, 57.9, '5/7/2008 02:25:01'),
#   (43494,
#    48893,
#    10621,
#    22326,
#    3816,
#    2114,
#    1,
#    177,
#    26.55,
#    '10/15/2008 04:41:55'),
#   (43507, 48912, 3798, 37273, 4951, 2038, 2, 652, 97.8, '7/31/2008 04:59:19'),
#   (43579, 48993, 23763, 37573, 3301, 1881, 3, 63, 9.45, '2/24/2008 06:16:30'),
#   (43644,
#    49058,
#    40133,
#    24381,
#    6622,
#    2106,
#    3,
#    1029,
#    154.35,
#    '10/7/2008 07:35:54'),
#   (43817, 49242, 6583, 10513, 947, 2078, 1, 20, 3.0, '9/9/2008 10:59:32'),
#   (43819, 49245, 24630, 10513, 4637, 1978, 1, 209, 31.35, '6/1/2008 11:01:55'),
#   (43823, 49251, 35318, 10513, 374, 2108, 1, 163, 24.45, '10/9/2008 11:09:58'),
#   (43905, 49349, 41352, 39902, 6180, 2008, 2, 382, 57.3, '7/1/2008 12:16:49'),
#   (43910, 49358, 36370, 10651, 4520, 2077, 2, 322, 48.3, '9/8/2008 12:25:12'),
#   (44083,
#    49558,
#    43455,
#    25900,
#    6537,
#    2172,
#    3,
#    171,
#    25.65,
#    '12/12/2008 03:27:11'),
#   (44273, 49775, 44937, 2741, 5797, 1943, 2, 70, 10.5, '4/27/2008 07:16:08'),
#   (44331, 49849, 24431, 33938, 7574, 1959, 2, 154, 23.1, '5/13/2008 08:25:51'),
#   (44374, 49882, 29677, 13486, 6877, 2100, 1, 238, 35.7, '10/1/2008 09:06:55'),
#   (44508, 50049, 24838, 26981, 18, 2139, 2, 370, 55.5, '11/9/2008 11:23:54'),
#   (44537, 50079, 12516, 2741, 5160, 2139, 2, 526, 78.9, '11/9/2008 11:57:03'),
#   (44656, 50223, 49798, 13486, 651, 1968, 1, 35, 5.25, '5/22/2008 02:10:29'),
#   (44706, 50278, 2158, 13486, 7584, 2125, 1, 106, 15.9, '10/26/2008 03:11:16'),
#   (44731, 50321, 20349, 2741, 5776, 2123, 2, 490, 73.5, '10/24/2008 03:39:34'),
#   (44750, 50347, 38820, 20334, 2987, 1912, 2, 646, 96.9, '3/27/2008 03:58:44'),
#   (44919, 50517, 25092, 1587, 5726, 2000, 3, 72, 10.8, '6/23/2008 07:25:11'),
#   (44971, 50584, 19756, 10297, 2765, 1961, 1, 21, 3.15, '5/15/2008 08:23:09'),
#   (44996,
#    50611,
#    22311,
#    10297,
#    4885,
#    2119,
#    1,
#    81,
#    12.15,
#    '10/20/2008 08:49:22'),
#   (45073, 50705, 4088, 10297, 3884, 1871, 1, 243, 36.45, '2/14/2008 10:22:42'),
#   (45100, 50734, 4803, 25900, 382, 2092, 3, 681, 102.15, '9/23/2008 10:54:06'),
#   (45102, 50736, 39875, 12363, 2386, 1902, 1, 85, 12.75, '3/17/2008 10:59:38'),
#   (45123,
#    50759,
#    29378,
#    12363,
#    1418,
#    2147,
#    1,
#    319,
#    47.85,
#    '11/17/2008 11:26:01'),
#   (45245, 50925, 42542, 10297, 1931, 1941, 1, 42, 6.3, '4/25/2008 01:39:26'),
#   (45539, 51243, 27697, 20334, 2751, 1868, 2, 664, 99.6, '2/11/2008 07:10:36'),
#   (45774, 51524, 67, 6389, 6691, 2048, 3, 375, 56.25, '8/10/2008 11:53:47'),
#   (46077, 51876, 18005, 24337, 3500, 2067, 2, 410, 61.5, '8/29/2008 05:37:37'),
#   (46257, 52065, 15811, 12363, 7987, 1848, 1, 87, 13.05, '1/22/2008 09:30:24'),
#   (46304, 52109, 5071, 13500, 1037, 2145, 4, 244, 36.6, '11/15/2008 10:30:02'),
#   (46419, 52233, 9836, 6921, 2486, 1884, 1, 275, 41.25, '2/27/2008 12:49:26'),
#   (46520, 52373, 36767, 9378, 7960, 2122, 2, 626, 93.9, '10/23/2008 02:52:22'),
#   (46598, 52466, 19891, 6389, 175, 2040, 3, 276, 41.4, '8/2/2008 04:14:49'),
#   (46755, 52641, 13741, 2741, 2007, 2157, 2, 186, 27.9, '11/27/2008 07:31:12'),
#   (46762, 52662, 37033, 2741, 8503, 1838, 2, 70, 10.5, '1/12/2008 07:42:16'),
#   (46832, 52747, 25144, 6389, 6655, 1860, 3, 747, 112.05, '2/3/2008 09:04:43'),
#   (46987, 52960, 20342, 5196, 2231, 1972, 1, 277, 41.55, '5/26/2008 12:08:15'),
#   (46996,
#    52972,
#    46737,
#    27729,
#    4807,
#    2176,
#    1,
#    207,
#    31.05,
#    '12/16/2008 12:17:41'),
#   (47015,
#    52998,
#    46180,
#    47473,
#    824,
#    1963,
#    3,
#    777,
#    116.55,
#    '5/17/2008 12:37:12'),
#   (47020, 53005, 42312, 5196, 6197, 2059, 1, 137, 20.55, '8/21/2008 12:41:00'),
#   (47028, 53022, 25589, 2741, 413, 1979, 2, 178, 26.7, '6/2/2008 12:48:31'),
#   (47121, 53132, 39002, 6921, 7074, 1853, 1, 111, 16.65, '1/27/2008 02:31:27'),
#   (47125,
#    53134,
#    26273,
#    25900,
#    7148,
#    2174,
#    3,
#    924,
#    138.6,
#    '12/14/2008 02:38:12'),
#   (47137, 53146, 40344, 42947, 2603, 2106, 1, 174, 26.1, '10/7/2008 02:44:15'),
#   (47142, 53149, 32569, 6921, 5575, 2083, 1, 195, 29.25, '9/14/2008 02:52:01'),
#   (47151, 53167, 25185, 5196, 1114, 2132, 1, 160, 24.0, '11/2/2008 03:05:55'),
#   (47451, 53527, 43763, 9378, 2173, 1911, 2, 596, 89.4, '3/26/2008 08:33:46'),
#   (47562,
#    53680,
#    42657,
#    22441,
#    7745,
#    2111,
#    2,
#    366,
#    54.9,
#    '10/12/2008 10:42:21'),
#   (47662, 53797, 33405, 2741, 6219, 1887, 2, 502, 75.3, '3/2/2008 12:30:34'),
#   (47701, 53856, 19580, 33938, 1983, 2092, 2, 610, 91.5, '9/23/2008 01:08:01'),
#   (47802, 53977, 10050, 1237, 8594, 1986, 4, 976, 146.4, '6/9/2008 03:29:16'),
#   (47976, 54181, 2507, 2921, 4080, 1980, 1, 113, 16.95, '6/3/2008 06:41:25'),
#   (48055, 54283, 34967, 2921, 508, 1843, 1, 318, 47.7, '1/17/2008 08:03:42'),
#   (48090, 54334, 18742, 2921, 2362, 1903, 1, 185, 27.75, '3/18/2008 08:42:43'),
#   (48148, 54401, 12256, 19360, 5895, 1885, 1, 73, 10.95, '2/28/2008 09:50:04'),
#   (48158, 54408, 36142, 19360, 2810, 2032, 1, 95, 14.25, '7/25/2008 10:05:56'),
#   (48178,
#    54436,
#    17845,
#    14174,
#    1588,
#    1883,
#    1,
#    157,
#    23.55,
#    '2/26/2008 10:26:08'),
#   (48497, 54806, 35796, 2921, 1693, 2012, 1, 288, 43.2, '7/5/2008 05:15:09'),
#   (48777,
#    55089,
#    49139,
#    13500,
#    2141,
#    2156,
#    4,
#    600,
#    90.0,
#    '11/26/2008 10:31:51'),
#   (48854, 55191, 43815, 7871, 533, 1872, 2, 576, 86.4, '2/15/2008 11:54:04'),
#   (48882, 55224, 9589, 2741, 4228, 2129, 2, 252, 37.8, '10/30/2008 12:26:54'),
#   (48928, 55267, 7571, 9378, 7233, 2100, 2, 224, 33.6, '10/1/2008 01:06:33'),
#   (49221, 55595, 2305, 13500, 4925, 1943, 4, 692, 103.8, '4/27/2008 06:52:21'),
#   (49299, 55667, 43220, 24078, 7609, 2045, 1, 125, 18.75, '8/7/2008 08:27:57'),
#   (49352, 55720, 37914, 7677, 5150, 2027, 4, 992, 148.8, '7/20/2008 09:38:34'),
#   (49479, 55839, 47294, 36278, 6265, 2091, 1, 152, 22.8, '9/22/2008 12:15:35'),
#   (49600, 55976, 18488, 2390, 2158, 2171, 2, 478, 71.7, '12/11/2008 02:31:12'),
#   (49659, 56057, 49475, 7871, 1712, 2150, 2, 556, 83.4, '11/20/2008 03:32:07'),
#   (49749, 56158, 36543, 34913, 7397, 2014, 1, 283, 42.45, '7/7/2008 05:17:28'),
#   (49839, 56275, 5813, 33164, 2179, 2081, 1, 97, 14.55, '9/12/2008 07:10:28'),
# ...
#   (76861, 87831, 15800, 20507, 1071, 1854, 1, 412, 61.8, '1/28/2008 01:46:46'),
#   (76923,
#    87897,
#    35539,
#    16863,
#    2580,
#    2122,
#    1,
#    214,
#    32.1,
#    '10/23/2008 02:51:50'),
#   (77003,
#    87994,
#    16326,
#    16863,
#    3941,
#    2157,
#    1,
#    164,
#    24.6,
#    '11/27/2008 04:20:33'),
#   (77097,
#    88087,
#    10384,
#    29840,
#    1095,
#    2079,
#    1,
#    429,
#    64.35,
#    '9/10/2008 06:18:21'),
#   (77233, 88226, 3384, 29840, 4019, 2184, 1, 54, 8.1, '12/24/2008 09:22:54'),
#   (77380, 88363, 36280, 20145, 328, 1978, 2, 830, 124.5, '6/1/2008 12:11:59'),
#   (77464, 88458, 49181, 42392, 4021, 1899, 2, 66, 9.9, '3/14/2008 01:44:53'),
#   (77747, 88781, 49836, 10186, 1427, 1936, 4, 476, 71.4, '4/20/2008 06:32:36'),
#   (77763, 88806, 31831, 20507, 1886, 1952, 1, 401, 60.15, '5/6/2008 06:45:30'),
#   (77878, 88933, 36901, 6968, 114, 1983, 1, 181, 27.15, '6/6/2008 09:09:25'),
#   (77929, 88990, 24829, 6968, 7270, 1967, 1, 191, 28.65, '5/21/2008 10:14:24'),
#   (78021, 89099, 24365, 6968, 6112, 2015, 1, 420, 63.0, '7/8/2008 12:04:39'),
#   (78068, 89156, 39960, 2390, 7929, 2050, 4, 680, 102.0, '8/12/2008 12:56:11'),
#   (78114, 89207, 13385, 6968, 2828, 2058, 1, 193, 28.95, '8/20/2008 01:30:40'),
#   (78134,
#    89229,
#    10045,
#    29840,
#    5015,
#    2052,
#    1,
#    473,
#    70.95,
#    '8/14/2008 02:00:41'),
#   (78177,
#    89280,
#    17557,
#    9518,
#    1695,
#    2136,
#    4,
#    1116,
#    167.4,
#    '11/6/2008 02:33:37'),
#   (78185, 89283, 2152, 11437, 8126, 2067, 2, 216, 32.4, '8/29/2008 02:39:01'),
#   (78470, 89595, 42209, 35711, 8056, 1959, 4, 456, 68.4, '5/13/2008 08:03:03'),
#   (78486, 89619, 37055, 38381, 6893, 2003, 1, 150, 22.5, '6/26/2008 08:17:54'),
#   (78500, 89626, 42726, 40042, 6252, 2045, 4, 812, 121.8, '8/7/2008 08:38:43'),
#   (78506, 89631, 7163, 20507, 3178, 1959, 1, 39, 5.85, '5/13/2008 08:47:44'),
#   (78549, 89684, 44998, 17931, 5695, 2060, 2, 250, 37.5, '8/22/2008 09:48:54'),
#   (78562, 89693, 7423, 11437, 272, 2170, 2, 684, 102.6, '12/10/2008 09:57:50'),
#   (78657, 89799, 34919, 20334, 6983, 1932, 1, 442, 66.3, '4/16/2008 11:40:11'),
#   (78717, 89855, 31969, 11437, 6751, 2070, 2, 238, 35.7, '9/1/2008 12:41:47'),
#   (78763, 89921, 148, 20334, 1638, 1919, 1, 207, 31.05, '4/3/2008 01:37:49'),
#   (79032,
#    90232,
#    16218,
#    24381,
#    1407,
#    2093,
#    4,
#    740,
#    111.0,
#    '9/24/2008 07:06:12'),
#   (79301,
#    90556,
#    32161,
#    19659,
#    1512,
#    2116,
#    2,
#    308,
#    46.2,
#    '10/17/2008 12:03:34'),
#   (79602, 90913, 45467, 11437, 8211, 1927, 2, 46, 6.9, '4/11/2008 05:18:03'),
#   (80484,
#    91890,
#    25929,
#    10186,
#    4182,
#    2006,
#    4,
#    1836,
#    275.4,
#    '6/29/2008 10:52:55'),
#   (80504, 91916, 4240, 4365, 995, 2059, 1, 384, 57.6, '8/21/2008 11:13:19'),
#   (80578,
#    91989,
#    38325,
#    41262,
#    1546,
#    1901,
#    3,
#    357,
#    53.55,
#    '3/16/2008 12:24:57'),
#   (80593, 92003, 32767, 26730, 427, 2072, 1, 35, 5.25, '9/3/2008 12:43:41'),
#   (80628,
#    92039,
#    13927,
#    10186,
#    5914,
#    2033,
#    4,
#    1292,
#    193.8,
#    '7/26/2008 01:19:03'),
#   (81004, 92404, 22850, 23867, 7432, 2018, 1, 210, 31.5, '7/11/2008 09:16:56'),
#   (81255, 92660, 39086, 24381, 7728, 1936, 4, 184, 27.6, '4/20/2008 02:39:37'),
#   (81531,
#    92974,
#    39437,
#    15424,
#    2755,
#    2152,
#    2,
#    402,
#    60.3,
#    '11/22/2008 07:53:51'),
#   (81634, 93095, 2707, 17183, 2009, 1975, 1, 300, 45.0, '5/29/2008 10:03:29'),
#   (81729, 93190, 9649, 17183, 7637, 2122, 1, 128, 19.2, '10/23/2008 12:03:08'),
#   (81769, 93228, 17021, 26052, 8765, 2016, 2, 290, 43.5, '7/9/2008 12:48:05'),
#   (81838, 93322, 4605, 26730, 5370, 2032, 1, 402, 60.3, '7/25/2008 02:17:30'),
#   (81863, 93345, 13857, 836, 5105, 2067, 4, 380, 57.0, '8/29/2008 02:45:35'),
#   (81959, 93449, 27367, 13486, 838, 1873, 1, 123, 18.45, '2/16/2008 04:27:49'),
#   (81994,
#    93498,
#    13030,
#    35711,
#    5704,
#    2109,
#    4,
#    1592,
#    238.8,
#    '10/10/2008 05:09:19'),
#   (82012, 93513, 20965, 2390, 698, 1873, 1, 500, 75.0, '2/16/2008 05:33:42'),
#   (82051, 93553, 19568, 4269, 5702, 2048, 1, 414, 62.1, '8/10/2008 06:16:15'),
#   (82185, 93718, 16155, 40042, 5672, 1954, 4, 184, 27.6, '5/8/2008 08:49:29'),
#   (82339, 93898, 30664, 23832, 2544, 1918, 4, 980, 147.0, '4/2/2008 11:38:00'),
#   (82341, 93901, 41931, 13486, 3448, 2071, 1, 115, 17.25, '9/2/2008 11:42:29'),
#   (82379,
#    93958,
#    16407,
#    13486,
#    7474,
#    2172,
#    1,
#    253,
#    37.95,
#    '12/12/2008 12:14:49'),
#   (82396, 93989, 32787, 2390, 492, 2022, 1, 28, 4.2, '7/15/2008 12:33:06'),
#   (82489, 94102, 10718, 10651, 479, 2154, 2, 192, 28.8, '11/24/2008 02:23:47'),
#   (82533, 94144, 32711, 42275, 5091, 2013, 1, 47, 7.05, '7/6/2008 03:18:05'),
#   (82670,
#    94273,
#    36477,
#    17183,
#    7893,
#    2115,
#    1,
#    292,
#    43.8,
#    '10/16/2008 06:05:29'),
#   (82920, 94525, 37767, 15424, 5025, 1981, 2, 672, 100.8, '6/4/2008 10:38:30'),
#   (82948, 94554, 41860, 10651, 6918, 1984, 2, 622, 93.3, '6/7/2008 11:11:14'),
#   (83038, 94643, 36164, 15424, 5911, 2033, 2, 148, 22.2, '7/26/2008 12:43:48'),
#   (83087, 94692, 33516, 19659, 7458, 2101, 2, 572, 85.8, '10/2/2008 01:31:28'),
#   (83240,
#    94870,
#    15905,
#    10651,
#    3560,
#    1852,
#    2,
#    674,
#    101.1,
#    '1/26/2008 04:36:43'),
#   (83303, 94955, 26907, 10651, 698, 1898, 2, 450, 67.5, '3/13/2008 06:00:21'),
#   (83481, 95212, 35842, 4365, 3659, 1863, 1, 459, 68.85, '2/6/2008 09:34:16'),
#   (83490, 95221, 20704, 4269, 3532, 1970, 1, 321, 48.15, '5/24/2008 09:41:29'),
#   (83496, 95230, 35260, 2390, 8712, 2028, 1, 51, 7.65, '7/21/2008 10:01:02'),
#   (83531, 95262, 20501, 4269, 1557, 1907, 1, 286, 42.9, '3/22/2008 10:47:18'),
#   (84060, 95893, 12653, 15424, 6613, 2121, 2, 52, 7.8, '10/22/2008 09:20:15'),
#   (84229, 96097, 38402, 13486, 8002, 1890, 1, 296, 44.4, '3/5/2008 12:44:37'),
#   (84303, 96177, 36533, 2390, 4763, 1857, 1, 352, 52.8, '1/31/2008 02:35:29'),
#   (84325, 96205, 28856, 4269, 753, 1965, 1, 498, 74.7, '5/19/2008 03:15:29'),
#   (84746, 96712, 16673, 1737, 1135, 1840, 1, 357, 53.55, '1/14/2008 11:26:00'),
#   (84928, 96951, 4989, 98, 3980, 1970, 1, 23, 3.45, '5/24/2008 03:07:07'),
#   (85140, 97186, 49604, 31046, 6074, 1931, 3, 99, 14.85, '4/15/2008 07:17:15'),
#   (85198, 97260, 4903, 4365, 2190, 2096, 1, 251, 37.65, '9/27/2008 08:32:24'),
#   (85367,
#    97445,
#    41185,
#    26469,
#    2462,
#    1932,
#    3,
#    1293,
#    193.95,
#    '4/16/2008 11:57:50'),
#   (85383, 97474, 11123, 24378, 4858, 2013, 1, 184, 27.6, '7/6/2008 12:15:48'),
#   (85437, 97531, 22445, 28409, 8396, 1865, 2, 592, 88.8, '2/8/2008 01:15:29'),
#   (85498, 97600, 3786, 4365, 4975, 2046, 1, 486, 72.9, '8/8/2008 02:13:23'),
#   (85673, 97806, 24841, 98, 5649, 2162, 1, 290, 43.5, '12/2/2008 05:29:10'),
#   (85705, 97839, 841, 98, 7894, 2086, 1, 383, 57.45, '9/17/2008 06:10:33'),
#   (85825, 97975, 39049, 28859, 94, 2046, 1, 160, 24.0, '8/8/2008 08:40:37'),
#   (85889, 98057, 42099, 24378, 8494, 1875, 1, 270, 40.5, '2/18/2008 10:04:17'),
#   (85909, 98077, 26397, 41262, 3190, 2080, 2, 518, 77.7, '9/11/2008 10:46:56'),
#   (86004, 98187, 32126, 10820, 2571, 1992, 1, 458, 68.7, '6/15/2008 12:51:21'),
#   (86225, 98442, 40872, 836, 7270, 1940, 4, 584, 87.6, '4/24/2008 05:14:28'),
#   (86255, 98477, 5084, 836, 6051, 2019, 4, 1156, 173.4, '7/12/2008 05:52:42'),
#   (86315, 98547, 26198, 20202, 2516, 1988, 1, 330, 49.5, '6/11/2008 06:50:09'),
#   (86322,
#    98549,
#    43992,
#    26469,
#    2946,
#    1943,
#    3,
#    1278,
#    191.7,
#    '4/27/2008 06:58:46'),
#   (86339,
#    98575,
#    40897,
#    10820,
#    5167,
#    1927,
#    1,
#    383,
#    57.45,
#    '4/11/2008 07:18:19'),
#   (86342, 98576, 34746, 1587, 5967, 2028, 2, 852, 127.8, '7/21/2008 07:23:27'),
#   (86519, 98768, 37992, 1737, 2117, 1961, 1, 434, 65.1, '5/15/2008 10:49:47'),
#   (86653, 98922, 9785, 836, 8210, 2055, 4, 1116, 167.4, '8/17/2008 01:16:54'),
#   (86739, 99029, 35463, 98, 2538, 2051, 1, 229, 34.35, '8/13/2008 02:57:29'),
#   (86771, 99075, 22077, 10513, 5062, 1945, 2, 630, 94.5, '4/29/2008 03:31:11'),
#   (86776,
#    99083,
#    37016,
#    40265,
#    8342,
#    2081,
#    4,
#    960,
#    144.0,
#    '9/12/2008 03:38:14'),
#   (86838, 99143, 10591, 3760, 1385, 1982, 1, 361, 54.15, '6/5/2008 04:44:28'),
#   (87020, 99343, 6326, 10186, 2721, 1978, 2, 876, 131.4, '6/1/2008 08:04:26'),
#   (87043, 99367, 7787, 28409, 8741, 1980, 2, 936, 140.4, '6/3/2008 08:28:15'),
#   (87159, 99530, 44911, 38158, 3831, 2000, 1, 71, 10.65, '6/23/2008 10:38:32'),
#   (87368,
#    99766,
#    32953,
#    33935,
#    5241,
#    2165,
#    2,
#    974,
#    146.1,
#    '12/5/2008 02:15:24'),
#   (87375, 99778, 25509, 3760, 2228, 1879, 1, 105, 15.75, '2/22/2008 02:21:55'),
#   (87472, 99881, 19504, 15424, 5017, 1938, 2, 46, 6.9, '4/22/2008 04:47:58'),
#   (87480, 99892, 31132, 1587, 8220, 1916, 2, 950, 142.5, '3/31/2008 04:53:11'),
#   (87565, 99994, 715, 10982, 8469, 1967, 2, 368, 55.2, '5/21/2008 06:16:48'),
#   (87768,
#    100246,
#    44851,
#    27208,
#    8028,
#    2095,
#    2,
#    888,
#    133.2,
#    '9/26/2008 10:01:47'),
#   (87769,
#    100246,
#    44851,
#    26052,
#    8028,
#    2094,
#    1,
#    444,
#    66.6,
#    '9/25/2008 10:02:02'),
#   (87939,
#    100430,
#    25315,
#    10982,
#    8296,
#    1881,
#    2,
#    874,
#    131.1,
#    '2/24/2008 01:22:23'),
#   (87956, 100450, 16530, 3760, 6677, 1879, 1, 180, 27.0, '2/22/2008 01:37:30'),
#   (87995,
#    100499,
#    33808,
#    27208,
#    1113,
#    1873,
#    2,
#    920,
#    138.0,
#    '2/16/2008 02:30:57'),
#   (88022,
#    100537,
#    22357,
#    10186,
#    1573,
#    1997,
#    2,
#    708,
#    106.2,
#    '6/20/2008 03:02:20'),
#   (88139,
#    100662,
#    9112,
#    10513,
#    7849,
#    2081,
#    2,
#    852,
#    127.8,
#    '9/12/2008 05:27:13'),
#   (88168,
#    100699,
#    29326,
#    7871,
#    1997,
#    2096,
#    4,
#    1884,
#    282.6,
#    '9/27/2008 05:56:49'),
#   (88270,
#    100813,
#    45818,
#    38158,
#    8649,
#    1872,
#    1,
#    209,
#    31.35,
#    '2/15/2008 07:28:56'),
#   (88414,
#    100973,
#    49949,
#    33935,
#    2146,
#    2128,
#    2,
#    604,
#    90.6,
#    '10/29/2008 10:15:14'),
#   (88514, 101132, 7359, 1737, 1211, 2107, 1, 243, 36.45, '10/8/2008 11:59:34'),
#   (88691,
#    101317,
#    42295,
#    23503,
#    3245,
#    2100,
#    1,
#    461,
#    69.15,
#    '10/1/2008 03:11:31'),
#   (88692, 101320, 38157, 8258, 4207, 2009, 1, 30, 4.5, '7/2/2008 03:15:54'),
#   (88712,
#    101343,
#    26484,
#    10982,
#    1414,
#    2023,
#    2,
#    130,
#    19.5,
#    '7/16/2008 03:38:18'),
#   (88732,
#    101362,
#    47062,
#    23130,
#    5843,
#    1989,
#    4,
#    776,
#    116.4,
#    '6/12/2008 03:52:03'),
#   (88774,
#    101406,
#    25144,
#    10513,
#    4834,
#    2156,
#    2,
#    934,
#    140.1,
#    '11/26/2008 04:40:20'),
#   (88856,
#    101508,
#    37676,
#    20010,
#    4404,
#    1966,
#    1,
#    297,
#    44.55,
#    '5/20/2008 06:17:53'),
#   (88874,
#    101532,
#    31270,
#    30651,
#    6470,
#    2034,
#    2,
#    718,
#    107.7,
#    '7/27/2008 06:40:54'),
#   (88898, 101551, 24140, 10513, 5512, 2014, 2, 302, 45.3, '7/7/2008 07:01:31'),
#   (88974,
#    101629,
#    18362,
#    38005,
#    8752,
#    2039,
#    2,
#    812,
#    121.8,
#    '8/1/2008 08:37:45'),
#   (89046,
#    101721,
#    15902,
#    28558,
#    2790,
#    2073,
#    4,
#    1852,
#    277.8,
#    '9/4/2008 10:08:50'),
#   (89067,
#    101735,
#    29025,
#    23130,
#    1285,
#    2087,
#    4,
#    1792,
#    268.8,
#    '9/18/2008 10:38:13'),
#   (89078, 101742, 38393, 28558, 7005, 1885, 4, 92, 13.8, '2/28/2008 10:47:00'),
#   (89102,
#    101773,
#    8982,
#    23503,
#    5834,
#    2179,
#    1,
#    374,
#    56.1,
#    '12/19/2008 11:14:21'),
#   (89220,
#    101895,
#    9837,
#    23503,
#    4088,
#    1881,
#    1,
#    285,
#    42.75,
#    '2/24/2008 01:35:06'),
#   (89225, 101899, 7127, 15424, 4441, 2064, 2, 526, 78.9, '8/26/2008 01:37:25'),
#   (89327,
#    101986,
#    3663,
#    23503,
#    2658,
#    2124,
#    1,
#    376,
#    56.4,
#    '10/25/2008 03:24:21'),
#   (89339,
#    102003,
#    10894,
#    38005,
#    6363,
#    2006,
#    2,
#    868,
#    130.2,
#    '6/29/2008 03:36:24'),
#   (89362, 102040, 1153, 1737, 4776, 1841, 1, 303, 45.45, '1/15/2008 03:56:28'),
#   (89391,
#    102078,
#    14122,
#    27208,
#    1685,
#    1968,
#    2,
#    746,
#    111.9,
#    '5/22/2008 04:37:04'),
#   (89504,
#    102221,
#    20021,
#    23944,
#    5189,
#    2156,
#    4,
#    592,
#    88.8,
#    '11/26/2008 06:43:29'),
#   (89873, 102627, 19725, 41892, 3431, 1890, 1, 422, 63.3, '3/5/2008 01:19:33'),
#   (89920, 102668, 25198, 1587, 5495, 1859, 2, 812, 121.8, '2/2/2008 02:12:04'),
#   (90116,
#    102859,
#    39485,
#    15424,
#    5289,
#    2126,
#    2,
#    946,
#    141.9,
#    '10/27/2008 06:18:25'),
#   (90360, 103160, 1631, 21004, 7495, 1910, 1, 40, 6.0, '3/25/2008 11:03:09'),
#   (90361, 103161, 16818, 10186, 7978, 2076, 1, 43, 6.45, '9/7/2008 11:04:38'),
#   (90371,
#    103170,
#    14762,
#    10186,
#    4987,
#    1875,
#    1,
#    307,
#    46.05,
#    '2/18/2008 11:21:00'),
#   (90435, 103241, 3381, 15424, 2680, 1889, 2, 586, 87.9, '3/4/2008 12:33:38'),
#   (90489, 103303, 33634, 7871, 6946, 2015, 4, 848, 127.2, '7/8/2008 01:50:45'),
#   (90513,
#    103332,
#    44655,
#    8258,
#    3231,
#    2141,
#    1,
#    468,
#    70.2,
#    '11/11/2008 02:16:41'),
#   (90874,
#    103723,
#    32477,
#    42638,
#    5803,
#    2156,
#    2,
#    816,
#    122.4,
#    '11/26/2008 09:23:03'),
#   (90876, 103728, 36235, 1587, 3016, 1861, 2, 656, 98.4, '2/4/2008 09:23:21'),
#   (90994,
#    103837,
#    36985,
#    10186,
#    5610,
#    2114,
#    1,
#    119,
#    17.85,
#    '10/15/2008 11:47:09'),
#   (91219, 104103, 9274, 23944, 2068, 2085, 4, 516, 77.4, '9/16/2008 03:56:18'),
#   (91304,
#    104214,
#    32487,
#    37408,
#    3111,
#    1872,
#    1,
#    432,
#    64.8,
#    '2/15/2008 05:38:29'),
#   (91317,
#    104232,
#    27847,
#    30651,
#    8218,
#    2064,
#    2,
#    384,
#    57.6,
#    '8/26/2008 05:48:25'),
#   (91388,
#    104299,
#    3808,
#    23571,
#    5132,
#    2024,
#    3,
#    1134,
#    170.1,
#    '7/17/2008 07:10:26'),
#   (91791,
#    104735,
#    47797,
#    23571,
#    8656,
#    1894,
#    3,
#    876,
#    131.4,
#    '3/9/2008 02:33:29'),
#   (91792, 104737, 1672, 10086, 3303, 1908, 4, 476, 71.4, '3/23/2008 02:33:33'),
#   (91809,
#    104755,
#    22264,
#    27208,
#    7566,
#    2155,
#    3,
#    1359,
#    203.85,
#    '11/25/2008 02:47:03'),
#   (91840,
#    104781,
#    21941,
#    8943,
#    4932,
#    2036,
#    4,
#    1952,
#    292.8,
#    '7/29/2008 03:19:29'),
#   (91845, 104788, 29175, 2390, 1878, 2073, 4, 704, 105.6, '9/4/2008 03:24:27'),
#   (91978,
#    104966,
#    14599,
#    7871,
#    7623,
#    1906,
#    4,
#    904,
#    135.6,
#    '3/21/2008 05:54:48'),
#   (92277, 105328, 42531, 30651, 2555, 2075, 2, 440, 66.0, '9/6/2008 11:30:26'),
#   (92339, 105392, 36478, 8258, 6808, 1846, 1, 468, 70.2, '1/20/2008 12:57:55'),
#   (92453,
#    105543,
#    27216,
#    25900,
#    1791,
#    1923,
#    2,
#    678,
#    101.7,
#    '4/7/2008 03:05:59'),
#   (92464, 105549, 10860, 42638, 7414, 2015, 2, 418, 62.7, '7/8/2008 03:20:04'),
#   (92476, 105562, 9716, 6707, 5140, 1890, 2, 632, 94.8, '3/5/2008 03:39:01'),
#   (92528,
#    105632,
#    24030,
#    8258,
#    2552,
#    2127,
#    1,
#    150,
#    22.5,
#    '10/28/2008 04:35:04'),
#   (92579, 105676, 14369, 2390, 404, 1908, 4, 484, 72.6, '3/23/2008 05:12:25'),
#   (92606,
#    105707,
#    34161,
#    38736,
#    5316,
#    2162,
#    3,
#    129,
#    19.35,
#    '12/2/2008 05:36:19'),
#   (92607, 105707, 34161, 38445, 5316, 2162, 1, 43, 6.45, '12/2/2008 05:36:40'),
#   (92662, 105775, 38887, 7871, 4590, 2021, 4, 276, 41.4, '7/14/2008 06:36:59'),
#   (92696,
#    105808,
#    43660,
#    20010,
#    4880,
#    1980,
#    1,
#    245,
#    36.75,
#    '6/3/2008 07:23:06'),
#   (92701, 105813, 31586, 10186, 7183, 2039, 1, 57, 8.55, '8/1/2008 07:35:55'),
#   (92942,
#    106075,
#    11660,
#    37408,
#    2584,
#    2105,
#    1,
#    442,
#    66.3,
#    '10/6/2008 12:35:48'),
#   (93117,
#    106288,
#    12064,
#    21004,
#    3245,
#    2095,
#    1,
#    182,
#    27.3,
#    '9/26/2008 03:41:19'),
#   (93148,
#    106329,
#    1738,
#    23571,
#    4261,
#    2041,
#    3,
#    711,
#    106.65,
#    '8/3/2008 04:20:11'),
#   (93241,
#    106446,
#    45502,
#    28585,
#    8323,
#    1997,
#    1,
#    274,
#    41.1,
#    '6/20/2008 06:10:01'),
#   (93246,
#    106454,
#    29720,
#    28347,
#    1380,
#    2130,
#    1,
#    442,
#    66.3,
#    '10/31/2008 06:17:07'),
#   (93282,
#    106503,
#    39192,
#    19419,
#    3366,
#    1940,
#    4,
#    1592,
#    238.8,
#    '4/24/2008 06:59:21'),
#   (93397, 106671, 2334, 19014, 1930, 1885, 4, 512, 76.8, '2/28/2008 09:20:06'),
#   (93547,
#    106822,
#    13831,
#    26667,
#    3428,
#    2096,
#    1,
#    254,
#    38.1,
#    '9/27/2008 12:13:30'),
#   (93612,
#    106905,
#    9186,
#    27208,
#    8656,
#    1882,
#    3,
#    783,
#    117.45,
#    '2/25/2008 01:20:59'),
#   ...])

# %%
# Get event information for all events that took place in a venue where the name ended in 'Stadium'
sq2 = """ SELECT e.*
          FROM event e
          JOIN venue v ON e.venue_id = v.venue_id
          WHERE v.venue_name LIKE '%Stadium';"""
run_query(sq2)
# Out:
# (['event_id', 'venue_id', 'cat_id', 'date_id', 'event_name', 'start_time'],
#  [(3803,
#    2,
#    9,
#    2181,
#    'Dropkick Murphys',
#    datetime.datetime(2008, 12, 21, 14, 0)),
#   (3816, 11, 9, 2139, 'Keb Mo', datetime.datetime(2008, 11, 9, 19, 0)),
#   (3821,
#    79,
#    9,
#    1885,
#    'Charlie Daniels Band',
#    datetime.datetime(2008, 2, 28, 19, 30)),
#   (3824, 98, 9, 1885, 'Govt Mule', datetime.datetime(2008, 2, 28, 14, 0)),
#   (3835, 74, 9, 2073, 'LeAnn Rimes', datetime.datetime(2008, 9, 4, 14, 30)),
#   (3837, 67, 9, 1850, 'Randy Travis', datetime.datetime(2008, 1, 24, 15, 0)),
#   (3840, 14, 9, 1876, 'Gwen Stefani', datetime.datetime(2008, 2, 19, 19, 30)),
#   (3843, 75, 9, 1986, 'Blake Shelton', datetime.datetime(2008, 6, 9, 14, 30)),
#   (3854, 6, 9, 1982, 'Gwen Stefani', datetime.datetime(2008, 6, 5, 15, 0)),
#   (3862, 116, 9, 1855, 'Teddy Geiger', datetime.datetime(2008, 1, 29, 19, 30)),
#   (3864, 75, 9, 1992, 'Celine Dion', datetime.datetime(2008, 6, 15, 15, 0)),
#   (3866, 72, 9, 1950, 'Cold War Kids', datetime.datetime(2008, 5, 1, 14, 0)),
#   (3869, 67, 9, 2115, 'Dave Stewart', datetime.datetime(2008, 10, 16, 20, 0)),
#   (3873, 11, 9, 2188, 'Avril Lavigne', datetime.datetime(2008, 12, 28, 14, 0)),
#   (3874, 129, 9, 1885, 'America', datetime.datetime(2008, 2, 28, 15, 0)),
#   (3889,
#    67,
#    9,
#    2108,
#    'Natasha Bedingfield',
#    datetime.datetime(2008, 10, 9, 19, 30)),
#   (3896,
#    14,
#    9,
#    1893,
#    'Natasha Bedingfield',
#    datetime.datetime(2008, 3, 8, 15, 0)),
#   (3899, 75, 9, 2089, 'Rusted Root', datetime.datetime(2008, 9, 20, 14, 0)),
#   (3901, 70, 9, 1861, 'Squeeze', datetime.datetime(2008, 2, 4, 14, 0)),
#   (3908,
#    74,
#    9,
#    2098,
#    'Sound Tribe Sector 9',
#    datetime.datetime(2008, 9, 29, 14, 0)),
#   (3909, 72, 9, 2190, 'Scorpions', datetime.datetime(2008, 12, 30, 14, 0)),
#   (3912, 103, 9, 1926, 'Nofx', datetime.datetime(2008, 4, 10, 19, 0)),
#   (3918, 74, 9, 1940, 'Gnarls Barkley', datetime.datetime(2008, 4, 24, 15, 0)),
#   (3925, 3, 9, 1864, 'Donny Osmond', datetime.datetime(2008, 2, 7, 14, 30)),
#   (3926, 72, 9, 1848, 'Neil Diamond', datetime.datetime(2008, 1, 22, 19, 30)),
#   (3927, 76, 9, 1925, 'Marc Anthony', datetime.datetime(2008, 4, 9, 14, 30)),
#   (3935,
#    116,
#    9,
#    2041,
#    'Los Lonely Boys',
#    datetime.datetime(2008, 8, 3, 15, 0)),
#   (3942, 108, 9, 2125, 'Teddy Geiger', datetime.datetime(2008, 10, 26, 20, 0)),
#   (3947, 98, 9, 1888, 'Eva Ayllon', datetime.datetime(2008, 3, 3, 20, 0)),
#   (3950,
#    98,
#    9,
#    2190,
#    'Martina McBride',
#    datetime.datetime(2008, 12, 30, 19, 0)),
#   (3956, 108, 9, 2102, 'Bad Company', datetime.datetime(2008, 10, 3, 19, 30)),
#   (3971,
#    74,
#    9,
#    1835,
#    'Toad The Wet Sprocket',
#    datetime.datetime(2008, 1, 9, 20, 0)),
#   (3985, 69, 9, 2057, 'Lenny Kravitz', datetime.datetime(2008, 8, 19, 20, 0)),
#   (3996, 71, 9, 1897, 'Umphreys McGee', datetime.datetime(2008, 3, 12, 19, 0)),
#   (3999, 2, 9, 1848, 'Soulfest', datetime.datetime(2008, 1, 22, 14, 30)),
#   (4001, 89, 9, 2139, 'Sigur Ros', datetime.datetime(2008, 11, 9, 15, 0)),
#   (4002, 69, 9, 1958, 'The National', datetime.datetime(2008, 5, 1, 14, 0)),
#   (4017,
#    79,
#    9,
#    2080,
#    'Earth Wind and Fire',
#    datetime.datetime(2008, 9, 11, 14, 0)),
#   (4019, 79, 9, 2185, 'U2', datetime.datetime(2008, 12, 25, 15, 0)),
#   (4033, 76, 9, 1900, 'Jason Mraz', datetime.datetime(2008, 3, 15, 15, 0)),
#   (4044,
#    71,
#    9,
#    1938,
#    'The Black Keys',
#    datetime.datetime(2008, 4, 22, 14, 30)),
#   (4049, 91, 9, 2141, 'Ted Nugent', datetime.datetime(2008, 11, 11, 19, 30)),
#   (4053,
#    13,
#    9,
#    1829,
#    'Sunday in the Country',
#    datetime.datetime(2008, 1, 3, 20, 0)),
#   (4055, 72, 9, 2023, 'Queensryche', datetime.datetime(2008, 7, 16, 20, 0)),
#   (4056, 11, 9, 2188, 'Conor Oberst', datetime.datetime(2008, 12, 28, 14, 30)),
#   (4062, 70, 9, 2100, 'Black Crowes', datetime.datetime(2008, 10, 1, 14, 0)),
#   (4063,
#    98,
#    9,
#    2171,
#    'Celtic Thunder',
#    datetime.datetime(2008, 12, 11, 15, 0)),
#   (4071, 92, 9, 2147, 'Nas', datetime.datetime(2008, 11, 17, 20, 0)),
#   (4073, 76, 9, 1931, 'Sheryl Crow', datetime.datetime(2008, 4, 15, 20, 0)),
#   (4077,
#    129,
#    9,
#    1848,
#    'Casting Crowns',
#    datetime.datetime(2008, 1, 22, 14, 0)),
#   (4079,
#    75,
#    9,
#    2024,
#    'Bullet for My Valentine',
#    datetime.datetime(2008, 7, 17, 20, 0)),
#   (4080, 67, 9, 2024, 'King Crimson', datetime.datetime(2008, 7, 17, 20, 0)),
#   (4093,
#    67,
#    9,
#    2079,
#    'Cute Is What We Aim For',
#    datetime.datetime(2008, 9, 10, 14, 0)),
#   (4094,
#    13,
#    9,
#    1931,
#    'George Thorogood and the Destroyers',
#    datetime.datetime(2008, 4, 15, 14, 30)),
#   (4096, 11, 9, 2189, 'Ryan Adams', datetime.datetime(2008, 12, 29, 19, 0)),
#   (4102, 98, 9, 2082, 'Nofx', datetime.datetime(2008, 9, 13, 19, 30)),
#   (4111, 13, 9, 1936, 'Erykah Badu', datetime.datetime(2008, 4, 20, 15, 0)),
#   (4114, 3, 9, 1942, 'Vince Gill', datetime.datetime(2008, 4, 26, 14, 0)),
#   (4116, 76, 9, 2026, 'Nashville Star', datetime.datetime(2008, 7, 19, 15, 0)),
#   (4124, 91, 9, 1883, 'Calibash', datetime.datetime(2008, 2, 26, 20, 0)),
#   (4125, 89, 9, 1960, 'Conor Oberst', datetime.datetime(2008, 5, 1, 14, 0)),
#   (4136,
#    92,
#    9,
#    2141,
#    'The Rowdy Frynds Tour',
#    datetime.datetime(2008, 11, 11, 20, 0)),
#   (4139,
#    103,
#    9,
#    1838,
#    'Charlie Daniels Band',
#    datetime.datetime(2008, 1, 12, 19, 30)),
#   (4141, 2, 9, 2046, 'Wolf Parade', datetime.datetime(2008, 8, 8, 19, 30)),
#   (4148, 119, 9, 2011, 'Motley Crue', datetime.datetime(2008, 7, 4, 14, 30)),
#   (4162, 13, 9, 2061, 'Killers', datetime.datetime(2008, 8, 23, 19, 0)),
#   (4168, 103, 9, 1913, 'Oasis', datetime.datetime(2008, 3, 28, 15, 0)),
#   (4170, 72, 9, 2045, 'Vampire Weekend', datetime.datetime(2008, 8, 7, 19, 0)),
#   (4174,
#    80,
#    9,
#    2072,
#    'Robert Plant and Alison Krauss',
#    datetime.datetime(2008, 9, 3, 14, 30)),
#   (4184, 14, 9, 2081, 'Colbie Caillat', datetime.datetime(2008, 9, 12, 19, 0)),
#   (4185,
#    103,
#    9,
#    1872,
#    'Smokey Robinson',
#    datetime.datetime(2008, 2, 15, 19, 0)),
#   (4188,
#    70,
#    9,
#    1883,
#    'Ray Lamontagne',
#    datetime.datetime(2008, 2, 26, 19, 30)),
#   (4191, 103, 9, 2040, 'Sara Bareilles', datetime.datetime(2008, 8, 2, 15, 0)),
#   (4200, 72, 9, 1908, 'Joe Satriani', datetime.datetime(2008, 3, 23, 14, 30)),
#   (4204,
#    70,
#    9,
#    2132,
#    'Teen Choice Awards',
#    datetime.datetime(2008, 11, 2, 14, 0)),
#   (4211,
#    14,
#    9,
#    1875,
#    'Rock To Win At the DNC',
#    datetime.datetime(2008, 2, 18, 14, 30)),
#   (4223, 108, 9, 1890, 'Luis Miguel', datetime.datetime(2008, 3, 5, 14, 0)),
#   (4239,
#    91,
#    9,
#    1973,
#    'Kool and The Gang',
#    datetime.datetime(2008, 5, 1, 15, 0)),
#   (4248, 119, 9, 1844, 'Godsmack', datetime.datetime(2008, 1, 18, 19, 30)),
#   (4251,
#    119,
#    9,
#    1907,
#    'Dave Matthews Band',
#    datetime.datetime(2008, 3, 22, 15, 0)),
#   (4259, 108, 9, 2118, 'Santana', datetime.datetime(2008, 10, 19, 15, 0)),
#   (4260, 74, 9, 2144, 'Eric Clapton', datetime.datetime(2008, 11, 14, 14, 0)),
#   (4265,
#    129,
#    9,
#    2142,
#    'Echo & the Bunnymen',
#    datetime.datetime(2008, 11, 12, 14, 30)),
#   (4268,
#    69,
#    9,
#    2084,
#    'Rock the Bells',
#    datetime.datetime(2008, 9, 15, 19, 30)),
#   (4278, 98, 9, 1901, 'Idina Menzel', datetime.datetime(2008, 3, 16, 14, 0)),
#   (4285, 81, 9, 2046, 'Eva Ayllon', datetime.datetime(2008, 8, 8, 14, 0)),
#   (4286,
#    91,
#    9,
#    2179,
#    'Counting Crows and Maroon 5',
#    datetime.datetime(2008, 12, 19, 19, 0)),
#   (4289, 3, 9, 1997, 'Stray Cats', datetime.datetime(2008, 6, 20, 19, 30)),
#   (4295, 74, 9, 2098, 'Kansas', datetime.datetime(2008, 9, 29, 19, 30)),
#   (4297, 119, 9, 1917, 'Nas', datetime.datetime(2008, 4, 1, 15, 0)),
#   (4302, 3, 9, 2018, 'Los Lonely Boys', datetime.datetime(2008, 7, 11, 20, 0)),
#   (4305, 116, 9, 1879, 'Jim Brickman', datetime.datetime(2008, 2, 22, 20, 0)),
#   (4306, 69, 9, 1832, 'Backstreet Boys', datetime.datetime(2008, 1, 6, 20, 0)),
#   (4311, 80, 9, 1989, 'Keb Mo', datetime.datetime(2008, 6, 12, 14, 0)),
#   (4312,
#    69,
#    9,
#    2024,
#    'Aretha Franklin',
#    datetime.datetime(2008, 7, 17, 19, 0)),
#   (4313, 98, 9, 2077, 'Jethro Tull', datetime.datetime(2008, 9, 8, 14, 0)),
#   (4320, 103, 9, 2046, 'Extreme', datetime.datetime(2008, 8, 8, 19, 30)),
#   (4323,
#    74,
#    9,
#    2170,
#    'Huey Lewis and the News',
#    datetime.datetime(2008, 12, 10, 20, 0)),
#   (4329, 71, 9, 1844, 'Neil Diamond', datetime.datetime(2008, 1, 18, 19, 0)),
#   (4330,
#    13,
#    9,
#    1967,
#    'Marco Antonio Solis',
#    datetime.datetime(2008, 5, 1, 14, 0)),
#   (4331,
#    89,
#    9,
#    2020,
#    'Trisha Yearwood',
#    datetime.datetime(2008, 7, 13, 20, 0)),
#   (4351,
#    76,
#    9,
#    1914,
#    'Sunday in the Country',
#    datetime.datetime(2008, 3, 29, 19, 30)),
#   (4353, 13, 9, 1846, 'Bruce Hornsby', datetime.datetime(2008, 1, 20, 19, 0)),
#   (4359,
#    103,
#    9,
#    2116,
#    'Country Jam USA',
#    datetime.datetime(2008, 10, 17, 14, 30)),
#   (4370,
#    116,
#    9,
#    2154,
#    'George Thorogood and the Destroyers',
#    datetime.datetime(2008, 11, 24, 20, 0)),
#   (4374, 74, 9, 2161, 'Dolly Parton', datetime.datetime(2008, 12, 1, 20, 0)),
#   (4378, 5, 9, 1853, 'Cafe Tacuba', datetime.datetime(2008, 1, 27, 19, 30)),
#   (4380, 5, 9, 2146, 'Bow Wow', datetime.datetime(2008, 11, 16, 19, 30)),
#   (4381, 69, 9, 1866, 'Jonas Brothers', datetime.datetime(2008, 2, 9, 14, 30)),
#   (4390, 76, 9, 1860, 'Missy Higgins', datetime.datetime(2008, 2, 3, 14, 0)),
#   (4394, 6, 9, 1830, 'Led Zeppelin', datetime.datetime(2008, 1, 4, 14, 30)),
#   (4403,
#    108,
#    9,
#    1859,
#    'Vampire Weekend',
#    datetime.datetime(2008, 2, 2, 20, 0)),
#   (4408, 89, 9, 2029, 'Jack Johnson', datetime.datetime(2008, 7, 22, 19, 0)),
#   (4409, 103, 9, 2085, 'Black Kids', datetime.datetime(2008, 9, 16, 15, 0)),
#   (4415,
#    5,
#    9,
#    1858,
#    'Dave Matthews Band',
#    datetime.datetime(2008, 2, 1, 15, 0)),
#   (4419, 14, 9, 1910, 'Boston', datetime.datetime(2008, 3, 25, 19, 0)),
#   (4425,
#    79,
#    9,
#    1999,
#    'Engelbert Humperdinck',
#    datetime.datetime(2008, 6, 22, 14, 30)),
#   (4429,
#    14,
#    9,
#    2139,
#    'Montgomery Gentry',
#    datetime.datetime(2008, 11, 9, 14, 0)),
#   (4436,
#    70,
#    9,
#    1873,
#    'George Thorogood',
#    datetime.datetime(2008, 2, 16, 20, 0)),
#   (4439, 79, 9, 2162, 'Cypress Hill', datetime.datetime(2008, 12, 2, 15, 0)),
#   (4440, 71, 9, 1956, 'The Who', datetime.datetime(2008, 5, 1, 14, 30)),
#   (4446, 129, 9, 2155, 'O.A.R.', datetime.datetime(2008, 11, 25, 19, 0)),
#   (4450, 76, 9, 2063, 'Jesse Lacey', datetime.datetime(2008, 8, 25, 20, 0)),
#   (4451, 70, 9, 2053, 'Garth Brooks', datetime.datetime(2008, 8, 15, 20, 0)),
#   (4463, 6, 9, 2128, 'Third Day', datetime.datetime(2008, 10, 29, 14, 0)),
#   (4473,
#    71,
#    9,
#    2114,
#    'Wisin y Yandel',
#    datetime.datetime(2008, 10, 15, 14, 30)),
#   (4493,
#    116,
#    9,
#    2060,
#    'Flogging Molly',
#    datetime.datetime(2008, 8, 22, 14, 30)),
#   (4501, 89, 9, 1934, 'Rock the Bells', datetime.datetime(2008, 4, 18, 15, 0)),
#   (4506,
#    98,
#    9,
#    2104,
#    'Weird Al Yankovic',
#    datetime.datetime(2008, 10, 5, 15, 0)),
#   (4508,
#    74,
#    9,
#    1913,
#    'Black Eyed Peas',
#    datetime.datetime(2008, 3, 28, 20, 0)),
#   (4538, 72, 9, 1929, 'Dennis DeYoung', datetime.datetime(2008, 4, 13, 15, 0)),
#   (4549, 79, 9, 2048, 'Boston', datetime.datetime(2008, 8, 10, 19, 30)),
#   (4551, 103, 9, 1939, 'Zucchero', datetime.datetime(2008, 4, 23, 14, 0)),
#   (4554, 74, 9, 1901, 'Regina Spektor', datetime.datetime(2008, 3, 16, 14, 0)),
#   (4563, 89, 9, 1830, 'Killers', datetime.datetime(2008, 1, 4, 20, 0)),
#   (4566, 119, 9, 2125, 'The Who', datetime.datetime(2008, 10, 26, 19, 0)),
#   (4567, 129, 9, 1910, 'Chris Isaak', datetime.datetime(2008, 3, 25, 14, 30)),
#   (4569,
#    80,
#    9,
#    2047,
#    'Lucinda Williams',
#    datetime.datetime(2008, 8, 9, 14, 30)),
#   (4570, 74, 9, 1991, 'Commodores', datetime.datetime(2008, 6, 14, 15, 0)),
#   (4572,
#    14,
#    9,
#    2143,
#    'Gogol Bordello',
#    datetime.datetime(2008, 11, 13, 20, 0)),
#   (4580, 13, 9, 2134, 'Steely Dan', datetime.datetime(2008, 11, 4, 19, 30)),
#   (4609, 5, 9, 1830, 'Los Temerarios', datetime.datetime(2008, 1, 4, 15, 0)),
#   (4611, 98, 9, 2012, 'Jill Scott', datetime.datetime(2008, 7, 5, 14, 30)),
#   (4612, 70, 9, 2041, 'Casting Crowns', datetime.datetime(2008, 8, 3, 19, 30)),
#   (4615,
#    81,
#    9,
#    1835,
#    'Smokey Robinson',
#    datetime.datetime(2008, 1, 9, 14, 30)),
#   (4619, 6, 9, 1973, 'Trisha Yearwood', datetime.datetime(2008, 5, 1, 15, 0)),
#   (4623, 6, 9, 2052, 'Neil Diamond', datetime.datetime(2008, 8, 14, 19, 0)),
#   (4626, 76, 9, 1957, 'Alice Cooper', datetime.datetime(2008, 5, 1, 19, 30)),
#   (4630,
#    108,
#    9,
#    2050,
#    'George Michael',
#    datetime.datetime(2008, 8, 12, 14, 0)),
#   (4632, 116, 9, 1869, 'Tesla', datetime.datetime(2008, 2, 12, 15, 0)),
#   (4634, 70, 9, 1906, 'Zucchero', datetime.datetime(2008, 3, 21, 14, 0)),
#   (4636, 89, 9, 2000, 'Motorhead', datetime.datetime(2008, 6, 23, 20, 0)),
#   (4638,
#    72,
#    9,
#    2099,
#    'Sarah Brightman',
#    datetime.datetime(2008, 9, 30, 20, 0)),
#   (4641,
#    92,
#    9,
#    1983,
#    'Smokey Robinson',
#    datetime.datetime(2008, 6, 6, 14, 30)),
#   (4644, 13, 9, 2125, 'Dj Tiesto', datetime.datetime(2008, 10, 26, 14, 0)),
#   (4646, 92, 9, 1914, 'Duffy', datetime.datetime(2008, 3, 29, 19, 0)),
#   (4652, 3, 9, 1934, 'The National', datetime.datetime(2008, 4, 18, 19, 0)),
#   (4654, 13, 9, 1886, 'Maze', datetime.datetime(2008, 3, 1, 15, 0)),
#   (4655, 92, 9, 1972, 'Queensryche', datetime.datetime(2008, 5, 1, 15, 0)),
#   (4657, 108, 9, 2011, 'Phil Vassar', datetime.datetime(2008, 7, 4, 14, 0)),
#   (4666, 70, 9, 2090, 'Sugarland', datetime.datetime(2008, 9, 21, 15, 0)),
#   (4668, 14, 9, 2114, 'Duran Duran', datetime.datetime(2008, 10, 15, 15, 0)),
#   (4670, 69, 9, 1919, 'Foo Fighters', datetime.datetime(2008, 4, 3, 15, 0)),
#   (4672, 13, 9, 1923, 'The Police', datetime.datetime(2008, 4, 7, 19, 0)),
#   (4673,
#    14,
#    9,
#    2117,
#    'Burt Bacharach',
#    datetime.datetime(2008, 10, 18, 19, 0)),
#   (4674, 98, 9, 2078, 'Jethro Tull', datetime.datetime(2008, 9, 9, 19, 0)),
#   (4677, 98, 9, 2129, 'KT Tunstall', datetime.datetime(2008, 10, 30, 14, 0)),
#   (4686,
#    70,
#    9,
#    1984,
#    'Rodrigo y Gabriela',
#    datetime.datetime(2008, 6, 7, 20, 0)),
#   (4711, 2, 9, 1829, 'Carrie Underwood', datetime.datetime(2008, 1, 3, 19, 0)),
#   (4715, 116, 9, 2010, 'Poison', datetime.datetime(2008, 7, 3, 14, 0)),
#   (4723, 79, 9, 2168, 'Foreigner', datetime.datetime(2008, 12, 8, 19, 30)),
#   (4730, 79, 9, 1889, 'Mars Volta', datetime.datetime(2008, 3, 4, 19, 0)),
#   (4731, 91, 9, 1831, 'Flogging Molly', datetime.datetime(2008, 1, 5, 14, 0)),
#   (4733, 14, 9, 2096, 'John Prine', datetime.datetime(2008, 9, 27, 20, 0)),
#   (4734, 75, 9, 1869, 'Fergie', datetime.datetime(2008, 2, 12, 19, 0)),
#   (4737, 67, 9, 2102, 'Gnarls Barkley', datetime.datetime(2008, 10, 3, 19, 0)),
#   (4738, 80, 9, 2043, 'Ben Harper', datetime.datetime(2008, 8, 5, 14, 30)),
#   (4741, 5, 9, 2164, 'Spoon', datetime.datetime(2008, 12, 4, 19, 0)),
#   (4746,
#    70,
#    9,
#    2173,
#    'Jerry Jeff Walker',
#    datetime.datetime(2008, 12, 13, 20, 0)),
#   (4753, 72, 9, 2015, 'John Hiatt', datetime.datetime(2008, 7, 8, 15, 0)),
#   (4756,
#    74,
#    9,
#    2142,
#    'Sara Bareilles',
#    datetime.datetime(2008, 11, 12, 19, 0)),
#   (4760, 119, 9, 1918, 'Jimmy Buffett', datetime.datetime(2008, 4, 2, 20, 0)),
#   (4761, 80, 9, 1899, 'Wolf Parade', datetime.datetime(2008, 3, 14, 14, 30)),
#   (4769, 2, 9, 2075, 'Neville Brothers', datetime.datetime(2008, 9, 6, 15, 0)),
#   (4771, 98, 9, 2111, 'Black Crowes', datetime.datetime(2008, 10, 12, 19, 0)),
#   (4780, 80, 9, 1927, 'Gladys Knight', datetime.datetime(2008, 4, 11, 14, 0)),
#   (4781, 14, 9, 2008, 'Sara Bareilles', datetime.datetime(2008, 7, 1, 19, 30)),
#   (4800, 76, 9, 2157, 'Girl Talk', datetime.datetime(2008, 11, 27, 19, 30)),
#   (4802, 70, 9, 1849, 'Nas', datetime.datetime(2008, 1, 23, 15, 0)),
#   (4804, 119, 9, 1878, 'Decemberists', datetime.datetime(2008, 2, 21, 19, 30)),
#   (4807, 108, 9, 2178, 'Judas Priest', datetime.datetime(2008, 12, 18, 19, 0)),
#   (4816, 74, 9, 1971, 'Santana', datetime.datetime(2008, 5, 1, 15, 0)),
#   (4822,
#    13,
#    9,
#    2155,
#    'Colbie Caillat',
#    datetime.datetime(2008, 11, 25, 14, 0)),
#   (4824, 74, 9, 2106, 'Sara Bareilles', datetime.datetime(2008, 10, 7, 14, 0)),
#   (4825, 13, 9, 2172, 'N.E.R.D.', datetime.datetime(2008, 12, 12, 15, 0)),
#   (4826,
#    71,
#    9,
#    1847,
#    'Jerry Jeff Walker',
#    datetime.datetime(2008, 1, 21, 19, 30)),
#   (4828,
#    14,
#    9,
#    2076,
#    'Oliver Dragojevic',
#    datetime.datetime(2008, 9, 7, 15, 0)),
#   (4830, 14, 9, 1875, 'Maze', datetime.datetime(2008, 2, 18, 19, 0)),
#   (4834, 89, 9, 2161, 'Regina Spektor', datetime.datetime(2008, 12, 1, 14, 0)),
#   (4840, 69, 9, 2174, 'Sara Evans', datetime.datetime(2008, 12, 14, 14, 0)),
#   (4841,
#    91,
#    9,
#    2005,
#    'Vampire Weekend',
#    datetime.datetime(2008, 6, 28, 19, 30)),
#   (4844, 129, 9, 1891, 'Herbie Hancock', datetime.datetime(2008, 3, 6, 19, 0)),
#   (4850,
#    91,
#    9,
#    1827,
#    'Zappa Plays Zappa',
#    datetime.datetime(2008, 1, 1, 14, 0)),
#   (4852, 129, 9, 2037, 'Mark Knopfler', datetime.datetime(2008, 7, 30, 19, 0)),
#   (4857, 108, 9, 2134, 'The Guess Who', datetime.datetime(2008, 11, 4, 19, 0)),
#   (4858, 81, 9, 2024, 'Ray Davies', datetime.datetime(2008, 7, 17, 14, 0)),
#   (4860,
#    5,
#    9,
#    2045,
#    'Vicente Fernandez',
#    datetime.datetime(2008, 8, 7, 15, 0)),
#   (4867, 119, 9, 1849, 'Clint Black', datetime.datetime(2008, 1, 23, 19, 30)),
#   (4874,
#    75,
#    9,
#    1944,
#    'Zappa Plays Zappa',
#    datetime.datetime(2008, 4, 28, 15, 0)),
#   (4876, 67, 9, 2059, 'Brian McKnight', datetime.datetime(2008, 8, 21, 19, 0)),
#   (4886,
#    2,
#    9,
#    2156,
#    'Weird Al Yankovic',
#    datetime.datetime(2008, 11, 26, 19, 30)),
#   (4887,
#    70,
#    9,
#    1849,
#    'Tom Petty and the Heartbreakers',
#    datetime.datetime(2008, 1, 23, 15, 0)),
#   (4891, 92, 9, 1963, 'Rusted Root', datetime.datetime(2008, 5, 1, 19, 0)),
#   (4894, 70, 9, 1890, 'Maze', datetime.datetime(2008, 3, 5, 19, 0)),
#   (4896,
#    67,
#    9,
#    1944,
#    'Guitars and Saxes',
#    datetime.datetime(2008, 4, 28, 15, 0)),
#   (4900, 71, 9, 2017, 'Iron and Wine', datetime.datetime(2008, 7, 10, 19, 30)),
#   (4902, 74, 9, 2163, 'The Who', datetime.datetime(2008, 12, 3, 15, 0)),
#   (4908,
#    14,
#    9,
#    1910,
#    'Celtic Thunder',
#    datetime.datetime(2008, 3, 25, 19, 30)),
#   (4914,
#    71,
#    9,
#    2040,
#    'Country Jam USA',
#    datetime.datetime(2008, 8, 2, 19, 30)),
#   (4915, 69, 9, 1832, 'Duran Duran', datetime.datetime(2008, 1, 6, 19, 30)),
#   (4916, 11, 9, 2096, 'Alan Jackson', datetime.datetime(2008, 9, 27, 15, 0)),
#   (4918, 14, 9, 2153, 'Brad Paisley', datetime.datetime(2008, 11, 23, 14, 0)),
#   (4920, 3, 9, 1955, 'Led Zeppelin', datetime.datetime(2008, 5, 1, 19, 30)),
#   (4940, 119, 9, 1990, 'Clint Black', datetime.datetime(2008, 6, 13, 19, 30)),
#   (4958, 76, 9, 2167, 'Kanye West', datetime.datetime(2008, 12, 7, 15, 0)),
#   (4960,
#    6,
#    9,
#    2046,
#    'Dave Matthews Band',
#    datetime.datetime(2008, 8, 8, 19, 0)),
#   (4963,
#    129,
#    9,
#    2013,
#    'Hermans Hermits',
#    datetime.datetime(2008, 7, 6, 19, 0)),
#   (4964,
#    119,
#    9,
#    2034,
#    'Steven Curtis Chapman',
#    datetime.datetime(2008, 7, 27, 19, 30)),
#   (4969, 71, 9, 1919, 'Sara Evans', datetime.datetime(2008, 4, 3, 15, 0)),
#   (4971,
#    6,
#    9,
#    2164,
#    'Justin Timberlake',
#    datetime.datetime(2008, 12, 4, 15, 0)),
#   (4983, 75, 9, 1929, 'Gary Allan', datetime.datetime(2008, 4, 13, 15, 0)),
#   (4988,
#    71,
#    9,
#    2061,
#    'Bamboozle Left',
#    datetime.datetime(2008, 8, 23, 19, 30)),
#   (4992,
#    103,
#    9,
#    2088,
#    'Little River Band',
#    datetime.datetime(2008, 9, 19, 14, 0)),
#   (4998, 70, 9, 2078, 'Tower of Power', datetime.datetime(2008, 9, 9, 15, 0)),
#   (5017, 76, 9, 1957, '3 Doors Down', datetime.datetime(2008, 5, 1, 19, 30)),
#   (5021, 79, 9, 2133, 'David Sanborn', datetime.datetime(2008, 11, 3, 19, 30)),
#   (5024, 92, 9, 2077, 'Paramore', datetime.datetime(2008, 9, 8, 15, 0)),
#   (5037, 67, 9, 1951, 'Keb Mo', datetime.datetime(2008, 5, 1, 15, 0)),
#   (5040, 11, 9, 1917, 'War', datetime.datetime(2008, 4, 1, 15, 0)),
#   (5043, 6, 9, 1894, 'Alicia Keys', datetime.datetime(2008, 3, 9, 19, 30)),
#   (5046, 74, 9, 2001, 'Celtic Thunder', datetime.datetime(2008, 6, 24, 15, 0)),
#   (5055,
#    3,
#    9,
#    2035,
#    'Sweet Honey in the Rock',
#    datetime.datetime(2008, 7, 28, 15, 0)),
#   (5069,
#    69,
#    9,
#    1834,
#    'Smashing Pumpkins',
#    datetime.datetime(2008, 1, 8, 19, 30)),
#   (5070, 70, 9, 2185, '.38 Special', datetime.datetime(2008, 12, 25, 15, 0)),
#   (5071, 75, 9, 1850, 'Bette Midler', datetime.datetime(2008, 1, 24, 19, 30)),
#   (5074, 103, 9, 1968, 'Rush', datetime.datetime(2008, 5, 1, 15, 0)),
#   (5085,
#    89,
#    9,
#    1930,
#    'Barenaked Ladies',
#    datetime.datetime(2008, 4, 14, 19, 0)),
#   (5094, 70, 9, 1961, 'Ryan Adams', datetime.datetime(2008, 5, 1, 19, 30)),
#   (5097, 98, 9, 1863, 'Sigur Ros', datetime.datetime(2008, 2, 6, 19, 0)),
#   (5108, 71, 9, 1874, 'Bon Jovi', datetime.datetime(2008, 2, 17, 19, 0)),
#   (5110, 71, 9, 1863, 'Nofx', datetime.datetime(2008, 2, 6, 19, 30)),
#   (5112, 80, 9, 1843, 'Michael Buble', datetime.datetime(2008, 1, 17, 19, 30)),
#   (5113, 71, 9, 2059, 'Lynyrd Skynyrd', datetime.datetime(2008, 8, 21, 19, 0)),
#   (5120, 80, 9, 2010, 'Radiohead', datetime.datetime(2008, 7, 3, 15, 0)),
#   (5146, 98, 9, 1979, 'Janet Jackson', datetime.datetime(2008, 6, 2, 14, 0)),
#   (5150,
#    75,
#    9,
#    2072,
#    'Earth Wind and Fire',
#    datetime.datetime(2008, 9, 3, 15, 0)),
#   (5153, 67, 9, 1919, 'Old 97s', datetime.datetime(2008, 4, 3, 19, 30)),
#   (5157, 76, 9, 1879, 'Janet Jackson', datetime.datetime(2008, 2, 22, 15, 0)),
#   (5158,
#    119,
#    9,
#    2126,
#    'Michael Bolton',
#    datetime.datetime(2008, 10, 27, 19, 0)),
#   (5164,
#    71,
#    9,
#    2088,
#    'Enrique Iglesias',
#    datetime.datetime(2008, 9, 19, 15, 0)),
#   (5166, 3, 9, 2101, 'Tony Bennett', datetime.datetime(2008, 10, 2, 19, 0)),
#   (5176,
#    80,
#    9,
#    2094,
#    'Blue Man Group How To Be A Megastar Tour',
#    datetime.datetime(2008, 9, 25, 19, 0)),
#   (5177, 6, 9, 2131, 'Nashville Star', datetime.datetime(2008, 11, 1, 14, 0)),
#   (5186,
#    71,
#    9,
#    2159,
#    'Insane Clown Posse',
#    datetime.datetime(2008, 11, 29, 14, 0)),
#   (5195, 108, 9, 1846, 'Eddie Vedder', datetime.datetime(2008, 1, 20, 14, 0)),
#   (5204,
#    116,
#    9,
#    1923,
#    'Alejandro Fernandez',
#    datetime.datetime(2008, 4, 7, 14, 0)),
#   (5208,
#    76,
#    9,
#    1960,
#    'Michael McDonald',
#    datetime.datetime(2008, 5, 1, 14, 0)),
#   (5213, 119, 9, 1909, 'Eagles', datetime.datetime(2008, 3, 24, 19, 30)),
#   (5223, 69, 9, 2081, 'Old 97s', datetime.datetime(2008, 9, 12, 14, 0)),
#   (5229, 81, 9, 1976, 'Rancid', datetime.datetime(2008, 5, 1, 15, 0)),
#   (5232, 71, 9, 1958, 'Lionel Richie', datetime.datetime(2008, 5, 1, 19, 30)),
#   (5242, 75, 9, 2047, 'Chris Isaak', datetime.datetime(2008, 8, 9, 14, 0)),
#   (5246, 76, 9, 1839, 'Killing Joke', datetime.datetime(2008, 1, 13, 19, 0)),
#   (5252, 14, 9, 2043, 'B.B. King', datetime.datetime(2008, 8, 5, 14, 0)),
#   (5262, 69, 9, 2035, 'John Fogerty', datetime.datetime(2008, 7, 28, 19, 30)),
#   (5268, 2, 9, 2100, 'Nine Inch Nails', datetime.datetime(2008, 10, 1, 19, 0)),
#   (5271, 119, 9, 1908, 'Iron and Wine', datetime.datetime(2008, 3, 23, 14, 0)),
#   (5274, 129, 9, 2035, 'Keb Mo', datetime.datetime(2008, 7, 28, 15, 0)),
#   (5280, 6, 9, 2170, 'Boston', datetime.datetime(2008, 12, 10, 19, 0)),
#   (5282,
#    75,
#    9,
#    2035,
#    'El Monstero y Los Masked Avengers',
#    datetime.datetime(2008, 7, 28, 15, 0)),
#   (5283, 3, 9, 1980, 'Paul Weller', datetime.datetime(2008, 6, 3, 19, 30)),
#   (5293, 89, 9, 1955, 'Trace Adkins', datetime.datetime(2008, 5, 1, 14, 0)),
#   (5294,
#    72,
#    9,
#    1963,
#    'Bruce Springsteen',
#    datetime.datetime(2008, 5, 1, 19, 30)),
#   (5295, 119, 9, 1924, 'Commodores', datetime.datetime(2008, 4, 8, 19, 30)),
#   (5296, 72, 9, 2032, 'John Hiatt', datetime.datetime(2008, 7, 25, 19, 0)),
#   (5303, 98, 9, 1893, 'Donny Osmond', datetime.datetime(2008, 3, 8, 19, 0)),
#   (5307, 103, 9, 1982, 'Kenny Chesney', datetime.datetime(2008, 6, 5, 15, 0)),
#   (5311, 5, 9, 2024, 'Dolly Parton', datetime.datetime(2008, 7, 17, 15, 0)),
#   (5314, 92, 9, 2190, 'Aimee Mann', datetime.datetime(2008, 12, 30, 19, 0)),
#   (5319, 70, 9, 1951, 'Zombies', datetime.datetime(2008, 5, 1, 15, 0)),
#   (5322, 3, 9, 1930, 'Green Day', datetime.datetime(2008, 4, 14, 14, 0)),
#   (5331,
#    13,
#    9,
#    1853,
#    'Toad The Wet Sprocket',
#    datetime.datetime(2008, 1, 27, 19, 30)),
#   (5336,
#    69,
#    9,
#    2144,
#    'Insane Clown Posse',
#    datetime.datetime(2008, 11, 14, 15, 0)),
#   (5337, 2, 9, 2020, 'Matisyahu', datetime.datetime(2008, 7, 13, 19, 0)),
#   (5338,
#    116,
#    9,
#    1836,
#    'Hall and Oates',
#    datetime.datetime(2008, 1, 10, 19, 0)),
#   (5342,
#    5,
#    9,
#    2064,
#    'Dickey Betts and Great Southern',
#    datetime.datetime(2008, 8, 26, 19, 30)),
#   (5348,
#    81,
#    9,
#    2180,
#    'Vans Warped Tour',
#    datetime.datetime(2008, 12, 20, 15, 0)),
#   (5352, 72, 9, 2102, 'Live', datetime.datetime(2008, 10, 3, 19, 0)),
#   (5353, 69, 9, 1923, 'George Michael', datetime.datetime(2008, 4, 7, 14, 0)),
#   (5354, 3, 9, 2026, 'Marc Anthony', datetime.datetime(2008, 7, 19, 19, 0)),
#   (5368, 69, 9, 1997, 'Spoon', datetime.datetime(2008, 6, 20, 19, 30)),
#   (5374, 98, 9, 1959, 'Soulfest', datetime.datetime(2008, 5, 1, 19, 30)),
#   (5393, 71, 9, 1932, 'Ted Nugent', datetime.datetime(2008, 4, 16, 19, 0)),
#   (5401, 116, 9, 2080, 'Queensryche', datetime.datetime(2008, 9, 11, 15, 0)),
#   (5405, 71, 9, 1958, 'Travis Tritt', datetime.datetime(2008, 5, 1, 19, 0)),
#   (5406, 91, 9, 1938, 'Blues Brothers', datetime.datetime(2008, 4, 22, 15, 0)),
#   (5410, 91, 9, 2002, 'Hot Tuna', datetime.datetime(2008, 6, 25, 19, 30)),
#   (5412,
#    81,
#    9,
#    2122,
#    'My Bloody Valentine',
#    datetime.datetime(2008, 10, 23, 19, 30)),
#   (5426, 75, 9, 2047, 'Little Big Town', datetime.datetime(2008, 8, 9, 14, 0)),
#   (5428, 72, 9, 1999, 'Celine Dion', datetime.datetime(2008, 6, 22, 19, 0)),
#   (5432, 14, 9, 2178, 'Erykah Badu', datetime.datetime(2008, 12, 18, 19, 30)),
#   (5442,
#    69,
#    9,
#    2153,
#    'Rick Springfield',
#    datetime.datetime(2008, 11, 23, 15, 0)),
#   (5450, 70, 9, 2063, 'Girl Talk', datetime.datetime(2008, 8, 25, 14, 0)),
#   (5453,
#    13,
#    9,
#    1888,
#    'El Monstero y Los Masked Avengers',
#    datetime.datetime(2008, 3, 3, 14, 0)),
#   (5463, 70, 9, 1871, 'Peter Frampton', datetime.datetime(2008, 2, 14, 14, 0)),
#   (5465, 74, 9, 1869, 'Journey', datetime.datetime(2008, 2, 12, 14, 0)),
#   (5475, 98, 9, 1828, 'Demi Lovato', datetime.datetime(2008, 1, 2, 19, 30)),
#   (5480, 13, 9, 2162, 'Sammy Hagar', datetime.datetime(2008, 12, 2, 19, 30)),
#   (5489,
#    91,
#    9,
#    2151,
#    'Emmylou Harris',
#    datetime.datetime(2008, 11, 21, 15, 0)),
#   (5491, 81, 9, 2167, 'Joe Cocker', datetime.datetime(2008, 12, 7, 14, 0)),
#   (5498, 76, 9, 2037, 'The Guess Who', datetime.datetime(2008, 7, 30, 19, 0)),
#   (5501, 92, 9, 1903, 'Chicago', datetime.datetime(2008, 3, 18, 19, 0)),
#   (5504,
#    70,
#    9,
#    2187,
#    'Patty Griffin',
#    datetime.datetime(2008, 12, 27, 19, 30)),
#   (5510,
#    70,
#    9,
#    2048,
#    'Rick Springfield',
#    datetime.datetime(2008, 8, 10, 14, 0)),
#   (5515, 11, 9, 1830, 'Foreigner', datetime.datetime(2008, 1, 4, 14, 0)),
#   (5517, 108, 9, 1840, 'Joan Baez', datetime.datetime(2008, 1, 14, 19, 30)),
#   (5519, 89, 9, 2034, 'Bob Dylan', datetime.datetime(2008, 7, 27, 19, 30)),
#   (5526, 129, 9, 2181, 'Live', datetime.datetime(2008, 12, 21, 15, 0)),
#   (5527, 92, 9, 1857, 'Suzanne Vega', datetime.datetime(2008, 1, 31, 14, 0)),
#   (5530, 89, 9, 1980, 'James Taylor', datetime.datetime(2008, 6, 3, 19, 0)),
#   (5547, 74, 9, 1950, 'Tina Turner', datetime.datetime(2008, 5, 1, 14, 0)),
#   (5573, 2, 9, 1866, 'Bo Bice', datetime.datetime(2008, 2, 9, 19, 0)),
#   (5574, 129, 9, 1890, 'Bon Jovi', datetime.datetime(2008, 3, 5, 19, 30)),
#   (5578, 6, 9, 2186, 'Keb Mo', datetime.datetime(2008, 12, 26, 19, 30)),
#   (5581, 80, 9, 2175, 'James Blunt', datetime.datetime(2008, 12, 15, 19, 0)),
#   (5584, 11, 9, 1966, 'Ray Lamontagne', datetime.datetime(2008, 5, 1, 15, 0)),
#   (5588, 81, 9, 2037, 'Chromeo', datetime.datetime(2008, 7, 30, 19, 30)),
#   (5592, 119, 9, 2157, 'Ben Harper', datetime.datetime(2008, 11, 27, 14, 0)),
#   (5595,
#    116,
#    9,
#    2012,
#    'Rick Springfield',
#    datetime.datetime(2008, 7, 5, 14, 0)),
#   (5596,
#    92,
#    9,
#    1861,
#    'Tokyo Police Club',
#    datetime.datetime(2008, 2, 4, 15, 0)),
#   (5598, 79, 9, 1870, 'Tower of Power', datetime.datetime(2008, 2, 13, 15, 0)),
#   (5599,
#    116,
#    9,
#    2177,
#    'Iggy and the Stooges',
#    datetime.datetime(2008, 12, 17, 14, 0)),
#   (5610,
#    79,
#    9,
#    2152,
#    'Hannah Montana',
#    datetime.datetime(2008, 11, 22, 19, 0)),
#   (5617, 14, 9, 1967, 'Ani DiFranco', datetime.datetime(2008, 5, 1, 15, 0)),
#   (5620, 67, 9, 2135, 'Ice Cube', datetime.datetime(2008, 11, 5, 14, 0)),
#   (5622, 129, 9, 2138, 'Chris Botti', datetime.datetime(2008, 11, 8, 15, 0)),
#   (5626, 14, 9, 1978, 'Bow Wow', datetime.datetime(2008, 6, 1, 19, 0)),
#   (5627,
#    13,
#    9,
#    2187,
#    'Crosby Stills Nash',
#    datetime.datetime(2008, 12, 27, 19, 30)),
#   (5628, 129, 9, 2102, 'Chris Botti', datetime.datetime(2008, 10, 3, 19, 30)),
#   (5629, 70, 9, 2040, 'Lionel Richie', datetime.datetime(2008, 8, 2, 19, 30)),
#   (5633,
#    119,
#    9,
#    2172,
#    'Children of Bodom',
#    datetime.datetime(2008, 12, 12, 19, 30)),
#   (5641, 5, 9, 1982, 'Wynonna', datetime.datetime(2008, 6, 5, 19, 0)),
#   (5644, 119, 9, 1846, 'Hippiefest', datetime.datetime(2008, 1, 20, 19, 30)),
#   (5652,
#    108,
#    9,
#    2156,
#    'Justin Timberlake',
#    datetime.datetime(2008, 11, 26, 19, 30)),
#   (5656, 103, 9, 1920, 'KT Tunstall', datetime.datetime(2008, 4, 4, 19, 30)),
#   (5657,
#    72,
#    9,
#    1866,
#    'Coheed and Cambria',
#    datetime.datetime(2008, 2, 9, 14, 0)),
#   (5660, 89, 9, 2034, 'Ben E. King', datetime.datetime(2008, 7, 27, 14, 0)),
#   (5668,
#    5,
#    9,
#    1851,
#    'DJ Shadow and Cut Chemist',
#    datetime.datetime(2008, 1, 25, 19, 0)),
#   (5674, 14, 9, 1907, 'Hannah Montana', datetime.datetime(2008, 3, 22, 14, 0)),
#   (5675, 14, 9, 2000, 'Hot Chip', datetime.datetime(2008, 6, 23, 14, 0)),
#   (5678, 119, 9, 1904, 'Spoon', datetime.datetime(2008, 3, 19, 19, 30)),
#   (5679, 3, 9, 2002, 'Boston', datetime.datetime(2008, 6, 25, 14, 0)),
#   (5685,
#    13,
#    9,
#    2140,
#    'Johnny Mathis',
#    datetime.datetime(2008, 11, 10, 19, 30)),
#   (5687, 80, 9, 1896, 'Kid Rock', datetime.datetime(2008, 3, 11, 14, 0)),
#   (5698, 75, 9, 1982, 'Kenny Chesney', datetime.datetime(2008, 6, 5, 19, 0)),
#   (5705,
#    6,
#    9,
#    2008,
#    'Steve Miller Band',
#    datetime.datetime(2008, 7, 1, 14, 0)),
#   (5706, 3, 9, 1965, 'Josh Turner', datetime.datetime(2008, 5, 1, 15, 0)),
#   (5712, 6, 9, 2050, 'Ringo Starr', datetime.datetime(2008, 8, 12, 14, 0)),
#   (5713, 2, 9, 2059, 'Fab Faux', datetime.datetime(2008, 8, 21, 14, 0)),
#   (5716,
#    98,
#    9,
#    2124,
#    'Jesse McCartney',
#    datetime.datetime(2008, 10, 25, 19, 30)),
#   (5720, 103, 9, 1833, 'Air Supply', datetime.datetime(2008, 1, 7, 19, 30)),
#   (5721, 69, 9, 1943, 'Los Temerarios', datetime.datetime(2008, 4, 27, 14, 0)),
#   (5724, 75, 9, 1854, 'Merle Haggard', datetime.datetime(2008, 1, 28, 15, 0)),
#   (5731, 91, 9, 2066, 'Govt Mule', datetime.datetime(2008, 8, 28, 19, 30)),
#   (5752, 76, 9, 1857, 'Britney Spears', datetime.datetime(2008, 1, 31, 14, 0)),
#   (5763, 129, 9, 1829, 'Missy Higgins', datetime.datetime(2008, 1, 3, 14, 0)),
#   (5770, 14, 9, 2126, 'Fergie', datetime.datetime(2008, 10, 27, 19, 30)),
#   (5776, 89, 9, 2176, 'Vince Gill', datetime.datetime(2008, 12, 16, 19, 0)),
#   (5790, 116, 9, 1973, 'Maze', datetime.datetime(2008, 5, 1, 19, 30)),
#   (5792,
#    108,
#    9,
#    2026,
#    'John Mellencamp',
#    datetime.datetime(2008, 7, 19, 19, 30)),
#   (5793, 74, 9, 1861, 'Sugarland', datetime.datetime(2008, 2, 4, 15, 0)),
#   (5796, 6, 9, 1903, 'Gavin DeGraw', datetime.datetime(2008, 3, 18, 19, 0)),
#   (5800,
#    92,
#    9,
#    1928,
#    'Echo & the Bunnymen',
#    datetime.datetime(2008, 4, 12, 15, 0)),
#   (5806, 98, 9, 2100, 'Poison', datetime.datetime(2008, 10, 1, 19, 0)),
#   (5808, 11, 9, 1964, 'Ani DiFranco', datetime.datetime(2008, 5, 1, 15, 0)),
#   (5811, 5, 9, 1870, 'Merle Haggard', datetime.datetime(2008, 2, 13, 19, 30)),
#   (5814, 14, 9, 1872, 'Regina Spektor', datetime.datetime(2008, 2, 15, 19, 0)),
#   (5821, 69, 9, 2093, 'Rush', datetime.datetime(2008, 9, 24, 15, 0)),
#   (5824,
#    98,
#    9,
#    2114,
#    'The Jesus and Mary Chain',
#    datetime.datetime(2008, 10, 15, 14, 0)),
#   (5833, 70, 9, 2067, 'Live', datetime.datetime(2008, 8, 29, 14, 0)),
#   (5835, 71, 9, 2170, 'LeAnn Rimes', datetime.datetime(2008, 12, 10, 19, 0)),
#   (5837,
#    116,
#    9,
#    1858,
#    'Kool and The Gang',
#    datetime.datetime(2008, 2, 1, 19, 0)),
#   (5845,
#    108,
#    9,
#    2139,
#    'Coheed and Cambria',
#    datetime.datetime(2008, 11, 9, 19, 0)),
#   (5849, 89, 9, 1984, 'Regina Spektor', datetime.datetime(2008, 6, 7, 14, 0)),
#   (5850, 129, 9, 2138, 'Merle Haggard', datetime.datetime(2008, 11, 8, 19, 0)),
#   (5854, 69, 9, 1876, 'Dierks Bentley', datetime.datetime(2008, 2, 19, 19, 0)),
#   (5856, 119, 9, 1831, 'Lollapalooza', datetime.datetime(2008, 1, 5, 14, 0)),
#   (5861, 71, 9, 2030, 'Gavin DeGraw', datetime.datetime(2008, 7, 23, 15, 0)),
#   (5865, 116, 9, 2052, 'Santana', datetime.datetime(2008, 8, 14, 14, 0)),
#   (5873,
#    70,
#    9,
#    1835,
#    'Natasha Bedingfield',
#    datetime.datetime(2008, 1, 9, 14, 0)),
#   (5879, 2, 9, 2120, 'Old 97s', datetime.datetime(2008, 10, 21, 15, 0)),
#   (5884, 76, 9, 2012, 'Vince Gill', datetime.datetime(2008, 7, 5, 15, 0)),
#   (5897, 80, 9, 1963, 'Vampire Weekend', datetime.datetime(2008, 5, 1, 15, 0)),
#   (5898, 76, 9, 1991, 'Blind Melon', datetime.datetime(2008, 6, 14, 19, 30)),
#   (5900, 80, 9, 1926, 'Boz Scaggs', datetime.datetime(2008, 4, 10, 14, 0)),
#   (5915,
#    70,
#    9,
#    1958,
#    'Voodoo Music Experience',
#    datetime.datetime(2008, 5, 1, 19, 0)),
#   (5919, 69, 9, 2023, 'Motorhead', datetime.datetime(2008, 7, 16, 14, 0)),
#   (5925,
#    129,
#    9,
#    1994,
#    'Country Thunder USA',
#    datetime.datetime(2008, 6, 17, 19, 0)),
#   (5933, 70, 9, 2021, 'Steely Dan', datetime.datetime(2008, 7, 14, 19, 30)),
#   (5934, 14, 9, 2065, 'Kanye West', datetime.datetime(2008, 8, 27, 15, 0)),
#   (5936,
#    79,
#    9,
#    1835,
#    'Neville Brothers',
#    datetime.datetime(2008, 1, 9, 19, 30)),
#   (5937,
#    14,
#    9,
#    1997,
#    'Brian Jonestown Massacre',
#    datetime.datetime(2008, 6, 20, 19, 30)),
#   (5940, 81, 9, 2010, 'Celine Dion', datetime.datetime(2008, 7, 3, 14, 0)),
#   (5942, 11, 9, 2112, 'Tony Bennett', datetime.datetime(2008, 10, 13, 19, 30)),
#   (5944, 11, 9, 1845, 'Wilco', datetime.datetime(2008, 1, 19, 19, 30)),
#   (5949, 2, 9, 1963, 'Jimmy Buffett', datetime.datetime(2008, 5, 1, 19, 30)),
#   (5958, 81, 9, 2022, 'Wynonna', datetime.datetime(2008, 7, 15, 15, 0)),
#   (5959, 81, 9, 1968, 'Madonna', datetime.datetime(2008, 5, 1, 14, 0)),
#   (5971, 74, 9, 1917, 'Counting Crows', datetime.datetime(2008, 4, 1, 19, 0)),
#   (5976, 119, 9, 2088, 'Stray Cats', datetime.datetime(2008, 9, 19, 19, 30)),
#   (5981, 91, 9, 1932, 'ZZ Top', datetime.datetime(2008, 4, 16, 19, 30)),
#   (5982,
#    6,
#    9,
#    2145,
#    'Trisha Yearwood',
#    datetime.datetime(2008, 11, 15, 19, 30)),
#   (5985,
#    81,
#    9,
#    1904,
#    'Jessica Simpson',
#    datetime.datetime(2008, 3, 19, 14, 0)),
#   (5991, 74, 9, 2011, 'Eddie Money', datetime.datetime(2008, 7, 4, 15, 0)),
#   (5998,
#    79,
#    9,
#    2141,
#    'Bamboozle Left',
#    datetime.datetime(2008, 11, 11, 15, 0)),
#   (6000,
#    11,
#    9,
#    2179,
#    'Jerry Jeff Walker',
#    datetime.datetime(2008, 12, 19, 15, 0)),
#   (6010, 3, 9, 2175, 'Kanye West', datetime.datetime(2008, 12, 15, 19, 0)),
#   (6016, 79, 9, 1962, 'Fergie', datetime.datetime(2008, 5, 1, 15, 0)),
#   (6017, 2, 9, 2023, 'Kanye West', datetime.datetime(2008, 7, 16, 19, 0)),
#   (6022, 69, 9, 2020, 'Dixie Chicks', datetime.datetime(2008, 7, 13, 19, 30)),
#   (6023,
#    92,
#    9,
#    2182,
#    'Blues Brothers',
#    datetime.datetime(2008, 12, 22, 19, 30)),
#   (6025,
#    3,
#    9,
#    1862,
#    'Sweet Honey in the Rock',
#    datetime.datetime(2008, 2, 5, 14, 0)),
#   (6030, 79, 9, 1857, 'America', datetime.datetime(2008, 1, 31, 19, 30)),
#   (6038, 67, 9, 1928, 'Eddie Money', datetime.datetime(2008, 4, 12, 19, 30)),
#   (6039, 14, 9, 1964, 'Boyz II Men', datetime.datetime(2008, 5, 1, 19, 30)),
#   (6042, 116, 9, 1997, 'John Hiatt', datetime.datetime(2008, 6, 20, 19, 30)),
#   (6048, 69, 9, 2000, 'Sugarland', datetime.datetime(2008, 6, 23, 19, 30)),
#   (6055, 74, 9, 1908, 'Frankie Valli', datetime.datetime(2008, 3, 23, 15, 0)),
#   (6058,
#    2,
#    9,
#    1979,
#    'Creedence Clearwater Revisited',
#    datetime.datetime(2008, 6, 2, 14, 0)),
#   (6063,
#    74,
#    9,
#    2083,
#    'Gordon Lightfoot',
#    datetime.datetime(2008, 9, 14, 15, 0)),
#   (6074, 74, 9, 1933, 'Sara Evans', datetime.datetime(2008, 4, 17, 14, 0)),
#   (6078,
#    116,
#    9,
#    2125,
#    'Dierks Bentley',
#    datetime.datetime(2008, 10, 26, 15, 0)),
#   (6086, 5, 9, 1889, 'Linkin Park', datetime.datetime(2008, 3, 4, 14, 0)),
#   (6088, 6, 9, 1960, 'Paul McCartney', datetime.datetime(2008, 5, 1, 15, 0)),
#   (6089, 91, 9, 2027, 'Ween', datetime.datetime(2008, 7, 20, 19, 0)),
#   (6096, 79, 9, 1854, 'Ben Harper', datetime.datetime(2008, 1, 28, 15, 0)),
#   (6097, 92, 9, 2048, 'Tony Bennett', datetime.datetime(2008, 8, 10, 14, 0)),
#   (6099, 103, 9, 1896, 'Rod Stewart', datetime.datetime(2008, 3, 11, 15, 0)),
#   (6116, 2, 9, 1883, 'Cake', datetime.datetime(2008, 2, 26, 14, 0)),
#   (6121, 13, 9, 2154, 'Kiss', datetime.datetime(2008, 11, 24, 19, 30)),
#   (6126, 98, 9, 1999, 'Foghat', datetime.datetime(2008, 6, 22, 14, 0)),
#   (6131, 81, 9, 1872, 'Rusted Root', datetime.datetime(2008, 2, 15, 19, 0)),
#   (6133,
#    75,
#    9,
#    2023,
#    'Vicente Fernandez',
#    datetime.datetime(2008, 7, 16, 19, 30)),
#   (6138,
#    11,
#    9,
#    1975,
#    'Aretha Franklin',
#    datetime.datetime(2008, 5, 1, 19, 30)),
#   (6140,
#    129,
#    9,
#    2042,
#    'Aretha Franklin',
#    datetime.datetime(2008, 8, 4, 14, 0)),
#   (6147, 14, 9, 1955, 'Bamboozle Left', datetime.datetime(2008, 5, 1, 15, 0)),
#   (6152,
#    92,
#    9,
#    1836,
#    'Coheed and Cambria',
#    datetime.datetime(2008, 1, 10, 19, 30)),
#   (6164, 76, 9, 2089, 'Chris Isaak', datetime.datetime(2008, 9, 20, 14, 0)),
#   (6169, 116, 9, 1891, 'Alice Cooper', datetime.datetime(2008, 3, 6, 19, 0)),
#   (6172, 11, 9, 1913, 'Tina Turner', datetime.datetime(2008, 3, 28, 15, 0)),
#   (6189, 119, 9, 1858, 'Live', datetime.datetime(2008, 2, 1, 19, 0)),
#   (6198, 67, 9, 2033, 'Fab Faux', datetime.datetime(2008, 7, 26, 19, 0)),
#   (6199, 80, 9, 1980, 'Trisha Yearwood', datetime.datetime(2008, 6, 3, 19, 0)),
#   (6208,
#    11,
#    9,
#    2007,
#    'The Swell Season',
#    datetime.datetime(2008, 6, 30, 14, 0)),
#   (6209, 119, 9, 2027, 'Rush', datetime.datetime(2008, 7, 20, 19, 0)),
#   (6218, 81, 9, 2078, 'Ben Folds', datetime.datetime(2008, 9, 9, 19, 0)),
#   (6225, 81, 9, 1848, 'Chaka Khan', datetime.datetime(2008, 1, 22, 14, 0)),
#   (6228,
#    6,
#    9,
#    1949,
#    'My Bloody Valentine',
#    datetime.datetime(2008, 5, 1, 14, 0)),
#   (6236, 2, 9, 2069, 'Wyclef Jean', datetime.datetime(2008, 8, 31, 14, 0)),
#   (6237, 2, 9, 2106, 'Bloc Party', datetime.datetime(2008, 10, 7, 15, 0)),
#   (6241, 2, 9, 1860, 'Isaac Hayes', datetime.datetime(2008, 2, 3, 19, 30)),
#   (6247, 89, 9, 1916, 'Bo Bice', datetime.datetime(2008, 3, 31, 19, 0)),
#   (6248,
#    67,
#    9,
#    2098,
#    'Steven Curtis Chapman',
#    datetime.datetime(2008, 9, 29, 14, 0)),
#   (6249, 76, 9, 1915, 'Tailgate 2008', datetime.datetime(2008, 3, 30, 14, 0)),
#   (6261, 76, 9, 1929, 'KT Tunstall', datetime.datetime(2008, 4, 13, 19, 30)),
#   (6262, 2, 9, 1828, 'Gogol Bordello', datetime.datetime(2008, 1, 2, 15, 0)),
#   (6263, 89, 9, 2018, 'Ben E. King', datetime.datetime(2008, 7, 11, 19, 30)),
#   (6268,
#    6,
#    9,
#    1991,
#    'Natasha Bedingfield',
#    datetime.datetime(2008, 6, 14, 19, 0)),
#   (6270,
#    98,
#    9,
#    1830,
#    'Rodrigo y Gabriela',
#    datetime.datetime(2008, 1, 4, 14, 0)),
#   (6272, 71, 9, 2086, 'Styx', datetime.datetime(2008, 9, 17, 19, 30)),
#   (6278, 13, 9, 2056, 'Billy Joel', datetime.datetime(2008, 8, 18, 14, 0)),
#   (6281, 67, 9, 1938, 'Dolly Parton', datetime.datetime(2008, 4, 22, 15, 0)),
#   (6293,
#    75,
#    9,
#    1853,
#    'Blues Brothers',
#    datetime.datetime(2008, 1, 27, 19, 30)),
#   (6294, 129, 9, 2074, 'Conor Oberst', datetime.datetime(2008, 9, 5, 19, 30)),
#   (6295,
#    129,
#    9,
#    1849,
#    'Alejandro Fernandez',
#    datetime.datetime(2008, 1, 23, 19, 0)),
#   (6299,
#    6,
#    9,
#    2005,
#    'Melissa Etheridge',
#    datetime.datetime(2008, 6, 28, 19, 30)),
#   (6302, 108, 9, 1855, 'Kenny Rogers', datetime.datetime(2008, 1, 29, 19, 0)),
#   (6305, 75, 9, 1890, 'Poison', datetime.datetime(2008, 3, 5, 19, 30)),
#   (6308, 6, 9, 1891, 'Wynonna', datetime.datetime(2008, 3, 6, 15, 0)),
#   (6309, 91, 9, 2169, 'Mars Volta', datetime.datetime(2008, 12, 9, 15, 0)),
#   (6310, 129, 9, 2137, 'Tony Bennett', datetime.datetime(2008, 11, 7, 14, 0)),
#   (6314, 129, 9, 2030, 'Wilco', datetime.datetime(2008, 7, 23, 19, 0)),
#   (6325,
#    129,
#    9,
#    2125,
#    'Los Temerarios',
#    datetime.datetime(2008, 10, 26, 19, 0)),
#   (6327, 70, 9, 2103, 'Gnarls Barkley', datetime.datetime(2008, 10, 4, 19, 0)),
#   (6331,
#    5,
#    9,
#    2174,
#    'Sunday in the Country',
#    datetime.datetime(2008, 12, 14, 19, 30)),
#   (6335, 71, 9, 2160, '3 Doors Down', datetime.datetime(2008, 11, 30, 14, 0)),
#   (6344, 13, 9, 1855, 'Jack Johnson', datetime.datetime(2008, 1, 29, 14, 0)),
#   (6347, 119, 9, 2089, 'Seal', datetime.datetime(2008, 9, 20, 19, 0)),
#   (6350, 79, 9, 2167, 'Kenny Chesney', datetime.datetime(2008, 12, 7, 19, 0)),
#   (6360, 13, 9, 1847, 'Frankie Valli', datetime.datetime(2008, 1, 21, 19, 0)),
#   (6363, 119, 9, 2010, 'Irish Tenors', datetime.datetime(2008, 7, 3, 19, 30)),
#   (6369, 75, 9, 1931, 'Rancid', datetime.datetime(2008, 4, 15, 19, 30)),
#   (6374,
#    67,
#    9,
#    1929,
#    'Lindsey Buckingham',
#    datetime.datetime(2008, 4, 13, 19, 0)),
#   (6376, 5, 9, 1977, 'Enrique Iglesias', datetime.datetime(2008, 5, 1, 15, 0)),
#   (6377,
#    11,
#    9,
#    2007,
#    'Dropkick Murphys',
#    datetime.datetime(2008, 6, 30, 19, 0)),
#   (6380, 76, 9, 2072, 'Smash Mouth', datetime.datetime(2008, 9, 3, 19, 30)),
#   (6382,
#    5,
#    9,
#    1989,
#    'Robert Cray Band',
#    datetime.datetime(2008, 6, 12, 19, 0)),
#   (6395, 69, 9, 2174, 'Hot Chip', datetime.datetime(2008, 12, 14, 14, 0)),
#   (6396, 75, 9, 2154, 'Killers', datetime.datetime(2008, 11, 24, 19, 0)),
#   (6403,
#    76,
#    9,
#    2189,
#    'Kenny Wayne Shepherd',
#    datetime.datetime(2008, 12, 29, 15, 0)),
#   (6405,
#    13,
#    9,
#    1879,
#    'Crosby Stills Nash',
#    datetime.datetime(2008, 2, 22, 19, 0)),
#   (6417, 13, 9, 1969, 'Elton John', datetime.datetime(2008, 5, 1, 19, 30)),
#   (6419, 76, 9, 1882, 'Zucchero', datetime.datetime(2008, 2, 25, 15, 0)),
#   (6424, 67, 9, 1898, 'Sheryl Crow', datetime.datetime(2008, 3, 13, 19, 30)),
#   (6433, 3, 9, 2078, 'Janet Jackson', datetime.datetime(2008, 9, 9, 19, 30)),
#   (6434, 89, 9, 2075, 'Cold War Kids', datetime.datetime(2008, 9, 6, 14, 0)),
#   (6435,
#    108,
#    9,
#    2180,
#    'Steve Winwood',
#    datetime.datetime(2008, 12, 20, 14, 0)),
#   (6440, 71, 9, 1827, 'Beck', datetime.datetime(2008, 1, 1, 19, 0)),
#   (6446, 80, 9, 2053, 'Live', datetime.datetime(2008, 8, 15, 19, 30)),
#   (6447, 2, 9, 1973, 'Jimmy Buffett', datetime.datetime(2008, 5, 1, 15, 0)),
#   (6458, 71, 9, 1991, 'Ringo Starr', datetime.datetime(2008, 6, 14, 14, 0)),
#   (6461,
#    13,
#    9,
#    2118,
#    'Crosby Stills Nash',
#    datetime.datetime(2008, 10, 19, 15, 0)),
#   (6476,
#    91,
#    9,
#    2094,
#    'John Mellencamp',
#    datetime.datetime(2008, 9, 25, 14, 0)),
#   (6481, 91, 9, 1836, 'Bamboozle Left', datetime.datetime(2008, 1, 10, 14, 0)),
#   (6482, 89, 9, 1874, 'Goo Goo Dolls', datetime.datetime(2008, 2, 17, 19, 30)),
#   (6487,
#    76,
#    9,
#    1995,
#    'Flogging Molly',
#    datetime.datetime(2008, 6, 18, 19, 30)),
#   (6490,
#    75,
#    9,
#    1839,
#    'Nine Inch Nails',
#    datetime.datetime(2008, 1, 13, 19, 30)),
#   (6492, 6, 9, 2084, 'Ryan Adams', datetime.datetime(2008, 9, 15, 14, 0)),
#   (6496, 2, 9, 1970, 'Gwen Stefani', datetime.datetime(2008, 5, 1, 19, 0)),
#   (6500,
#    69,
#    9,
#    2133,
#    'Red Hot Chili Peppers',
#    datetime.datetime(2008, 11, 3, 19, 30)),
#   (6511, 6, 9, 2028, 'Extreme', datetime.datetime(2008, 7, 21, 14, 0)),
#   (6519,
#    3,
#    9,
#    1869,
#    'American Idols Live',
#    datetime.datetime(2008, 2, 12, 19, 0)),
#   (6520,
#    119,
#    9,
#    1966,
#    'Stone Temple Pilots',
#    datetime.datetime(2008, 5, 1, 15, 0)),
#   (6524, 69, 9, 2066, 'Vince Gill', datetime.datetime(2008, 8, 28, 15, 0)),
#   (6527, 5, 9, 1933, 'The Black Keys', datetime.datetime(2008, 4, 17, 19, 30)),
#   (6531,
#    116,
#    9,
#    2185,
#    'Creedence Clearwater Revisited',
#    datetime.datetime(2008, 12, 25, 19, 0)),
#   (6533, 92, 9, 2182, 'Jason Aldean', datetime.datetime(2008, 12, 22, 15, 0)),
#   (6536, 92, 9, 1922, 'The Police', datetime.datetime(2008, 4, 6, 15, 0)),
#   (6538, 119, 9, 1918, 'Iron and Wine', datetime.datetime(2008, 4, 2, 19, 0)),
#   (6543, 129, 9, 2017, 'Simple Plan', datetime.datetime(2008, 7, 10, 15, 0)),
#   (6544, 98, 9, 1883, 'Alicia Keys', datetime.datetime(2008, 2, 26, 15, 0)),
#   (6557, 79, 9, 1899, 'Celine Dion', datetime.datetime(2008, 3, 14, 15, 0)),
#   (6558,
#    91,
#    9,
#    2174,
#    'Echo & the Bunnymen',
#    datetime.datetime(2008, 12, 14, 15, 0)),
#   (6564, 129, 9, 1854, 'KT Tunstall', datetime.datetime(2008, 1, 28, 14, 0)),
#   (6572, 74, 9, 2028, 'Citizen Cope', datetime.datetime(2008, 7, 21, 14, 0)),
#   (6586,
#    116,
#    9,
#    2078,
#    'Crosby Stills Nash',
#    datetime.datetime(2008, 9, 9, 19, 0)),
#   (6587,
#    5,
#    9,
#    2117,
#    'Michael McDonald',
#    datetime.datetime(2008, 10, 18, 19, 30)),
#   (6589,
#    116,
#    9,
#    2087,
#    'Backstreet Boys',
#    datetime.datetime(2008, 9, 18, 19, 0)),
#   (6594, 76, 9, 1866, 'Cake', datetime.datetime(2008, 2, 9, 19, 30)),
#   (6595,
#    103,
#    9,
#    1938,
#    'Wisin y Yandel',
#    datetime.datetime(2008, 4, 22, 14, 0)),
#   (6598, 3, 9, 1893, 'Bad Company', datetime.datetime(2008, 3, 8, 19, 30)),
#   (6619,
#    75,
#    9,
#    2100,
#    'Jerry Jeff Walker',
#    datetime.datetime(2008, 10, 1, 15, 0)),
#   (6626, 119, 9, 1910, 'Paramore', datetime.datetime(2008, 3, 25, 19, 30)),
#   (6627, 92, 9, 1858, 'Josh Turner', datetime.datetime(2008, 2, 1, 14, 0)),
#   (6628, 91, 9, 1983, 'David Sanborn', datetime.datetime(2008, 6, 6, 19, 30)),
#   (6631, 81, 9, 1866, 'Burt Bacharach', datetime.datetime(2008, 2, 9, 15, 0)),
#   (6642, 67, 9, 2104, 'Linkin Park', datetime.datetime(2008, 10, 5, 19, 30)),
#   (6643, 13, 9, 1941, 'Avril Lavigne', datetime.datetime(2008, 4, 25, 15, 0)),
#   (6647, 91, 9, 1882, 'UB40', datetime.datetime(2008, 2, 25, 19, 30)),
#   (6648, 72, 9, 1833, 'Mariah Carey', datetime.datetime(2008, 1, 7, 14, 0)),
#   (6649, 6, 9, 1827, 'Hannah Montana', datetime.datetime(2008, 1, 1, 19, 30)),
#   (6653,
#    91,
#    9,
#    1878,
#    'Montgomery Gentry',
#    datetime.datetime(2008, 2, 21, 19, 0)),
#   (6659,
#    108,
#    9,
#    2148,
#    'My Morning Jacket',
#    datetime.datetime(2008, 11, 18, 14, 0)),
#   (6672, 91, 9, 1993, 'Nofx', datetime.datetime(2008, 6, 16, 19, 0)),
#   (6674, 11, 9, 2136, 'Fab Faux', datetime.datetime(2008, 11, 6, 19, 30)),
#   (6675, 2, 9, 1916, 'Kid Rock', datetime.datetime(2008, 3, 31, 15, 0)),
#   (6682, 14, 9, 1909, 'War', datetime.datetime(2008, 3, 24, 19, 30)),
#   (6684, 103, 9, 1979, 'Daughtry', datetime.datetime(2008, 6, 2, 15, 0)),
#   (6685,
#    74,
#    9,
#    2090,
#    'Little River Band',
#    datetime.datetime(2008, 9, 21, 19, 0)),
#   (6688, 71, 9, 1993, 'Decemberists', datetime.datetime(2008, 6, 16, 14, 0)),
#   (6699, 3, 9, 1844, 'Gogol Bordello', datetime.datetime(2008, 1, 18, 19, 30)),
#   (6706,
#    14,
#    9,
#    2059,
#    'Jamboree in the Hills',
#    datetime.datetime(2008, 8, 21, 14, 0)),
#   (6707, 14, 9, 1970, 'Eagles', datetime.datetime(2008, 5, 1, 15, 0)),
#   (6710, 6, 9, 2084, 'Idina Menzel', datetime.datetime(2008, 9, 15, 15, 0)),
#   (6711,
#    72,
#    9,
#    1827,
#    'Smashing Pumpkins',
#    datetime.datetime(2008, 1, 1, 19, 0)),
#   (6716, 5, 9, 1864, 'Alan Jackson', datetime.datetime(2008, 2, 7, 15, 0)),
#   (6717, 103, 9, 1858, 'Regina Spektor', datetime.datetime(2008, 2, 1, 14, 0)),
#   (6721, 119, 9, 1840, 'Neil Diamond', datetime.datetime(2008, 1, 14, 19, 30)),
# ...
#   (7705, 89, 9, 1958, 'Bow Wow', datetime.datetime(2008, 5, 1, 19, 0)),
#   (7711, 3, 9, 2119, 'Rod Stewart', datetime.datetime(2008, 10, 20, 14, 0)),
#   (7714, 116, 9, 2002, 'Kid Rock', datetime.datetime(2008, 6, 25, 15, 0)),
#   (7716,
#    81,
#    9,
#    1925,
#    'Counting Crows and Maroon 5',
#    datetime.datetime(2008, 4, 9, 14, 0)),
#   (7717, 119, 9, 1846, 'Bad Company', datetime.datetime(2008, 1, 20, 19, 30)),
#   (7718,
#    98,
#    9,
#    2063,
#    'Vicente Fernandez',
#    datetime.datetime(2008, 8, 25, 14, 0)),
#   (7722, 6, 9, 1966, 'Wolf Parade', datetime.datetime(2008, 5, 1, 19, 30)),
#   (7734, 129, 9, 2041, 'Bloc Party', datetime.datetime(2008, 8, 3, 19, 30)),
#   (7736, 80, 9, 2137, 'Etta James', datetime.datetime(2008, 11, 7, 19, 30)),
#   (7739, 92, 9, 1983, 'Linkin Park', datetime.datetime(2008, 6, 6, 14, 0)),
#   (7742, 14, 9, 2064, 'Kid Rock', datetime.datetime(2008, 8, 26, 15, 0)),
#   (7746, 71, 9, 1950, 'Clint Black', datetime.datetime(2008, 5, 1, 19, 0)),
#   (7747, 6, 9, 1827, 'K.D. Lang', datetime.datetime(2008, 1, 1, 15, 0)),
#   (7756, 70, 9, 2041, 'Black Crowes', datetime.datetime(2008, 8, 3, 19, 30)),
#   (7758, 13, 9, 1918, 'Dandy Warhols', datetime.datetime(2008, 4, 2, 14, 0)),
#   (7764,
#    14,
#    9,
#    1917,
#    'Dropkick Murphys',
#    datetime.datetime(2008, 4, 1, 14, 0)),
#   (7766, 14, 9, 2119, 'Iron and Wine', datetime.datetime(2008, 10, 20, 15, 0)),
#   (7776, 71, 9, 1832, 'Billy Joel', datetime.datetime(2008, 1, 6, 19, 30)),
#   (7780, 108, 9, 1960, 'Patty Griffin', datetime.datetime(2008, 5, 1, 14, 0)),
#   (7790, 70, 9, 1946, 'Rock the Bells', datetime.datetime(2008, 4, 30, 19, 0)),
#   (7793,
#    2,
#    9,
#    2034,
#    'Cute Is What We Aim For',
#    datetime.datetime(2008, 7, 27, 14, 0)),
#   (7795,
#    108,
#    9,
#    1880,
#    'The Swell Season',
#    datetime.datetime(2008, 2, 23, 15, 0)),
#   (7796, 3, 9, 1920, 'Lynyrd Skynyrd', datetime.datetime(2008, 4, 4, 14, 0)),
#   (7800,
#    72,
#    9,
#    2187,
#    'Christina Aguilera',
#    datetime.datetime(2008, 12, 27, 19, 0)),
#   (7802, 67, 9, 1839, 'Joshua Radin', datetime.datetime(2008, 1, 13, 19, 30)),
#   (7804, 79, 9, 2066, 'Joanna Newsom', datetime.datetime(2008, 8, 28, 14, 0)),
#   (7805, 98, 9, 1936, 'Maroon 5', datetime.datetime(2008, 4, 20, 19, 30)),
#   (7806, 98, 9, 2045, 'Sarah Brightman', datetime.datetime(2008, 8, 7, 14, 0)),
#   (7811,
#    71,
#    9,
#    1944,
#    'Robert Cray Band',
#    datetime.datetime(2008, 4, 28, 19, 0)),
#   (7812, 80, 9, 2119, 'Reba McEntire', datetime.datetime(2008, 10, 20, 14, 0)),
#   (7818, 70, 9, 1947, 'Natalie Cole', datetime.datetime(2008, 5, 1, 19, 0)),
#   (7822, 69, 9, 1973, 'Akon', datetime.datetime(2008, 5, 1, 15, 0)),
#   (7826, 71, 9, 1944, 'Ana Gabriel', datetime.datetime(2008, 4, 28, 15, 0)),
#   (7847, 67, 9, 1979, 'Shakira', datetime.datetime(2008, 6, 2, 15, 0)),
#   (7850, 80, 9, 2127, 'Ice Cube', datetime.datetime(2008, 10, 28, 15, 0)),
#   (7856, 116, 9, 2032, 'The Police', datetime.datetime(2008, 7, 25, 19, 30)),
#   (7861,
#    80,
#    9,
#    2159,
#    'Counting Crows',
#    datetime.datetime(2008, 11, 29, 19, 30)),
#   (7862, 71, 9, 1987, 'Ani DiFranco', datetime.datetime(2008, 6, 10, 14, 0)),
#   (7863, 2, 9, 2090, 'Fab Faux', datetime.datetime(2008, 9, 21, 15, 0)),
#   (7866, 69, 9, 2094, 'Dave Stewart', datetime.datetime(2008, 9, 25, 15, 0)),
#   (7870,
#    76,
#    9,
#    2108,
#    'Toad The Wet Sprocket',
#    datetime.datetime(2008, 10, 9, 14, 0)),
#   (7876,
#    119,
#    9,
#    1967,
#    'Projekt Revolution',
#    datetime.datetime(2008, 5, 1, 19, 30)),
#   (7879, 6, 9, 1835, 'Burt Bacharach', datetime.datetime(2008, 1, 9, 19, 30)),
#   (7884, 67, 9, 1850, 'Ray Davies', datetime.datetime(2008, 1, 24, 15, 0)),
#   (7885, 79, 9, 2073, 'Built To Spill', datetime.datetime(2008, 9, 4, 19, 30)),
#   (7901,
#    75,
#    9,
#    2028,
#    'Flogging Molly',
#    datetime.datetime(2008, 7, 21, 19, 30)),
#   (7906, 119, 9, 2111, 'El Tri', datetime.datetime(2008, 10, 12, 14, 0)),
#   (7909, 2, 9, 1854, 'Dwight Yoakam', datetime.datetime(2008, 1, 28, 15, 0)),
#   (7910, 80, 9, 1993, 'Joe Cocker', datetime.datetime(2008, 6, 16, 14, 0)),
#   (7912,
#    119,
#    9,
#    1897,
#    'Return To Forever',
#    datetime.datetime(2008, 3, 12, 15, 0)),
#   (7917, 116, 9, 2083, 'Ana Gabriel', datetime.datetime(2008, 9, 14, 19, 30)),
#   (7927, 11, 9, 2033, 'Chaka Khan', datetime.datetime(2008, 7, 26, 19, 30)),
#   (7936, 71, 9, 2023, 'Gogol Bordello', datetime.datetime(2008, 7, 16, 14, 0)),
#   (7939,
#    92,
#    9,
#    1867,
#    'Country Thunder USA',
#    datetime.datetime(2008, 2, 10, 14, 0)),
#   (7948, 2, 9, 2140, 'Calibash', datetime.datetime(2008, 11, 10, 19, 0)),
#   (7951, 5, 9, 2035, 'Joan Baez', datetime.datetime(2008, 7, 28, 15, 0)),
#   (7957, 2, 9, 2008, 'Built To Spill', datetime.datetime(2008, 7, 1, 14, 0)),
#   (7958, 6, 9, 1964, 'Patty Griffin', datetime.datetime(2008, 5, 1, 15, 0)),
#   (7962, 13, 9, 1959, 'Matchbox Twenty', datetime.datetime(2008, 5, 1, 19, 0)),
#   (7969,
#    5,
#    9,
#    2027,
#    'New Kids on the Block',
#    datetime.datetime(2008, 7, 20, 19, 0)),
#   (7972, 92, 9, 2026, 'Lollapalooza', datetime.datetime(2008, 7, 19, 19, 30)),
#   (7973, 2, 9, 1908, 'Simple Plan', datetime.datetime(2008, 3, 23, 15, 0)),
#   (7974,
#    72,
#    9,
#    2060,
#    'Huey Lewis and the News',
#    datetime.datetime(2008, 8, 22, 19, 0)),
#   (7977, 79, 9, 1898, 'Joe Cocker', datetime.datetime(2008, 3, 13, 19, 30)),
#   (7982, 6, 9, 2057, 'Joanna Newsom', datetime.datetime(2008, 8, 19, 14, 0)),
#   (7985, 11, 9, 2006, 'Chris Botti', datetime.datetime(2008, 6, 29, 14, 0)),
#   (7987, 108, 9, 1869, 'Ween', datetime.datetime(2008, 2, 12, 19, 0)),
#   (7998, 72, 9, 1965, 'Neil Diamond', datetime.datetime(2008, 5, 1, 19, 30)),
#   (8012, 98, 9, 1949, 'Ringo Starr', datetime.datetime(2008, 5, 1, 14, 0)),
#   (8017, 89, 9, 2124, 'Dwight Yoakam', datetime.datetime(2008, 10, 25, 14, 0)),
#   (8021, 98, 9, 1865, 'Black Crowes', datetime.datetime(2008, 2, 8, 14, 0)),
#   (8025, 5, 9, 2157, 'Blues Brothers', datetime.datetime(2008, 11, 27, 15, 0)),
#   (8026, 80, 9, 1935, 'Kiss', datetime.datetime(2008, 4, 19, 19, 0)),
#   (8042, 91, 9, 2072, 'Sara Bareilles', datetime.datetime(2008, 9, 3, 15, 0)),
#   (8045, 2, 9, 2059, '3 Doors Down', datetime.datetime(2008, 8, 21, 15, 0)),
#   (8048, 71, 9, 2033, 'N.E.R.D.', datetime.datetime(2008, 7, 26, 19, 30)),
#   (8054,
#    14,
#    9,
#    2142,
#    'Earth Wind and Fire',
#    datetime.datetime(2008, 11, 12, 15, 0)),
#   (8055, 108, 9, 2085, 'Decemberists', datetime.datetime(2008, 9, 16, 15, 0)),
#   (8060,
#    119,
#    9,
#    1991,
#    'Hall and Oates',
#    datetime.datetime(2008, 6, 14, 15, 0)),
#   (8062,
#    76,
#    9,
#    2031,
#    'Little Big Town',
#    datetime.datetime(2008, 7, 24, 14, 0)),
#   (8068, 103, 9, 1949, 'Eric Clapton', datetime.datetime(2008, 5, 1, 15, 0)),
#   (8071, 14, 9, 1939, 'Ben Harper', datetime.datetime(2008, 4, 23, 19, 30)),
#   (8072,
#    2,
#    9,
#    1895,
#    'Brian Jonestown Massacre',
#    datetime.datetime(2008, 3, 10, 19, 30)),
#   (8073, 3, 9, 1928, 'Madonna', datetime.datetime(2008, 4, 12, 19, 0)),
#   (8077,
#    116,
#    9,
#    1948,
#    'Guitars and Saxes',
#    datetime.datetime(2008, 5, 1, 19, 30)),
#   (8080,
#    72,
#    9,
#    2064,
#    'Little River Band',
#    datetime.datetime(2008, 8, 26, 19, 0)),
#   (8082, 98, 9, 2047, 'Led Zeppelin', datetime.datetime(2008, 8, 9, 15, 0)),
#   (8093, 80, 9, 2005, 'Zombies', datetime.datetime(2008, 6, 28, 15, 0)),
#   (8097, 67, 9, 2165, 'Kiss', datetime.datetime(2008, 12, 5, 19, 30)),
#   (8098,
#    98,
#    9,
#    1832,
#    'The Swell Season',
#    datetime.datetime(2008, 1, 6, 19, 30)),
#   (8102, 92, 9, 2068, 'Fergie', datetime.datetime(2008, 8, 30, 19, 30)),
#   (8103, 119, 9, 2005, 'Alice Cooper', datetime.datetime(2008, 6, 28, 14, 0)),
#   (8106, 91, 9, 1845, 'Bob Dylan', datetime.datetime(2008, 1, 19, 19, 0)),
#   (8107,
#    74,
#    9,
#    1997,
#    'Stone Temple Pilots',
#    datetime.datetime(2008, 6, 20, 14, 0)),
#   (8108, 116, 9, 2131, 'Ringo Starr', datetime.datetime(2008, 11, 1, 19, 30)),
#   (8116,
#    75,
#    9,
#    2131,
#    'Gretchen Wilson',
#    datetime.datetime(2008, 11, 1, 19, 30)),
#   (8117, 72, 9, 2130, 'ZZ Top', datetime.datetime(2008, 10, 31, 14, 0)),
#   (8118,
#    13,
#    9,
#    1917,
#    'Lucinda Williams',
#    datetime.datetime(2008, 4, 1, 19, 30)),
#   (8120, 11, 9, 2020, 'Bette Midler', datetime.datetime(2008, 7, 13, 19, 30)),
#   (8125, 11, 9, 1891, 'Killers', datetime.datetime(2008, 3, 6, 14, 0)),
#   (8130, 71, 9, 1900, 'Brand New', datetime.datetime(2008, 3, 15, 14, 0)),
#   (8134, 6, 9, 1979, 'Temptations', datetime.datetime(2008, 6, 2, 19, 30)),
#   (8135, 108, 9, 2002, 'Paramore', datetime.datetime(2008, 6, 25, 14, 0)),
#   (8137,
#    11,
#    9,
#    2021,
#    'Neville Brothers',
#    datetime.datetime(2008, 7, 14, 14, 0)),
#   (8140, 91, 9, 2040, 'Built To Spill', datetime.datetime(2008, 8, 2, 19, 0)),
#   (8144, 92, 9, 1975, 'Joanna Newsom', datetime.datetime(2008, 5, 1, 19, 30)),
#   (8157, 98, 9, 1887, 'Cold War Kids', datetime.datetime(2008, 3, 2, 19, 0)),
#   (8168,
#    70,
#    9,
#    2191,
#    'Little River Band',
#    datetime.datetime(2008, 12, 31, 15, 0)),
#   (8174, 92, 9, 1986, 'Tower of Power', datetime.datetime(2008, 6, 9, 14, 0)),
#   (8176,
#    71,
#    9,
#    2133,
#    'Counting Crows',
#    datetime.datetime(2008, 11, 3, 19, 30)),
#   (8183, 13, 9, 1846, 'James Taylor', datetime.datetime(2008, 1, 20, 19, 30)),
#   (8192, 92, 9, 1909, 'Brand New', datetime.datetime(2008, 3, 24, 15, 0)),
#   (8209, 129, 9, 1965, 'John Mayer', datetime.datetime(2008, 5, 1, 19, 0)),
#   (8216,
#    89,
#    9,
#    1955,
#    'Vans Warped Tour',
#    datetime.datetime(2008, 5, 1, 15, 0)),
#   (8219, 74, 9, 2095, 'Blind Melon', datetime.datetime(2008, 9, 26, 19, 0)),
#   (8220, 119, 9, 1927, 'Nick Cave', datetime.datetime(2008, 4, 11, 15, 0)),
#   (8222, 5, 9, 1876, 'Nine Inch Nails', datetime.datetime(2008, 2, 19, 14, 0)),
#   (8224, 89, 9, 2050, 'Live', datetime.datetime(2008, 8, 12, 19, 0)),
#   (8230, 69, 9, 2176, 'Teena Marie', datetime.datetime(2008, 12, 16, 15, 0)),
#   (8233, 72, 9, 1868, 'Old 97s', datetime.datetime(2008, 2, 11, 15, 0)),
#   (8236, 71, 9, 1847, 'Susan Tedeschi', datetime.datetime(2008, 1, 21, 19, 0)),
#   (8238, 116, 9, 1860, 'Fleet Foxes', datetime.datetime(2008, 2, 3, 15, 0)),
#   (8246, 14, 9, 2043, 'Umphreys McGee', datetime.datetime(2008, 8, 5, 19, 0)),
#   (8247, 108, 9, 2064, 'Scorpions', datetime.datetime(2008, 8, 26, 19, 0)),
#   (8253, 13, 9, 1904, 'Jesse Lacey', datetime.datetime(2008, 3, 19, 14, 0)),
#   (8259, 5, 9, 2066, 'Govt Mule', datetime.datetime(2008, 8, 28, 19, 0)),
#   (8265, 70, 9, 1876, 'Boyz II Men', datetime.datetime(2008, 2, 19, 19, 0)),
#   (8268, 14, 9, 1879, 'Ben E. King', datetime.datetime(2008, 2, 22, 19, 0)),
#   (8273,
#    3,
#    9,
#    1896,
#    'Hootie and the Blowfish',
#    datetime.datetime(2008, 3, 11, 19, 0)),
#   (8284, 92, 9, 2067, 'Foreigner', datetime.datetime(2008, 8, 29, 14, 0)),
#   (8287, 11, 9, 2184, 'Mos Def', datetime.datetime(2008, 12, 24, 19, 30)),
#   (8293,
#    2,
#    9,
#    2141,
#    'Jonas Brothers',
#    datetime.datetime(2008, 11, 11, 19, 30)),
#   (8312,
#    74,
#    9,
#    2081,
#    'Dropkick Murphys',
#    datetime.datetime(2008, 9, 12, 15, 0)),
#   (8313, 3, 9, 2023, 'Patty Griffin', datetime.datetime(2008, 7, 16, 14, 0)),
#   (8320,
#    67,
#    9,
#    1913,
#    'Dropkick Murphys',
#    datetime.datetime(2008, 3, 28, 19, 30)),
#   (8323, 5, 9, 2009, 'Britney Spears', datetime.datetime(2008, 7, 2, 15, 0)),
#   (8325,
#    80,
#    9,
#    1833,
#    'Rick Springfield',
#    datetime.datetime(2008, 1, 7, 19, 30)),
#   (8328,
#    89,
#    9,
#    1883,
#    'Britney Spears',
#    datetime.datetime(2008, 2, 26, 19, 30)),
#   (8330, 119, 9, 2058, 'Ringo Starr', datetime.datetime(2008, 8, 20, 19, 0)),
#   (8333, 116, 9, 1860, 'Sammy Hagar', datetime.datetime(2008, 2, 3, 19, 0)),
#   (8336, 119, 9, 2064, 'Scorpions', datetime.datetime(2008, 8, 26, 19, 30)),
#   (8342, 11, 9, 2086, 'Seal', datetime.datetime(2008, 9, 17, 15, 0)),
#   (8351, 80, 9, 2040, 'Hot Chip', datetime.datetime(2008, 8, 2, 15, 0)),
#   (8357, 69, 9, 2155, 'Lonestar', datetime.datetime(2008, 11, 25, 19, 30)),
#   (8359, 81, 9, 1835, 'Rick Braun', datetime.datetime(2008, 1, 9, 15, 0)),
#   (8362,
#    5,
#    9,
#    2162,
#    'Hootie and the Blowfish',
#    datetime.datetime(2008, 12, 2, 19, 0)),
#   (8367,
#    98,
#    9,
#    2070,
#    'Jerry Jeff Walker',
#    datetime.datetime(2008, 9, 1, 14, 0)),
#   (8371, 2, 9, 2049, 'Ray Davies', datetime.datetime(2008, 8, 11, 19, 0)),
#   (8374, 72, 9, 2134, 'Tina Turner', datetime.datetime(2008, 11, 4, 15, 0)),
#   (8385, 116, 9, 1970, 'Dandy Warhols', datetime.datetime(2008, 5, 1, 19, 0)),
#   (8389,
#    67,
#    9,
#    1982,
#    'Southside Johnny & the Asbury Jukes',
#    datetime.datetime(2008, 6, 5, 19, 0)),
#   (8390, 75, 9, 1866, 'Trace Adkins', datetime.datetime(2008, 2, 9, 19, 30)),
#   (8391,
#    69,
#    9,
#    1987,
#    'Dropkick Murphys',
#    datetime.datetime(2008, 6, 10, 19, 0)),
#   (8399, 5, 9, 2036, 'Decemberists', datetime.datetime(2008, 7, 29, 19, 0)),
#   (8400, 5, 9, 2086, 'Bow Wow', datetime.datetime(2008, 9, 17, 14, 0)),
#   (8407,
#    92,
#    9,
#    2033,
#    'Crosby Stills Nash',
#    datetime.datetime(2008, 7, 26, 15, 0)),
#   (8420,
#    80,
#    9,
#    1998,
#    'Lucinda Williams',
#    datetime.datetime(2008, 6, 21, 19, 0)),
#   (8422, 74, 9, 2014, 'Ween', datetime.datetime(2008, 7, 7, 14, 0)),
#   (8423, 70, 9, 1983, 'Cake', datetime.datetime(2008, 6, 6, 15, 0)),
#   (8426,
#    91,
#    9,
#    1938,
#    'Michael McDonald',
#    datetime.datetime(2008, 4, 22, 19, 30)),
#   (8434, 14, 9, 2120, 'Air Supply', datetime.datetime(2008, 10, 21, 19, 30)),
#   (8437, 103, 9, 1899, 'Teddy Geiger', datetime.datetime(2008, 3, 14, 14, 0)),
#   (8445, 3, 9, 1838, 'Gary Allan', datetime.datetime(2008, 1, 12, 15, 0)),
#   (8451, 108, 9, 2075, 'Etta James', datetime.datetime(2008, 9, 6, 19, 30)),
#   (8456,
#    80,
#    9,
#    1922,
#    'Zappa Plays Zappa',
#    datetime.datetime(2008, 4, 6, 19, 30)),
#   (8459,
#    3,
#    9,
#    1909,
#    'Rick Springfield',
#    datetime.datetime(2008, 3, 24, 19, 0)),
#   (8460, 98, 9, 1978, 'Eagles', datetime.datetime(2008, 6, 1, 14, 0)),
#   (8479, 74, 9, 1883, 'Joe Satriani', datetime.datetime(2008, 2, 26, 14, 0)),
#   (8486,
#    14,
#    9,
#    1839,
#    'Christina Aguilera',
#    datetime.datetime(2008, 1, 13, 19, 30)),
#   (8496, 69, 9, 1855, 'Killers', datetime.datetime(2008, 1, 29, 19, 0)),
#   (8504, 80, 9, 2120, 'Clint Black', datetime.datetime(2008, 10, 21, 19, 30)),
#   (8506,
#    89,
#    9,
#    2182,
#    'Flogging Molly',
#    datetime.datetime(2008, 12, 22, 19, 30)),
#   (8507, 119, 9, 1995, 'Linda Eder', datetime.datetime(2008, 6, 18, 19, 0)),
#   (8522, 11, 9, 2108, 'Nas', datetime.datetime(2008, 10, 9, 19, 0)),
#   (8528, 79, 9, 1845, 'America', datetime.datetime(2008, 1, 19, 19, 30)),
#   (8529,
#    119,
#    9,
#    2135,
#    'Vanessa Hudgens',
#    datetime.datetime(2008, 11, 5, 19, 30)),
#   (8549, 92, 9, 1954, 'Marc Anthony', datetime.datetime(2008, 5, 1, 19, 30)),
#   (8553, 92, 9, 1883, 'John Prine', datetime.datetime(2008, 2, 26, 15, 0)),
#   (8564, 80, 9, 2002, 'Phil Vassar', datetime.datetime(2008, 6, 25, 19, 0)),
#   (8569, 74, 9, 1989, 'Girl Talk', datetime.datetime(2008, 6, 12, 14, 0)),
#   (8573, 13, 9, 1898, 'Journey', datetime.datetime(2008, 3, 13, 14, 0)),
#   (8577,
#    70,
#    9,
#    2155,
#    'Country Thunder USA',
#    datetime.datetime(2008, 11, 25, 15, 0)),
#   (8585,
#    69,
#    9,
#    2028,
#    'Little River Band',
#    datetime.datetime(2008, 7, 21, 15, 0)),
#   (8598, 70, 9, 2043, 'Bow Wow', datetime.datetime(2008, 8, 5, 15, 0)),
#   (8599, 74, 9, 2174, 'John Hiatt', datetime.datetime(2008, 12, 14, 14, 0)),
#   (8601, 75, 9, 2132, 'Built To Spill', datetime.datetime(2008, 11, 2, 14, 0)),
#   (8602,
#    3,
#    9,
#    2031,
#    'Toad The Wet Sprocket',
#    datetime.datetime(2008, 7, 24, 15, 0)),
#   (8610, 71, 9, 1961, 'Sugarland', datetime.datetime(2008, 5, 1, 19, 0)),
#   (8620,
#    116,
#    9,
#    2183,
#    'Susan Tedeschi',
#    datetime.datetime(2008, 12, 23, 19, 0)),
#   (8623, 103, 9, 2173, 'Daughtry', datetime.datetime(2008, 12, 13, 19, 0)),
#   (8625,
#    129,
#    9,
#    2044,
#    'Melissa Etheridge',
#    datetime.datetime(2008, 8, 6, 14, 0)),
#   (8626, 119, 9, 2119, 'Scorpions', datetime.datetime(2008, 10, 20, 14, 0)),
#   (8628, 67, 9, 1962, 'Steve Winwood', datetime.datetime(2008, 5, 1, 15, 0)),
#   (8631, 69, 9, 2047, 'The Whigs', datetime.datetime(2008, 8, 9, 19, 0)),
#   ...])

# %%
# Get event information where the total sales for that event were greater than $50000
sq3 = """ SELECT e.*
          FROM event e
          WHERE e.event_id IN (
          SELECT s.event_id
          FROM sales s
          GROUP BY s.event_id
          HAVING SUM(s.price_paid) > 50000);"""
run_query(sq3)
# Out:
# (['event_id', 'venue_id', 'cat_id', 'date_id', 'event_name', 'start_time'],
#  [(289,
#    300,
#    8,
#    2100,
#    'Adriana Lecouvreur',
#    datetime.datetime(2008, 10, 1, 19, 30)),
#   (1602,
#    257,
#    6,
#    2128,
#    'Phantom of the Opera',
#    datetime.datetime(2008, 10, 29, 19, 30)),
#   (7895, 47, 9, 1944, 'Janet Jackson', datetime.datetime(2008, 4, 28, 15, 0))])

# %%
get_table_names()
# Out:
# [('sales',),
#  ('venue',),
#  ('event',),
#  ('users',),
#  ('category',),
#  ('listing',),
#  ('date',)]

# %%
get_column_names(table_name= 'date')
# Out:
# [('date_id',),
#  ('qtr',),
#  ('year',),
#  ('holiday',),
#  ('week',),
#  ('cal_date',),
#  ('day',),
#  ('month',)]

# %%
## Q6 Your function ends here - Any code outside of these start/end markers won't be graded
