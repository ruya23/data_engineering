# %% [markdown]
# ##  HW2 Part 2 - Flatting JSON data from Yelp
#
# For this second part of the assignment we're going to be using the Yelp API via the python package `yelpapi`.  Like with the Spotify API, you need to go get a yelp developer account here: https://www.yelp.com/fusion.
# When you try to create an app, it asks for name, description and contact info. The it gives you clientid and api key.
#
# The goal will be to make a dataset of local taco places that are doing well during Coronavirus. Specifically, we want to make a dataset that takes their average score since they've been open and compares it to the average score of the last three reviews.  Shops that have been doing well should hopefully have these two averages be similar.
#
# There will be three main steps to this process:
#
# * First you'll search by location type and get aggregate information for everything that falls in the ice cream category.
# * Second you'll get reviews for all those locations.  Yelp only returns three reviews when you call an ID, but that still works. Given you can only query one ID at a time, you'll need to write a loop to create a dataframe of all the reviews.
# * Third, you'll aggregate the latest review information to see how their average review score compares to their overall average review score.

# %%
# Mount google drive
import os, sys
from google.colab import drive
drive.mount('/content/mnt')
nb_path = '/content/notebooks'
os.symlink('/content/mnt/My Drive/Colab Notebooks', nb_path)
sys.path.insert(0, nb_path)  # or append(nb_path)
# Out:
# Mounted at /content/mnt

# %%
# Install yelpapi once. Next time you run this notebook, you can skip this.
# !pip install --target=$nb_path yelpapi

# %%
# !pip install yelpapi
# Out:
# Requirement already satisfied: yelpapi in /usr/local/lib/python3.10/dist-packages (2.5.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from yelpapi) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->yelpapi) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->yelpapi) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->yelpapi) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->yelpapi) (2024.8.30)

# %%
# Now enter your API key so you can make requests
from yelpapi import YelpAPI

# yelp_api = YelpAPI('ENTER YOUR KEY HERE')
api_key = '76E6F89aosfZor1yCwCVVD73TbLXxxqSDSB15TsUxU5GGMaXnxzsvhQ6qEUYTFkJTxRjc8HrRZY0MEad-SFEG6Cf5Fl4QYDmujlxny6ZQT2FGukqp8PHqvoVC_s7YXYx'
yelp_api = YelpAPI(api_key)

# %% [markdown]
# ### Making calls to with Yelp API
#
# There are many functions in the `yelpapi` package.  The first one we'll use is `search_query()`.  You can put in a term you want to search for followed up by the location and it'll give you all the locations that match.  For example, the following would search for all ice cream places here in Tucson.
#
# ```
# ice = yelp_api.search_query(term = 'ice cream', location = 'Tucson, AZ')
# ```
#
# This will give you a response of all the ice cream places in Tucson. It'll be in JSON form so will need flattening before being useful.

# %% [markdown]
# ### Q6 Getting all taco shops and flattening - [3 points]
#
# **Task:** Start by making a dataframe that uses the `search_query()` function to search using the term 'taco'.  Call this `taco_shops`.  After that, flatten the json results to `taco_shops_df`.

# %%
## Q6 part 1 Your code starts here
# search for taco shops and store to taco_shops
taco_shops = yelp_api.search_query(term = 'taco', location = 'Tucson, AZ')

# %%
# Look at taco_shops
taco_shops
# Out:
# {'businesses': [{'id': 'o3woQWQ-0HxFftItIEeNdw',
#    'alias': 'el-rustico-tucson',
#    'name': 'El Rustico',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r0iQjoJH3F_2hDtZ6v8JJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-rustico-tucson?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 289,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.249041, 'longitude': -110.978552},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2281 N Oracle Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Tucson',
#     'zip_code': '85705',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['2281 N Oracle Rd', 'Tucson, AZ 85705']},
#    'phone': '+15206233478',
#    'display_phone': '(520) 623-3478',
#    'distance': 4427.438301074469},
#   {'id': 'nvwtUKh6rBb29rFbC9kq5w',
#    'alias': 'taco-rico-tucson-2',
#    'name': 'Taco Rico',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f9mKwXxAW1vpb6aZfDfT_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-rico-tucson-2?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 99,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.9,
#    'coordinates': {'latitude': 32.33711, 'longitude': -111.06119},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4499 W Ina Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Tucson',
#     'zip_code': '85741',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['4499 W Ina Rd', 'Tucson, AZ 85741']},
#    'phone': '+15202864776',
#    'display_phone': '(520) 286-4776',
#    'distance': 15907.766627944407},
#   {'id': 'sYNKHA_o1eYurKLCxMOQnA',
#    'alias': 'la-frida-mexican-grill-and-seafood-tucson',
#    'name': 'La Frida Mexican Grill & Seafood',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y0REcHfGYV-VlPbQWocqMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-frida-mexican-grill-and-seafood-tucson?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 305,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 32.206109346545134, 'longitude': -110.8376665},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7230 E 22nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Tucson',
#     'zip_code': '85705',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['7230 E 22nd St', 'Tucson, AZ 85705']},
#    'phone': '+15203448335',
#    'display_phone': '(520) 344-8335',
#    'distance': 9853.886778058735},
#   {'id': 'jmwasbZfgj3honf79qKsnA',
#    'alias': 'street-taco-and-beer-co-tucson',
#    'name': 'Street- Taco and Beer Co.',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VOaRTnYRNSnSF6DR28fUog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/street-taco-and-beer-co-tucson?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 976,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 32.222001, 'longitude': -110.972225},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '58 W Congress St',
#     'address2': None,
#     'address3': '',
#     'city': 'Tucson',
#     'zip_code': '85701',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['58 W Congress St', 'Tucson, AZ 85701']},
#    'phone': '+19499492226',
#    'display_phone': '(949) 949-2226',
#    'distance': 4599.43926172535},
#   {'id': 'A-5IN85MwL9F8wJRsDna6g',
#    'alias': 'tacos-apson-tucson',
#    'name': 'Tacos Apson',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3fm1NqA6sHWNAkTwy2dRxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-apson-tucson?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 348,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 32.1831398010254,
#     'longitude': -110.97688293457},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3501 S 12th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Tucson',
#     'zip_code': '85713',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['3501 S 12th Ave', 'Tucson, AZ 85713']},
#    'phone': '+15206701248',
#    'display_phone': '(520) 670-1248',
#    'distance': 8119.923468751527},
#   {'id': 'aZ-2J_3nvuT-XdryCjrthg',
#    'alias': 'carniceria-wild-west-tucson-2',
#    'name': 'Carniceria Wild West',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Bqdpq4aKA8x9hq6RP9vWOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carniceria-wild-west-tucson-2?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 84,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 32.294315, 'longitude': -110.961553},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '4825 N 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Tucson',
#     'zip_code': '85718',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['4825 N 1st Ave', 'Tucson, AZ 85718']},
#    'phone': '+15203449253',
#    'display_phone': '(520) 344-9253',
#    'distance': 6149.896045687265},
#   {'id': 'DVBJRvnCpkqaYl6nHroaMg',
#    'alias': 'tumerico-tucson',
#    'name': 'Tumerico',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CuNce_79wwpMg91hBaEO1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tumerico-tucson?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 1212,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 32.2276238, 'longitude': -110.9346204},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2526 E 6th St',
#     'address2': None,
#     'address3': None,
#     'city': 'Tucson',
#     'zip_code': '85716',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['2526 E 6th St', 'Tucson, AZ 85716']},
#    'phone': '+15202406947',
#    'display_phone': '(520) 240-6947',
#    'distance': 1969.3303222293234},
#   {'id': 'Nggy_QUDxaLlrcQAQf7GnQ',
#    'alias': 'taqueria-juanitos-tucson-4',
#    'name': "Taqueria Juanito's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/u67QWv8Ob2PoPQL2Yuk4sA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-juanitos-tucson-4?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 522,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.250571, 'longitude': -110.982543},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '708 W Grant Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Tucson',
#     'zip_code': '85705',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['708 W Grant Rd', 'Tucson, AZ 85705']},
#    'phone': '+15206232222',
#    'display_phone': '(520) 623-2222',
#    'distance': 4818.947059216808},
#   {'id': 'nEaTbGFlU7d9eLU2kl6KBw',
#    'alias': 'taqueria-el-pueblito-tucson-2',
#    'name': 'Taqueria El Pueblito',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DNlNjVg25gI9W1ppWwbK4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-el-pueblito-tucson-2?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 395,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 32.264046291126,
#     'longitude': -110.944400293796},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1800 E Fort Lowell Rd',
#     'address2': 'Ste A156',
#     'address3': '',
#     'city': 'Tucson',
#     'zip_code': '85719',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['1800 E Fort Lowell Rd',
#      'Ste A156',
#      'Tucson, AZ 85719']},
#    'phone': '+15203399336',
#    'display_phone': '(520) 339-9336',
#    'distance': 2415.6719133742145},
#   {'id': 'n-Fvi1lNzSJfp2na2nWcxQ',
#    'alias': 'la-yaquesita-mexican-cuisine-no-title',
#    'name': 'La Yaquesita Mexican Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zvqRS9rxI1cfMUhsRirhDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-yaquesita-mexican-cuisine-no-title?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 73,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 32.22818825671165,
#     'longitude': -110.9653277951665},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '500 N 4th Ave',
#     'address2': 'Ste 1',
#     'address3': '',
#     'city': 'Tucson',
#     'zip_code': '85705',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['500 N 4th Ave', 'Ste 1', 'Tucson, AZ 85705']},
#    'phone': '+15206221924',
#    'display_phone': '(520) 622-1924',
#    'distance': 3683.016838080199},
#   {'id': 'RHdEScVIAQ7xzFFMiQEnAQ',
#    'alias': 'the-quesadillas-tucson',
#    'name': 'The Quesadillas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p2bfZEsLz1Hi4NtLVQmywA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-quesadillas-tucson?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 661,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 32.251377455959386,
#     'longitude': -110.87498140841916},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2418 N Craycroft Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Tucson',
#     'zip_code': '85712',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['2418 N Craycroft Rd', 'Tucson, AZ 85712']},
#    'phone': '+15202961345',
#    'display_phone': '(520) 296-1345',
#    'distance': 5378.698960587908},
#   {'id': 'kqJFht2-rPBgsMaHXpG9-A',
#    'alias': 'amelias-mexican-kitchen-tucson',
#    'name': "Amelia's Mexican Kitchen",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WFB1APVk2krUkEcsyE0_LA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amelias-mexican-kitchen-tucson?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 439,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 32.25117147070553, 'longitude': -110.8737481},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5553 E Grant Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Tucson',
#     'zip_code': '85712',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['5553 E Grant Rd', 'Tucson, AZ 85712']},
#    'phone': '+15203507406',
#    'display_phone': '(520) 350-7406',
#    'distance': 5490.912247649972},
#   {'id': 'TvJWlcn3NdRTr6i0VpIeiw',
#    'alias': 'ramiros-taco-shop-tucson',
#    'name': "Ramiro's Taco Shop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Luf2iFHF6Za3KQO7Yepn2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramiros-taco-shop-tucson?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 14,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 32.221207280338255,
#     'longitude': -110.9512415600255},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1350 E Broadway Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Tucson',
#     'zip_code': '85719',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['1350 E Broadway Blvd', 'Tucson, AZ 85719']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3236.1250143777665},
#   {'id': 'MK0OMY_u9unl8xSqjPLtMw',
#    'alias': 'seis-kitchen-tucson-3',
#    'name': 'Seis Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IA84w5FJqeah-hObULXWTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seis-kitchen-tucson-3?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 1000,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 32.21975122142369,
#     'longitude': -110.98547891840268},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '130 S Avenida Del Convento',
#     'address2': 'Ste 100',
#     'address3': '',
#     'city': 'Tucson',
#     'zip_code': '85745',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['130 S Avenida Del Convento',
#      'Ste 100',
#      'Tucson, AZ 85745']},
#    'phone': '+15206222002',
#    'display_phone': '(520) 622-2002',
#    'distance': 5793.87493705726},
#   {'id': 'DA5Mecz4auAhTTlFWNh33Q',
#    'alias': 'la-chaiteria-tucson',
#    'name': 'La Chaiteria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PY0EuQUJ14lWxT8u-2s58Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-chaiteria-tucson?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 164,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 32.2203982, 'longitude': -110.98881833},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1002 W Congress St',
#     'address2': '',
#     'address3': None,
#     'city': 'Tucson',
#     'zip_code': '85745',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['1002 W Congress St', 'Tucson, AZ 85745']},
#    'phone': '+15204007127',
#    'display_phone': '(520) 400-7127',
#    'distance': 6036.858521761892},
#   {'id': 'Jcm-2RZWIcF0E4V6kekBsQ',
#    'alias': 'el-chinito-gordo-tucson-2',
#    'name': 'El Chinito Gordo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5k5Sm4hQYRq6R_SQJUlczQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-chinito-gordo-tucson-2?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 414,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 32.26007117, 'longitude': -110.97779133},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2920 N Oracle Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Tucson',
#     'zip_code': '85705',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['2920 N Oracle Rd', 'Tucson, AZ 85705']},
#    'phone': '+15208228776',
#    'display_phone': '(520) 822-8776',
#    'distance': 4641.653711963312},
#   {'id': '0ghzROkZWKWwQKDt1fkPAQ',
#    'alias': 'el-guero-canelo-tucson-7',
#    'name': 'El Guero Canelo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ywhj9Zbq3GU8UmpQBlWJ2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-guero-canelo-tucson-7?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 828,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.25188, 'longitude': -110.97749},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2480 N Oracle Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Tucson',
#     'zip_code': '85705',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['2480 N Oracle Rd', 'Tucson, AZ 85705']},
#    'phone': '+15208828977',
#    'display_phone': '(520) 882-8977',
#    'distance': 4382.020562157121},
#   {'id': 'sk11RFNogbE0axZUIDBRHw',
#    'alias': 'los-mezquites-tucson',
#    'name': 'Los Mezquites',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/trZTQzZDmDA1eRczrrIAEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-mezquites-tucson?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 27,
#    'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 32.1482243038168,
#     'longitude': -111.017440147698},
#    'transactions': ['delivery'],
#    'location': {'address1': '2341-2399 W Drexel Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Tucson',
#     'zip_code': '85746',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['2341-2399 W Drexel Rd', 'Tucson, AZ 85746']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 13463.71023188242},
#   {'id': 'orLNj9bDRMxaz6Hgs9YvVg',
#    'alias': 'agave-house-tucson-2',
#    'name': 'Agave House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Uz--JqAMfxJbOKDCTgXeDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/agave-house-tucson-2?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 97,
#    'categories': [{'alias': 'newmexican', 'title': 'New Mexican Cuisine'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 32.232044, 'longitude': -110.957177},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '943 E University Blvd',
#     'address2': 'Ste 171',
#     'address3': '',
#     'city': 'Tucson',
#     'zip_code': '85719',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['943 E University Blvd',
#      'Ste 171',
#      'Tucson, AZ 85719']},
#    'phone': '+15206006631',
#    'display_phone': '(520) 600-6631',
#    'distance': 2809.5722077673877},
#   {'id': 'gFyPBRZmkJAFhm1e-CcNXg',
#    'alias': 'tacos-los-compas-tucson',
#    'name': 'Tacos Los Compas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sQKzs78hVGrWNd_i_rQMtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-los-compas-tucson?adjust_creative=9fg9i7ke1NAGhf8W3e97VA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9fg9i7ke1NAGhf8W3e97VA',
#    'review_count': 6,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 32.2652872, 'longitude': -110.9548389},
#    'transactions': [],
#    'location': {'address1': '1115 E Fort Lowell Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Tucson',
#     'zip_code': '85719',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['1115 E Fort Lowell Rd', 'Tucson, AZ 85719']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3121.1853984481754}],
#  'total': 886,
#  'region': {'center': {'longitude': -110.93170166015625,
#    'latitude': 32.245161513458996}}}

# %%
# What keys are present?
taco_shops.keys()
## Q6 part 1  Your code ends here - Any code outside of these start/end markers won't be graded
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# Now use the json_normalize function to flatten `taco_shops`.  Note that you need to select the key that contains the businesses when flattening.  But this one is easier than the examples from the homework in that you don't need to provide any other arguments.
#
# Store the result as `taco_shops_df`
#
# After that select only the columns 'id', 'alias', 'name', 'review_count', and 'rating'.

# %%
## Q6 part 2 Your code starts here
# Flatten to taco_shops_df
import pandas as pd
from pandas import json_normalize

taco_shops_df = json_normalize(taco_shops['businesses'])
taco_shops_df.head() # Check
# Out:
#                        id                                      alias  \
# 0  o3woQWQ-0HxFftItIEeNdw                          el-rustico-tucson
# 1  nvwtUKh6rBb29rFbC9kq5w                         taco-rico-tucson-2
# 2  sYNKHA_o1eYurKLCxMOQnA  la-frida-mexican-grill-and-seafood-tucson
# 3  jmwasbZfgj3honf79qKsnA             street-taco-and-beer-co-tucson
# 4  A-5IN85MwL9F8wJRsDna6g                         tacos-apson-tucson
#
#                                name  \
# 0                        El Rustico
# 1                         Taco Rico
# 2  La Frida Mexican Grill & Seafood
# 3         Street- Taco and Beer Co.
# 4                       Tacos Apson
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/r0iQjo...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/f9mKwX...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/Y0REcH...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/VOaRTn...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/3fm1Nq...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/el-rustico-tucson?adj...           289
# 1  https://www.yelp.com/biz/taco-rico-tucson-2?ad...            99
# 2  https://www.yelp.com/biz/la-frida-mexican-gril...           305
# 3  https://www.yelp.com/biz/street-taco-and-beer-...           976
# 4  https://www.yelp.com/biz/tacos-apson-tucson?ad...           348
#
#                                           categories  rating  \
# 0             [{'alias': 'tacos', 'title': 'Tacos'}]     4.5
# 1  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.9
# 2  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.7
# 3  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.3
# 4         [{'alias': 'mexican', 'title': 'Mexican'}]     4.2
#
#          transactions  ... coordinates.latitude coordinates.longitude  \
# 0                  []  ...            32.249041           -110.978552
# 1                  []  ...            32.337110           -111.061190
# 2                  []  ...            32.206109           -110.837666
# 3          [delivery]  ...            32.222001           -110.972225
# 4  [pickup, delivery]  ...            32.183140           -110.976883
#
#   location.address1  location.address2  location.address3  location.city  \
# 0  2281 N Oracle Rd                                  None         Tucson
# 1     4499 W Ina Rd               None               None         Tucson
# 2    7230 E 22nd St                                  None         Tucson
# 3  58 W Congress St               None                            Tucson
# 4   3501 S 12th Ave                                               Tucson
#
#   location.zip_code location.country location.state  \
# 0             85705               US             AZ
# 1             85741               US             AZ
# 2             85705               US             AZ
# 3             85701               US             AZ
# 4             85713               US             AZ
#
#                location.display_address
# 0  [2281 N Oracle Rd, Tucson, AZ 85705]
# 1     [4499 W Ina Rd, Tucson, AZ 85741]
# 2    [7230 E 22nd St, Tucson, AZ 85705]
# 3  [58 W Congress St, Tucson, AZ 85701]
# 4   [3501 S 12th Ave, Tucson, AZ 85713]
#
# [5 rows x 24 columns]

# %%
# Select only necessary columns
taco_shops_df = taco_shops_df[['id', 'alias', 'name', 'review_count', 'rating']]
taco_shops_df.shape # Check shape.  Is it 20 x 5?
## Q6 part 2  Your code ends here - Any code outside of these start/end markers won't be graded
# Out:
# (20, 5)

# %% [markdown]
# ## Q7 Getting reviews for the taco shops - [6 points]
#
# Now we're going to use the `reviews_query()` function to get the last three reviews for a given ID.  The issue here is that you can only feed it one ID at a time.  So, we'll have to write a loop that queries for each ID in `taco_shops_df` and builds out a dataframe of reviews.
#
# **Task:**  Write a for loop that does the following steps:
# * First make an empty data frame outside of the loop called `taco_shops_reviews_df`
# * Initalize your loop so that it runs the length of `taco_shops_df` you made earlier.
# * For each i in loop, use the id from `taco_shops_df` to get reviews from yelp using the `reviews_query()` function in `yelp_api` and store it to an object called `reviews`.
# * Flatten `reviews` to an objected called `reviews_df`
# * Add `location_id` to `reviews_df` - I gave you the code to do this :)
# * Append `reviews_df` to `taco_shops_reviews_df` such that it builds out that dataframe with each `reviews_df` dataframe that's generated each loop.
# * After the loop is done select only the columns `'id', 'text', 'rating', 'time_created', 'location_id'`

# %%
## Q7 Your code starts here
# Write our loop

taco_shops_reviews_df = pd.DataFrame()

for i in range(len(taco_shops_df)):
    shop_id = taco_shops_df.iloc[i]['id']
    reviews = yelp_api.reviews_query(shop_id)
    reviews_df = pd.json_normalize(reviews, 'reviews')
    reviews_df['location_id'] = taco_shops_df['id'][i]
    taco_shops_reviews_df = pd.concat([taco_shops_reviews_df, reviews_df], ignore_index=True)

# %%
# Select columns 'id', 'text', 'rating', 'time_created', 'location_id'
taco_shops_reviews_df = taco_shops_reviews_df[['id', 'text', 'rating', 'time_created', 'location_id']]
## Q7  Your code ends here - Any code outside of these start/end markers won't be graded

# %% [markdown]
# ### Q8 Aggregating your review data - [3 points]
#
# **Task:** Now go and do a data aggregation to get the mean review score across the three reviews. Remember, we want this grouped by location_id.  Call this dataframe `latest_reviews_agg`.
#
# In your groupby you should set `as_index` to false to make joining on the ID values easier.
#
# You should also rename the second column to `mean_rating` vs. leaving it as the dual level name.

# %%
## Q8 Your code starts here
# Do your groupby to get mean rating.
# Call it latest_reviews_agg.
latest_reviews_agg = taco_shops_reviews_df.groupby('location_id', as_index=False)['rating'].mean()

# %%
# Check it!
latest_reviews_agg.head()
# Out:
#               location_id    rating
# 0  0ghzROkZWKWwQKDt1fkPAQ  4.333333
# 1  A-5IN85MwL9F8wJRsDna6g  5.000000
# 2  DA5Mecz4auAhTTlFWNh33Q  4.666667
# 3  DVBJRvnCpkqaYl6nHroaMg  5.000000
# 4  Jcm-2RZWIcF0E4V6kekBsQ  4.666667

# %%
# Rename so the two column names are 'location_id' and 'mean_rating'
latest_reviews_agg = latest_reviews_agg.rename(columns={'rating': 'mean_rating'})
## Q8  Your code ends here - Any code outside of these start/end markers won't be graded

# %% [markdown]
# ### Q9 Join your two datasets and one last transform - [3 points]
#
# **Task:** Now it's time to join `latest_reviews_agg` back to your `taco_shops_df` dataframe.  You're going to want to join them on the location_id, but remember it is called just 'id' in the `taco_shops_df`  dataframe.  Call this joined dataset `taco_shops_comp`
#
# After you make that dataset do one last transform.  In this I want you to make a new column called 'still_good' where the value is 'yes' if the mean_rating is greater than or equal to the average rating since they opened, or 'no' if the rating has dropped.   The idea here is that this could be a value that one would use to see if their average score of the latest reviews has improved or suffered during Covid.

# %%
## Q9 Your code starts here
# Join and name taco_shops_comp

taco_shops_comp = pd.merge(taco_shops_df, latest_reviews_agg, left_on='id', right_on='location_id', how='left')

# %% [markdown]
# When you are comparing the columns make sure to not comparing taco_shops_df and taco_shops_comp since their tuples may have different orders! Use both columns from taco_shops_comp

# %%
# Make still_good column
taco_shops_comp['still_good'] = taco_shops_comp.apply(lambda row: 'yes' if row['mean_rating'] >= row['rating'] else 'no',axis=1)

# %%
# So, do any locations have a lower average in their last three reviews compared to their average overall score?
locations_with_lower_recent_ratings = taco_shops_comp[taco_shops_comp['still_good'] == 'no']
print(locations_with_lower_recent_ratings)
## Q9  Your code ends here - Any code outside of these start/end markers won't be graded
# Out:
#                         id                                      alias  \
# 1   nvwtUKh6rBb29rFbC9kq5w                         taco-rico-tucson-2
# 2   sYNKHA_o1eYurKLCxMOQnA  la-frida-mexican-grill-and-seafood-tucson
# 5   aZ-2J_3nvuT-XdryCjrthg              carniceria-wild-west-tucson-2
# 8   nEaTbGFlU7d9eLU2kl6KBw              taqueria-el-pueblito-tucson-2
# 13  MK0OMY_u9unl8xSqjPLtMw                      seis-kitchen-tucson-3
# 14  DA5Mecz4auAhTTlFWNh33Q                        la-chaiteria-tucson
# 17  sk11RFNogbE0axZUIDBRHw                       los-mezquites-tucson
# 18  orLNj9bDRMxaz6Hgs9YvVg                       agave-house-tucson-2
#
#                                 name  review_count  rating  \
# 1                          Taco Rico            99     4.9
# 2   La Frida Mexican Grill & Seafood           305     4.7
# 5               Carniceria Wild West            84     4.7
# 8               Taqueria El Pueblito           395     4.2
# 13                      Seis Kitchen          1000     4.2
# 14                      La Chaiteria           164     4.7
# 17                     Los Mezquites            27     4.7
# 18                       Agave House            97     4.4
#
#                location_id  mean_rating still_good
# 1   nvwtUKh6rBb29rFbC9kq5w     4.333333         no
# 2   sYNKHA_o1eYurKLCxMOQnA     4.666667         no
# 5   aZ-2J_3nvuT-XdryCjrthg     4.000000         no
# 8   nEaTbGFlU7d9eLU2kl6KBw     3.000000         no
# 13  MK0OMY_u9unl8xSqjPLtMw     3.666667         no
# 14  DA5Mecz4auAhTTlFWNh33Q     4.666667         no
# 17  sk11RFNogbE0axZUIDBRHw     4.666667         no
# 18  orLNj9bDRMxaz6Hgs9YvVg     3.000000         no

# %% [markdown]
# You should get 8 shops (this may change suddenly since data is live, but on July 12 2024 is still 8) including El Rustico and Seis Kitchen
